# %%
# Load in Libraries
library("dplyr")
# Out:
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union

# %%
glassdoor = read.csv('../../Data/glassdoor.csv')

# %%
# Recoding State into a New Column unique(glassdoor$State)
glassdoor$StateR <- glassdoor$StateR[glassdoor$State=='NY'] <- glassdoor$StateR[glassdoor$State=='NJ'] <- 1

# %%
# Recoding City into the same variable
unique(glassdoor$City)
# Out:
#  [1] "New York"       "Rego Park"      "West New York"  "Williston Park"
#  [5] "Brooklyn"       "Maspeth"        "Paramus"        "West Orange"
#  [9] "Staten Island"  "Lynbrook"       "Fort Lee"       "Jersey City"
# [13] "Bronx"          "Mamaroneck"

# %%
glassdoor$City[glassdoor$City=='New York'] <- glassdoor$City[glassdoor$City=='Rego Park'] <- glassdoor$City[glassdoor$City=='West New York'] <- glassdoor$City[glassdoor$City=='Williston Park'] <- glassdoor$City[glassdoor$City=='Brooklyn'] <- glassdoor$City[glassdoor$City=='Maspeth'] <- glassdoor$City[glassdoor$City=='Paramus'] <- glassdoor$City[glassdoor$City=='West Orange'] <- glassdoor$City[glassdoor$City=='Staten Island'] <- glassdoor$City[glassdoor$City=='Lynbrook'] <- glassdoor$City[glassdoor$City=='Fort Lee'] <- glassdoor$City[glassdoor$City=='Jersey City'] <- glassdoor$City[glassdoor$City=='Bronx'] <- glassdoor$City[glassdoor$City=='Mamaroneck'] <- 13

# %%
# Don't need to dummy code in R - all analyses that need it do it automacally # Recoding continuous to categorical with the Max Salary Variable
glassdoor$Max_SalaryR = ifelse(glassdoor$Max_Salary < 30000, "0", ifelse(glassdoor$Max_Salary <= 60000,"1", "2"))

# %%
head(glassdoor)
# Out:
#   Job_title
# 1 Chief Marketing Officer (CMO)
# 2 Registered Nurse
# 3 Dental Hygienist
# 4 Senior Salesforce Developer
# 5 DEPUTY EXECUTIVE DIRECTOR, PROGRAM AND LEGAL ADVOCACY
# 6 Emergency Veterinarian - NYC
#   Company                               State City Min_Salary Max_Salary
# 1 National Debt Relief                  NY    13       -1         -1
# 2 Queens Boulevard Endoscopy Center     NY    13       -1         -1
# 3 Batista Dental                        NJ    13       -1         -1
# 4 National Debt Relief                  NY    13    44587      82162
# 5 National Advocates for Pregnant Women NY    13   125410     212901
# 6 Veterinary Emergency Group            NY    13    94715     103279
# ...
