# %%
library(ggplot2)

# %%
df <- read.csv("https://raw.githubusercontent.com/woz-u/DS-Student-Resources/main/DS105-Intermediate-Statistics/Data/Seattle_ParksnRec.csv")

# %%
df
# Out:
#    Geographic.Region Year X..of.trips.Winter X..of.participants.Winter
# 1  Central           2005 13                 154
# 2  Central           2006 17                 229
# 3  Central           2007 17                 222
# 4  Central           2008 18                 300
# 5  Central           2009 18                 276
# 6  Central           2010 15                 208
# 7  Central           2011  5                  54
# 8  Central           2012  7                 148
# 9  Central           2013  9                  70
# 10 Central           2014  4                  49
# 11 Central           2015  5                  61
# 12 Central           2016  4                  31
# 13 Northeast         2005  6                 140
# 14 Northeast         2006  9                 164
# 15 Northeast         2007  7                 114
# 16 Northeast         2008  7                 219
# 17 Northeast         2009 14                 216
# 18 Northeast         2010 13                 283
# ...

# %% [markdown]
# # of trips Fall

# %% [markdown]
# Assess and transform the requested data, then submit your annotated program files for review.

# %%
#Alternative to DSO105 lesson2 using ggplot
ggplot(df, aes(x=X..of.trips.Fall)) + geom_histogram(aes(y=..density..), bins = 16, colour="black", fill="white") +
        geom_density(alpha=.2, fill="#FF6666")
# Out:
# plot without title

# %%
ggplot(df, aes(x=X..of.trips.Fall^(1/3))) + geom_histogram(aes(y=..density..), bins = 16,colour="black", fill="white") +
        geom_density(alpha=.2, fill="#FF6666")
# Out:
# plot without title

# %% [markdown]
# # of participants Fall

# %%
ggplot(df, aes(x=X..of.participants.Fall)) + geom_histogram(aes(y=..density..), bins = 16, colour="black", fill="white") +
        geom_density(alpha=.2, fill="#FF6666")
# Out:
# plot without title

# %%
ggplot(df, aes(x=X..of.participants.Fall^0.5)) + geom_histogram(aes(y=..density..), bins = 16, colour="black", fill="white") +
        geom_density(alpha=.2, fill="#FF6666")
# Out:
# plot without title

# %% [markdown]
# # of trips per Year

# %%
ggplot(df, aes(x=X..of.trips.per.year)) + geom_histogram(aes(y=..density..), bins=16, colour="black", fill="white") +
        geom_density(alpha=.2, fill="#FF6666")
# Out:
# plot without title

# %%
ggplot(df, aes(x=X..of.trips.per.year^0.333)) + geom_histogram(aes(y=..density..), bins=16, colour="black", fill="white") +
        geom_density(alpha=.2, fill="#FF6666")
# Out:
# plot without title

# %% [markdown]
# # participants per Year

# %%
ggplot(df, aes(x=X..participants.per.year)) + geom_histogram(aes(y=..density..), bins=16, colour="black", fill="white") +
        geom_density(alpha=.2, fill="#FF6666")
# Out:
# plot without title

# %%
ggplot(df, aes(x=X..participants.per.year^0.5)) + geom_histogram(aes(y=..density..), bins=16, colour="black", fill="white") +
        geom_density(alpha=.2, fill="#FF6666")
# Out:
# plot without title

# %% [markdown]
# # increase/decrease of prior year

# %%
ggplot(df, aes(x=increase.decrease.of.prior.year)) + geom_histogram(aes(y=..density..), bins=16, colour="black", fill="white") +
        geom_density(alpha=.2, fill="#FF6666")
# Out:
# plot without title

# %% [markdown]
# # Average # people per trip

# %%
ggplot(df, aes(x=Average...people.per.trip)) + geom_histogram(aes(y=..density..), bins=16, colour="black", fill="white") +
        geom_density(alpha=.2, fill="#FF6666")
# Out:
# plot without title
