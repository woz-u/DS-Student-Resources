# %%
import requests
from bs4 import BeautifulSoup # this handles parsing data from html content

url = "http://volweb.utk.edu/~mihli1/demos/case3.html"
response = requests.get(url)
soup = BeautifulSoup(response.content,
                     "html.parser")

for child in soup.children:
  print(child)  # will print ALL the children of the top-level document

print('\n')

# search by tag
paragraphs = soup.find_all('p')  # find every html element with a P tag. returns a ResultSet (like a list) of tags
for p in paragraphs:  # iterate over all the tags in the set of results
  print(p.text)  # print the text of the current tag
  if p.b:  # if searching for a <b> tag inside the current <p> doesn't return None
    print("{} is in BOLD!".format(p.b))  # then print something

print(soup.p)  # print just the first p soup finds
# Out:
# html
#
#
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>Python Demo</title>
# <style>
#         .top {color:blue;}
#         .bottom {color:brown;}
#     </style>
# </head>
# <body>
# <h2>Top</h2>
# <p class="top">This is the first paragraph</p>
# <p class="top">This is the second paragraph</p>
# <h2>Middle</h2>
# <p>This is the <b>middle</b> paragraph</p>
# <h2>Bottom</h2>
# <p class="bottom">This is the fourth paragraph</p>
# <p class="bottom">This is the fifth paragraph</p>
# </body>
# </html>
#
#
#
#
# This is the first paragraph
# This is the second paragraph
# This is the middle paragraph
# <b>middle</b> is in BOLD!
# This is the fourth paragraph
# This is the fifth paragraph
# <p class="top">This is the first paragraph</p>

# %%
import os
from bs4 import BeautifulSoup
# Python 3.x
from urllib.request import urlopen, urlretrieve

URL = 'https://www.gsa.gov/policy-regulations/policy/vehicle-management-policy/vehicle-management-library'
OUTPUT_DIR = ''  # path to output folder, '.' or '' uses current folder

u = urlopen(URL)
try:
    html = u.read().decode('utf-8')
finally:
    u.close()

soup = BeautifulSoup(html, "html.parser")
for link in soup.select('a[href^="http://"]'):
    href = link.get('href')
    if not any(href.endswith(x) for x in ['.csv','.xls','.xlsx']):
        continue

    filename = os.path.join(OUTPUT_DIR, href.rsplit('/', 1)[-1])

    # We need a https:// URL for this site
    href = href.replace('http://','https://')

    print("Downloading %s to %s..." % (href, filename) )
    urlretrieve(href, filename)
    print("Done.")
# Out:
# ...
# Done.
# ...
# Done.

# %%
import requests
from bs4 import BeautifulSoup # this handles parsing data from html content

url = "https://www.gsa.gov/policy-regulations/policy/vehicle-management-policy/vehicle-management-library"
response = requests.get(url)
soup = BeautifulSoup(response.content,
                     "html.parser")

for child in soup.children:
  print(child)  # will print ALL the children of the top-level document

print('\n')

# search by tag
paragraphs = soup.find_all('p')  # find every html element with a P tag. returns a ResultSet (like a list) of tags
for p in paragraphs:  # iterate over all the tags in the set of results
  print(p.text)  # print the text of the current tag
  if p.b:  # if searching for a <b> tag inside the current <p> doesn't return None
    print("{} is in BOLD!".format(p.b))  # then print something

print(soup.p)  # print just the first p soup finds
# Out:
# html
#
#
# [if lt IE 7 ]>
# <html class="ie6" lang="en-us">
# <![endif]
#
#
# [if IE 7 ]>
# <html class="ie7" lang="en-us">
# <![endif]
#
#
# [if IE 8 ]>
# <html class="ie8" lang="en-us">
# <![endif]
#
#
# [if IE 9 ]>
# <html class="ie9" lang="en-us">
# <![endif]
#
#
# [if (gt IE 9)|!(IE)]><!
#
#
# <html class="" lang="en-us">
# <!--<![endif]-->
# <head>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <meta content="aQpQL1MEsT30Wi80WMg3pp5fKqUJ7NjSOi9NHajrTC8" name="google-site-verification">
# <meta content="https://www.gsa.gov/sites/gsa.gov/templates/resources/images/inner-nav-logo.jpg" property="og:image"/>
# <link href="/policy-regulations/policy/vehicle-management-policy/vehicle-management-library" rel="canonical"/>
# <link href="/node/85222" rel="shortlink"/>
# <link href="https://www.gsa.gov/sites/gsa.gov/templates/resources/favicon.ico" rel="shortcut icon" type="image/vnd.microsoft.icon"/>
# ...
