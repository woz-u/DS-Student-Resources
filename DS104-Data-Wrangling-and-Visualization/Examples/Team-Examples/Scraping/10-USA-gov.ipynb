# %% [markdown]
# ## USA.gov Data
#
# ref: https://www.usa.gov/developer
#
# [USA.gov](https://www.usa.gov/) uses GitHub repositories to maintain the documentation for most of our APIs and data feeds.  Using GitHub, you can easily provide feedback to us and ask questions using each repository's issue tracker.  You can also email us any questions you might have regarding our APIs.
#
# ## APIs and Data Feeds from USA.gov
# USA.gov offers a variety of APIs and data feeds to help developers access and expose quality government information and services from their own websites and applications.  Currently, these APIs include:
#
# [Corporate Consumer Contact API](https://github.com/usagov/Corporate-Consumer-Contact-API-Documentation)
# This API returns a manually curated list of contact information for consumer-related corporations.
# Style:  RESTful API
# Return Format:  JSON, JSONP, XML
#
# [DigitalGov Search API (formerly USASearch)](https://search.usa.gov/login)
# Provides DigitalGov Search customers with results. This API is only available for use on official government websites. Sign in is required.  Once you login, you can find the API documentation under the "activate" menu.
# Style:  RESTful API (requires DigitalGov Search account)
# Return Format:  JSON, JSONP, XML
#
# [Federal Agency Directory API ](https://github.com/usagov/Federal-Agency-Directory-API-Documentation)
# This API contains directory information about federal agencies, such as contact methods, in English and Spanish.
# Style:  RESTful API
# Return Format:  JSON, JSONP, XML
#
# [Federal Mobile Product API](https://github.com/usagov/Federal-Mobile-Product-API-Documentation)
# This API contains native and hybrid apps, responsive sites, and mobile websites from across the government, in English and Spanish.
# Style:  RESTful API
# Return Format:  JSON, JSONP
#
# [Go.USA.gov API](https://go.usa.gov/api)
# Go.USA.gov is a URL shortener for government employees. The API can shorten, preview, and show clicks on short URLs.
# Style:  RESTful API
# Return Format:  JSON, JSONP, XML, plain text
#
# [Government Jobs API](http://search.digitalgov.gov/developer/jobs.html)
# This API returns job openings across the federal government, and includes all current openings posted on USAJobs.gov that are open to the public and located in the United States. It also includes some state and local government jobs.
# Style:  RESTful API
# Return Format:  JSON
#
# [List of Non-.gov URLs in Our Search](https://github.com/GSA/govt-urls)
# We search across all federal, state, local, tribal, and territorial government websites. Most government websites end in .gov or .mil, but many do not. This is a list of all government URLs that do not end in .gov or .mil.
# Style:  JSON, TXT file
#
# [Social Media Registry API ](https://github.com/usagov/Social-Media-Registry-API-Documentation)
# The Social Media Registry is an official source of information about federal government social media accounts.
# Style:  RESTful API
# Return Format:  HTML5, JSON, XML
#
# ## Other Developer Resources
# Here are some resources for developing with government-provided information and services:
#
# [List of developer hubs across government from 18F.](http://18f.github.io/API-All-the-X/pages/developer_hubs)
# [Data.gov](http://www.data.gov/) provides data, tools, and resources to conduct research, develop web and mobile applications, design data visualizations, and more.
#
# https://github.com/QuantGov

# %% [markdown]
# Developer Hubs
# CSV - JSON - XML - YML - [Edit]
#
# - White House
# http://www.whitehouse.gov/developers
# - Department of Agriculture
# http://www.usda.gov/developers
# - Department of Agriculture - Economic Research Service
# https://www.ers.usda.gov/developer/
# - Department of Agriculture - National Agricultural Statistics Service
# https://www.nass.usda.gov/developer/
# - Department of Commerce
# http://www.commerce.gov/developer
# - Department of Commerce - Bureau of Economic Analysis
# http://www.bea.gov/api
# - Department of Commerce - Census Bureau
# http://www.census.gov/developers/
# - Department of Commerce - International Trade Administration
# http://developer.trade.gov/
# - Department of Commerce - National Oceanic and Atmospheric Administration - National Weather Service
# http://graphical.weather.gov/xml/
# - Department of Commerce - National Oceanic and Atmospheric Administration - Center for Operational Oceanographic Products and Services
# http://tidesandcurrents.noaa.gov/api/
# - Department of Commerce - National Oceanic and Atmospheric Administration - National Climate Data Center
# http://www.ncdc.noaa.gov/cdo-web/
# - Department of Commerce - US Patent and Trademark Office
# https://developer.uspto.gov/
# - Department of Defense
# http://www.defense.gov/developer/
# - Department of Defense - Arlington National Cemetary
# http://www.arlingtoncemetery.mil/Developer/
# - Department of Education
# http://www.ed.gov/developers
# - Department of Energy
# http://www.energy.gov/developers
# - Energy Information Administration
# http://www.eia.gov/developer/
# - Argonne National Laboratory - National Environmental Policy Act
# http://nepanode.anl.gov/developer/
# - National Renewable Energy Laboratory
# http://developer.nrel.gov/
# - Office of Scientific and Technical Information
# http://www.osti.gov/XMLServices
# - Department of Health and Human Services
# http://www.hhs.gov/developer
# - Department of Health and Human Services - Centers for Medicare and Medicaid Services
# https://developer.cms.gov/
# - Department of Health and Human Services - Centers for Medicare and Medicaid Services - Quality Payment Program
# https://qpp.cms.gov/developers
# - Department of Health and Human Services - Food and Drug Administration
# http://open.fda.gov
# - Department of Health and Human Services - National Institute on Drug Abuse
# http://www.drugabuse.gov/developer
# - Department of Health and Human Services - National Institutes of Health
# https://federation.nih.gov/webServices.asp
# - Department of Health and Human Services - National Library of Medicine
# http://www.nlm.nih.gov/api/
# - Department of Health and Human Services - Substance Abuse and Mental Health Services Administration
# http://store.samhsa.gov/developer
# - Department of Homeland Security
# http://www.dhs.gov/developer
# - Federal Emergency Management Agency
# http://www.fema.gov/developer-resources
# - Department of Housing and Urban Development
# http://www.hud.gov/developer
# - Department of the Interior
# http://www.doi.gov/developer
# - Department of the Interior - National Park Service
# https://www.nps.gov/developer
# - U.S. Geological Survey
# http://data.usgs.gov/
# - Department of Justice
# http://www.justice.gov/developer
# - Bureau of Alcohol, Tobacco, Firearms, and Explosives
# https://www.atf.gov/content/About/statistics/developer
# - Bureau of Justice Statistics
# http://www.bjs.gov/developer/
# - Office of Justice Programs
# http://data.ojp.gov/developer/
# - Department of Labor
# http://developer.dol.gov/
# - Bureau of Labor Statistics
# http://www.bls.gov/developers/
# - Department of State
# http://www.state.gov/developer
# - Office of the Historian - State Department
# http://history.state.gov/developer
# - Department of Transportation
# http://www.dot.gov/developer
# - Federal Aviation Administration
# http://services.faa.gov/
# - Federal Motor Carrier Safety Administration
# http://mobile.fmcsa.dot.gov/developer
# - National Highway Traffic Safety Administration
# http://www.nhtsa.gov/webapi/Default.aspx
# - Department of the Treasury
# http://www.treasury.gov/developer
# - Department of Veterans Affairs
# http://www.va.gov/developer
# - Consumer Financial Protection Bureau
# http://www.consumerfinance.gov/developers/
# - Environmental Protection Agency
# http://www.epa.gov/developer/
# - Federal Communications Commission
# http://www.fcc.gov/developers
# - Federal Election Commission
# https://api.open.fec.gov/developers/
# - Federal Trade Commission
# https://www.ftc.gov/developer
# - Federal Reserve Bank of St. Louis
# http://api.stlouisfed.org/
# - General Services Administration
# http://www.gsa.gov/developers/
# - General Services Administration - Technology Transformation Service - Login.gov
# https://developers.login.gov/
# - General Services Administration - Code.gov
# https://developers.code.gov/
# - Government Printing Office - Govinfo.gov
# https://www.govinfo.gov/developers
# - National Aeronautics and Space Administration
# https://api.nasa.gov/
# - National Archives and Records Administration
# http://www.archives.gov/developers/
# - Federal Register
# http://www.federalregister.gov/blog/learn/developers
# - National Science Foundation
# http://nsf.gov/developer/
# - Nuclear Regulatory Commission
# http://www.nrc.gov/developer.html
# - Office of Personnel Management
# http://www.opm.gov/developer
# - Recovery Accountability and Transparency Board
# http://www.recovery.gov/arra/FAQ/Developer/Pages/default.aspx
# - Small Business Administration
# http://www.sba.gov/about-sba/sba_performance/sba_data_store/web_service_api
# - Smithsonian Institution
# https://smithsonian.github.io/api-docs/#/
# - Social Security Administration
# http://www.ssa.gov/developer
# - U.S. Agency for International Development
# http://www.usaid.gov/developer
# - Analytics.USA.gov
# https://analytics.usa.gov/developer
# - BusinessUSA
# http://business.usa.gov/apis
# - Data.gov
# http://developer.data.gov
# - Commerce - Census - MIDAAS API
# https://midaas.commerce.gov/developers/
# - DEA - E-Commerce Program
# http://www.deaecom.gov/developer.html
# - DigitalGov Search
# http://search.digitalgov.gov/developer
# - EnergyStar.gov
# https://data.energystar.gov/developers
# - Export.gov
# https://developer.export.gov
# - FCC - Mapping Broadband Health in America
# https://www.fcc.gov/health/maps/developers
# - Federal Digital System
# http://api.fdsys.gov/
# - FOIA.gov
# http://www.foia.gov/developer.html
# - ForeignAssistance.gov
# http://www.foreignassistance.gov/web/Developer.aspx
# - FuelEconomy.gov
# http://www.fueleconomy.gov/ws
# - Geoplatform.gov
# http://www.geoplatform.gov/developer-pathway
# - GlobalChange.gov
# http://data.globalchange.gov/
# - Healthcare.gov
# http://www.healthcare.gov/developers
# - HealthData.gov
# http://www.healthdata.gov/developer
# - HealthFinder.gov
# http://healthfinder.gov/developers/
# - HHS - Health Indicator Warehouse
# http://healthindicators.gov/Developers/
# - HHS - Medicare
# http://data.medicare.gov/
# - Information Sharing Environment
# http://ise.gov/developers
# - Integrated Taxonomic Information System
# http://www.itis.gov/ws_description.html
# - ITDashboard.gov
# http://www.itdashboard.gov/data_feeds
# - JobCenter
# http://jobcenter.usa.gov/apis
# - MyUSA
# http://my.usa.gov/developer/
# - National Broadband Map
# http://www.broadbandmap.gov/developer/
# - National Information Exchange Model
# http://www.niem.gov/developers
# - National Map
# http://viewer.nationalmap.gov/example/services.html
# - National Resource Directory
# http://www.nrd.gov/home/api
# - Performance.gov
# http://performance.gov/api
# - Performance.gov Permits
# http://permits.performance.gov/developers-api
# - Pillbox
# http://pillbox.nlm.nih.gov/developer.html
# - Regulations.gov
# http://www.regulations.gov/#!developers
# - Sustainable Facilities Tools
# http://sftool.gov/developers
# - Small Business Innovation Research
# http://www.sbir.gov/apis
# - TreasuryDirect.gov
# http://www.treasurydirect.gov/webapis/webapisindex.htm
# - USA.gov
# http://www.usa.gov/developer
# - USAJOBS.gov
# https://data.usajobs.gov
# - USASpending.gov
# https://api.usaspending.gov/
# - U.S. Courts - PACER
# http://www.pacer.gov/cmecf/developer/
