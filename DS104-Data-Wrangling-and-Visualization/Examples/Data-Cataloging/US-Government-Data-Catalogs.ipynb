# %% [markdown]
# # US Government Data Catalogs

# %% [markdown]
# [Catalog.data.gov](https://catalog.data.gov/dataset): This is the official data catalog for the U.S. government, and it provides access to over 250,000 datasets from various federal agencies.
#
# [USASpending.gov](https://www.usaspending.gov/): This website provides access to data on federal spending, including contracts, grants, and loans.
#
# [HealthData.gov](https://healthdata.gov/): This website provides access to health-related data from various federal agencies, including the Centers for Disease Control and Prevention (CDC) and the National Institutes of Health (NIH).
#
# [Climate.gov](https://www.climate.gov/): This website provides access to data related to climate, including maps, charts, and datasets.
#
# [Census.gov](https://www.census.gov/): This website provides access to data from the U.S. Census Bureau, including population, housing, and economic data.
#
# [Energy.gov](https://www.energy.gov/data/open-energy-data): This website provides access to data related to energy, including renewable energy, energy efficiency, and fossil fuels.
#
# [National Archives Catalog](https://catalog.archives.gov/): This website provides access to a wide range of historical and government records, including photographs, documents, and audio and video recordings.
#
# [NASA Open Data Portal](https://data.nasa.gov/): This website provides access to data related to space exploration and science, including satellite imagery, climate data, and astronaut biographies.
#
# [National Oceanic and Atmospheric Administration (NOAA) Data Catalog](https://data.noaa.gov/datasetsearch/): This website provides access to a wide range of environmental data, including weather forecasts, oceanographic data, and climate models.
#
# [Federal Reserve Economic Data (FRED)](https://fred.stlouisfed.org/): This website provides access to economic data from the Federal Reserve System, including data on employment, inflation, and interest rates.
#
# [USAFacts.org](https://usafacts.org/): This website provides access to data related to government finance and spending, including data on taxes, revenue, and government programs.
#
# [Department of Education's Ed Data Express](https://eddataexpress.ed.gov/): This website provides access to data related to education, including data on graduation rates, enrollment, and student achievement.
#
# [National Cancer Institute's Cancer Data Access System (CDAS)](https://prevention.cancer.gov/resources/cancer-data-access-system): This website provides access to data related to cancer research, including clinical trial data and cancer incidence and mortality rates.
#
# [Department of Labor's Data & Statistics](https://www.bls.gov/): This website provides access to data related to labor and employment, including data on wages, occupational safety, and workforce demographics.
#
# [National Renewable Energy Laboratory's (NREL) Open Data](https://www.nrel.gov/research/data-tools.html): This website provides access to data related to renewable energy, including data on solar, wind, and geothermal energy resources.
#
# [Department of Transportation's National Transportation Library](https://ntl.bts.gov/ntl): This website provides access to data related to transportation, including data on highways, airports, and public transportation.
#
# [National Institute of Standards and Technology (NIST) Data Gateway](https://www.nist.gov/publications/nist-data-gateway): This website provides access to data related to science and technology, including data on materials properties, energy efficiency, and atomic spectra.
#
# [National Library of Medicine's (NLM) National Center for Biotechnology Information (NCBI)](https://www.ncbi.nlm.nih.gov/): This website provides access to data related to biomedical research, including data on genetics, genomics, and clinical trials.
#
# [Department of Homeland Security's (DHS) Data & Statistics](https://www.dhs.gov/data): This website provides access to data related to homeland security, including data on immigration, border security, and disaster response.
#
# [United States Geological Survey's (USGS) Science Data Catalog](https://data.usgs.gov/datacatalog/): This website provides access to data related to natural resources, hazards, and environmental health, including data on earthquakes, volcanoes, and water resources.
#
# [Environmental Protection Agency's (EPA) Environmental Data Gateway](https://edg.epa.gov/metadata/catalog/main/home.page): This website provides access to data related to environmental quality, including data on air pollution, water quality, and toxic substances.
#
# [Department of Agriculture's (USDA) National Agricultural Library](https://www.nal.usda.gov/): This website provides access to data related to agriculture, including data on crop yields, food safety, and rural development.
#
# [Centers for Medicare & Medicaid Services (CMS) Data Navigator](https://data.cms.gov/): This website provides access to data related to healthcare, including data on hospital quality, healthcare spending, and health insurance coverage.
#
# [Department of Housing and Urban Development's (HUD) Open Data Portal](https://data.hud.gov/): This website provides access to data related to housing and urban development, including data on affordable housing, community development, and homelessness.
#
# [Department of Veterans Affairs' (VA) Open Data Portal](https://www.data.va.gov/): This website provides access to data related to veterans' health, benefits, and services, including data on veteran population demographics, healthcare utilization, and disability compensation.
#
# [Consumer Financial Protection Bureau's (CFPB) Open Data](https://www.consumerfinance.gov/data-research/): This website provides access to data related to consumer finance, including data on mortgage lending, credit card usage, and payday lending.
#
# [Bureau of Labor Statistics' (BLS) Databases, Tables & Calculators by Subject](https://www.bls.gov/data/): This website provides access to data related to labor market statistics, including data on employment, wages, and labor productivity.
#
# [Department of Commerce's International Trade Administration (ITA) Data and Analysis](https://www.trade.gov/trade-data-analysis): This website provides access to data related to international trade and investment, including data on export and import activity, trade agreements, and foreign direct investment.
#
# [National Agricultural Statistics Service's (NASS) Quick Stats](https://www.nass.usda.gov/Quick_Stats/): This website provides access to data related to agriculture and rural communities, including data on crop production, livestock inventory, and farm income.
#
# [Department of Energy's (DOE) Energy Information Administration (EIA) Open Data Portal](https://www.eia.gov/opendata/): This website provides access to data related to energy markets and use, including data on energy production and consumption, electricity generation, and petroleum prices.
#
# [National Science Foundation's (NSF) National Center for Science and Engineering Statistics (NCSES)](https://ncses.nsf.gov/explore-data): This website provides access to data related to science and engineering research and development, including data on research funding, workforce trends, and scientific publications.
#
# [National Park Service's (NPS) Data Store](https://irma.nps.gov/DataStore/): This website provides access to data related to the natural and cultural resources of the National Park System, including data on park visitation, wildlife populations, and cultural artifacts.
#
# [Department of Justice's (DOJ) Bureau of Justice Statistics (BJS)](https://bjs.ojp.gov/): This website provides access to data related to crime and justice, including data on law enforcement personnel, crime rates, and the criminal justice system.
#
# [National Highway Traffic Safety Administration's (NHTSA) Traffic Safety Fact Sheets](https://crashstats.nhtsa.dot.gov/#!/DocumentTypeList/11): This website provides access to data related to traffic safety, including data on motor vehicle crashes, fatalities, and injuries.
#
# [Department of State's Office of the Historian](https://history.state.gov/): This website provides access to data related to US diplomatic history, including data on foreign relations, international treaties, and diplomatic correspondence.
#
# [General Services Administration's (GSA) Data.gov Catalog](https://catalog.data.gov/organization/gsa-gov): This website provides access to a wide range of government data, including data on federal spending, health, education, and more.
#
# [Department of Defense's (DoD) Defense Technical Information Center (DTIC)](https://discover.dtic.mil/): This website provides access to data related to defense research and development, including data on weapons systems, military technology, and scientific research.
#
# [Department of Homeland Security's (DHS) Homeland Security Digital Library (HSDL)](https://www.hsdl.org/c/): This website provides access to data related to homeland security, including data on emergency management, cybersecurity, and border security.
#
# [National Aeronautics and Space Administration's (NASA) Earth Observing System Data and Information System (EOSDIS)](https://www.earthdata.nasa.gov/eosdis): This website provides access to data related to Earth science research, including data on climate change, atmospheric chemistry, and land use.
#
# [National Archives and Records Administration's (NARA) Archives.gov](https://www.archives.gov/): This website provides access to historical records and government documents, including data on military records, genealogy, and presidential libraries.
#
# [Department of the Interior's (DOI) Bureau of Land Management (BLM) Data Services](https://www.blm.gov/services/geospatial/GISData): This website provides access to data related to public lands and natural resources, including data on land ownership, minerals, and wildlife.
#
# [Department of Transportation's (DOT) Bureau of Transportation Statistics (BTS)](https://www.bts.gov/): This website provides access to data related to transportation, including data on air travel, freight transportation, and traffic congestion.
#
# [Environmental Protection Agency's (EPA) Enforcement and Compliance History Online (ECHO)](https://echo.epa.gov/): This website provides access to data related to environmental enforcement, including data on environmental violations, inspections, and enforcement actions.
#
# [Department of Education's (ED) Common Core of Data (CCD)](https://nces.ed.gov/ccd/): This website provides access to data related to education, including data on school districts, student enrollment, and educational expenditures.
#
# [Department of Labor's (DOL) ONET OnLine](https://www.onetonline.org/): This website provides access to data related to occupations, including data on job duties, skills, and education requirements.
#
# [Food and Drug Administration's (FDA) OpenFDA](https://open.fda.gov/): This website provides access to data related to drugs, medical devices, and food safety, including data on adverse events, product recalls, and labeling.
#
# [Department of Housing and Urban Development's (HUD) Picture of Subsidized Households](https://www.huduser.gov/portal/pdrdatas_landing.html): This website provides access to data related to affordable housing, including data on tenant demographics, housing units, and rental assistance programs.
#
# [Small Business Administration's (SBA) Office of Advocacy](https://advocacy.sba.gov/category/research/): This website provides access to data related to small business, including data on business demographics, employment, and entrepreneurship.
#
# [Department of Commerce's National Institute of Standards and Technology (NIST) Manufacturing Extension Partnership (MEP) National Network](https://www.nist.gov/mep/mep-national-network): This website provides access to data related to manufacturing, including data on productivity, innovation, and workforce development.

# %%
import pandas as pd

# %%
govdata = pd.read_clipboard()

# %%
govdata
# Out:
#                                               Catalog  \
# 0                                    Catalog.data.gov
# 1                                     USASpending.gov
# 2                                      HealthData.gov
# 3                                         Climate.gov
# 4                                          Census.gov
# 5                                          Energy.gov
# 6                           National Archives Catalog
# 7                               NASA Open Data Portal
# 8                                   NOAA Data Catalog
# 9                Federal Reserve Economic Data (FRED)
# 10                                       USAFacts.org
# 11          Department of Education's Ed Data Express
# 12  National Cancer Institute's Cancer Data Access...
# 13            Department of Labor's Data & Statistics
# 14  National Renewable Energy Laboratory's (NREL) ...
# 15  Department of Transportation's National Transp...
# ...

# %%
import pandas as pd

# create a dictionary with the data you want your dataframe to contain
data = [
    {
        'catalog_name': 'Catalog.data.gov',
        'hyperlink': 'https://catalog.data.gov/dataset',
        'info': 'Data.gov is the United States government\'s open data website. It provides access to datasets published by agencies across the federal government. Data.gov is intended to provide access to government open data to the public, achieve agency missions, drive innovation, fuel economic activity, and uphold the ideals of an open and transparent government.'
    },
    {
        'catalog_name': 'USASpending.gov',
        'hyperlink': 'https://www.usaspending.gov/',
        'info': 'This website provides access to data on federal spending, including contracts, grants, and loans.'
    },
    {
        'catalog_name': 'HealthData.gov',
        'hyperlink': 'https://healthdata.gov/',
        'info': 'This website provides access to health-related data from various federal agencies, including the Centers for Disease Control and Prevention (CDC) and the National Institutes of Health (NIH).'
    },
    {
        'catalog_name': 'Climate.gov',
        'hyperlink': 'https://www.climate.gov/',
        'info': 'This website provides access to data related to climate, including maps, charts, and datasets.'
    },
    {
        'catalog_name': 'Census.gov',
        'hyperlink': 'https://www.census.gov/',
        'info': 'This website provides access to data from the U.S. Census Bureau, including population, housing, and economic data.'
    },
    {
        'catalog_name': 'Census.gov datasets',
        'hyperlink': 'https://www.census.gov/data/datasets.html',
        'info': 'Census Datasets: Data files, for public use, with all personally identifiable information removed to ensure confidentiality. Users analyze, extract, customize and publish stats.'
    },
    {
        'catalog_name': 'Energy.gov',
        'hyperlink': 'https://www.energy.gov/data/open-energy-data',
        'info': 'This website provides access to data related to energy, including renewable energy, energy efficiency, and fossil fuels.'
    },
    {
        'catalog_name': 'National Archives Catalog',
        'hyperlink': 'https://catalog.archives.gov/',
        'info': 'This website provides access to a wide range of historical and government records, including photographs, documents, and audio and video recordings.'
    },
    {
        'catalog_name': 'NASA Open Data Portal',
        'hyperlink': 'https://data.nasa.gov/',
        'info': 'This website provides access to data related to space exploration and science, including satellite imagery, climate data, and astronaut biographies.'
    },
    {
        'catalog_name': 'National Oceanic and Atmospheric Administration (NOAA) Data Catalog',
        'hyperlink': 'https://data.noaa.gov/datasetsearch/',
        'info': 'This website provides access to a wide range of environmental data, including weather forecasts, oceanographic data, and climate models.'
    },
    {
        'catalog_name': 'Federal Reserve Economic Data (FRED)',
        'hyperlink': 'https://fred.stlouisfed.org/',
        'info': 'This website provides access to economic data from the Federal Reserve System, including data on employment, inflation, and interest rates.'
    },
    {
        'catalog_name': 'USAFacts.org',
        'hyperlink': 'https://usafacts.org/',
        'info': 'This website provides access to data related to government finance and spending, including data on taxes, revenue, and government programs.'
    },
    {
        'catalog_name': 'Department of Education\'s Ed Data Express',
        'hyperlink': 'https://eddataexpress.ed.gov/',
        'info': 'This website provides access to data related to education, including data on graduation rates, enrollment, and student achievement.'
    },
    {
        'catalog_name': 'National Cancer Institute Cancer Data Access System (CDAS)',
        'hyperlink': 'https://prevention.cancer.gov/resources/cancer-data',
        'info': 'This website provides access to data related to cancer research, including clinical trial data and cancer incidence and mortality rates.'
    },
    {
        'catalog_name': 'Department of Labor\'s Data & Statistics',
        'hyperlink': 'https://www.bls.gov/',
        'info': 'This website provides access to data related to labor and employment, including data on wages, occupational safety, and workforce demographics.'
    },
    {
        'catalog_name': 'National Renewable Energy Laboratory\'s (NREL) Open Data',
        'hyperlink': 'https://www.nrel.gov/research/data-tools.html',
        'info': 'This website provides access to data related to renewable energy, including data on solar, wind, and geothermal energy resources.'
    },
    {
        'catalog_name': 'Department of Transportation\'s National Transportation Library',
        'hyperlink': 'https://ntl.bts.gov/ntl',
        'info': 'This website provides access to data related to transportation, including data on highways, airports, and public transportation.'
    },
    {
        'catalog_name': 'National Institute of Standards and Technology (NIST) Data Gateway',
        'hyperlink': 'https://www.nist.gov/publications/nist-data-gateway',
        'info': 'This website provides access to data related to science and technology, including data on materials properties, energy efficiency, and atomic spectra.'
    },
    {
        'catalog_name': 'National Library of Medicine\'s (NLM) Finding Datasets, Data Repositories, and Data Standards',
        'hyperlink': 'https://www.nihlibrary.nih.gov/finding-datasets-data-repositories-and-data-standards',
        'info': 'This online guide contains resources for finding data repositories for data preservation and access and locating datasets for reuse. The guide was developed as an online companion for the class Resources for Finding and Sharing Research Data. '
    },
    {
        'catalog_name': 'National Library of Medicine\'s (NLM) National Center for Biotechnology Information (NCBI)',
        'hyperlink': 'https://www.ncbi.nlm.nih.gov/',
        'info': 'This website provides access to data related to biomedical research, including data on genetics, genomics, and clinical trials.'
    },
    {
        'catalog_name': 'Department of Homeland Security\'s (DHS) Data & Statistics',
        'hyperlink': 'https://www.dhs.gov/data',
        'info': 'This website provides access to data related to homeland security, including data on immigration, border security, and disaster response.'
    },
    {
        'catalog_name': 'United States Geological Survey\'s (USGS) Science Data Catalog',
        'hyperlink': 'https://data.usgs.gov/datacatalog/',
        'info': 'This website provides access to data related to natural resources, hazards, and environmental health, including data on earthquakes, volcanoes, and water resources.'
    },
    {
        'catalog_name': 'Environmental Protection Agency\'s (EPA) Environmental Data Gateway',
        'hyperlink': 'https://edg.epa.gov/metadata/catalog/main/home.page',
        'info': 'This website provides access to data related to environmental quality, including data on air pollution, water quality, and toxic substances.'
    },
    {
        'catalog_name': 'Department of Agriculture\'s (USDA) National Agricultural Library',
        'hyperlink': 'https://www.nal.usda.gov/',
        'info': 'This website provides access to data related to agriculture, including data on crop yields, food safety, and rural development.'
    },
    {
        'catalog_name': 'Centers for Medicare & Medicaid Services (CMS) Data Navigator',
        'hyperlink': 'https://data.cms.gov/',
        'info': 'This website provides access to data related to healthcare, including data on hospital quality, healthcare spending, and health insurance coverage.'
    },
    {
        'catalog_name': "Department of Housing and Urban Development\'s (HUD) Open Data Portal",
        'hyperlink': "https://data.hud.gov/",
        'info': "This website provides access to data related to housing and urban development, including data on affordable housing, community development, and homelessness."
    },
    {
        'catalog_name': "Department of Veterans Affairs\' (VA) Open Data Portal",
        'hyperlink': "https://www.data.va.gov/",
        'info': "This website provides access to data related to veterans' health, benefits, and services, including data on veteran population demographics, healthcare utilization, and disability compensation."
    },
    {
        'catalog_name': "Consumer Financial Protection Bureau\'s (CFPB) Open Data",
        'hyperlink': "https://www.consumerfinance.gov/data-research/",
        'info': "This website provides access to data related to consumer finance, including data on mortgage lending, credit card usage, and payday lending."
    },
    {
        'catalog_name': "Bureau of Labor Statistics\' (BLS) Databases, Tables & Calculators by Subject",
        'hyperlink': "https://www.bls.gov/data/",
        'info': "This website provides access to data related to labor market statistics, including data on employment, wages, and labor productivity."
    },
    {
        'catalog_name': "Department of Commerce\'s International Trade Administration (ITA) Data and Analysis",
        'hyperlink': "https://www.trade.gov/trade-data-analysis",
        'info': "This website provides access to data related to international trade and investment, including data on export and import activity, trade agreements, and foreign direct investment."
    },
    {
        'catalog_name': "National Agricultural Statistics Service\'s (NASS) Quick Stats",
        'hyperlink': "https://www.nass.usda.gov/Quick_Stats/",
        'info': "This website provides access to data related to agriculture and rural communities, including data on crop production, livestock inventory, and farm income."
    },
    {
        'catalog_name': "Department of Energy\'s (DOE) Energy Information Administration (EIA) Open Data Portal",
        'hyperlink': "https://www.eia.gov/opendata/",
        'info': "This website provides access to data related to energy markets and use, including data on energy production and consumption, electricity generation, and petroleum prices."
    },
    {
        'catalog_name': "National Science Foundation\'s (NSF) National Center for Science and Engineering Statistics (NCSES)",
        'hyperlink': "https://ncses.nsf.gov/explore-data",
        'info': "This website provides access to data related to science and engineering research and development, including data on research funding, workforce trends, and scientific publications."
    },
    {
        'catalog_name': "National Park Service\'s (NPS) Data Store",
        'hyperlink': "https://irma.nps.gov/DataStore/",
        'info': "This website provides access to data related to the natural and cultural resources of the National Park System, including data on park visitation, wildlife populations, and cultural artifacts."
    },
    {
        'catalog_name': "Department of Justice\'s (DOJ) Bureau of Justice Statistics (BJS)",
        'hyperlink': "https://bjs.ojp.gov/",
        'info': "This website provides access to data related to crime and justice, including data on law enforcement personnel, crime rates, and the criminal justice system."
    },
    {
        'catalog_name': "National Highway Traffic Safety Administration\'s (NHTSA) Traffic Safety Fact Sheets",
        'hyperlink': "https://crashstats.nhtsa.dot.gov/#!/DocumentTypeList/11",
        'info': "This website provides access to data related to traffic safety, including data on motor vehicle crashes, fatalities, and injuries."
    },
    {
        'catalog_name': "Department of State\'s Office of the Historian",
        'hyperlink': "https://history.state.gov/",
        'info': "This website provides access to data related to US diplomatic history, including data on foreign relations, international treaties, and diplomatic correspondence."
    },
    {
        'catalog_name': "General Services Administration\'s (GSA) Data.gov Catalog",
        'hyperlink': "https://catalog.data.gov/organization/gsa-gov",
        'info': "This website provides access to a wide range of government data, including data on federal spending, health, education, and more."
    },
    {
        'catalog_name': "Department of Defense\'s (DoD) Defense Technical Information Center (DTIC)",
        'hyperlink': "https://discover.dtic.mil/",
        'info': "This website provides access to data related to defense research and development, including data on weapons systems, military technology, and scientific research."
    },
    {
        'catalog_name': "Department of Homeland Security\'s (DHS) Homeland Security Digital Library (HSDL)",
        'hyperlink': "https://www.hsdl.org/c/",
        'info': "This website provides access to data related to homeland security, including data on emergency management, cybersecurity, and border security."
    },
    {
        'catalog_name': "National Aeronautics and Space Administration\'s (NASA) Earth Observing System Data and Information System (EOSDIS)",
        'hyperlink': "https://www.earthdata.nasa.gov/eosdis",
        'info': "This website provides access to data related to Earth science research, including data on climate change, atmospheric chemistry, and land use."
    },
    {
        'catalog_name': "National Archives and Records Administration\'s (NARA) Archives.gov",
        'hyperlink': "https://www.archives.gov/",
        'info': "This website provides access to historical records and government documents, including data on military records, genealogy, and presidential libraries."
    },
    {
        'catalog_name': "Department of the Interior\'s (DOI) Bureau of Land Management (BLM) Data Services",
        'hyperlink': "https://www.blm.gov/services/geospatial/GISData",
        'info': "This website provides access to data related to public lands and natural resources, including data on land ownership, minerals, and wildlife."
    },
    {
        'catalog_name': "Department of Transportation\'s (DOT) Bureau of Transportation Statistics (BTS)",
        'hyperlink': "https://www.bts.gov/",
        'info': "This website provides access to data related to transportation, including data on air travel, freight transportation, and traffic congestion."
    },
    {
        'catalog_name': "Environmental Protection Agency\'s (EPA) Enforcement and Compliance History Online (ECHO)",
        'hyperlink': "https://echo.epa.gov/",
        'info': "This website provides access to data related to environmental enforcement, including data on environmental violations, inspections, and enforcement actions."
    },
    {
        'catalog_name': "Department of Education\'s (ED) Common Core of Data (CCD)",
        'hyperlink': "https://nces.ed.gov/ccd/",
        'info': "This website provides access to data related to education, including data on school districts, student enrollment, and educational expenditures."
    },
    {
        'catalog_name': "Department of Labor\'s (DOL) ONET OnLine",
        'hyperlink': "https://www.onetonline.org/",
        'info': "This website provides access to data related to occupations, including data on job duties, skills, and education requirements."
    },
    {
        'catalog_name': "Food and Drug Administration\'s (FDA) OpenFDA",
        'hyperlink': "https://open.fda.gov/",
        'info': "This website provides access to data related to drugs, medical devices, and food safety, including data on adverse events, product recalls, and labeling."
    },
    {
        'catalog_name': "Department of Housing and Urban Development\'s (HUD) Picture of Subsidized Households",
        'hyperlink': "https://www.huduser.gov/portal/pdrdatas_landing.html",
        'info': "This website provides access to data related to affordable housing, including data on tenant demographics, housing units, and rental assistance programs."
    },
    {
        'catalog_name': "Small Business Administration\'s (SBA) Office of Advocacy",
        'hyperlink': "https://advocacy.sba.gov/category/research/",
        'info': "This website provides access to data related to small business, including data on business demographics, employment, and entrepreneurship."
    },
    {
        'catalog_name': "Department of Commerce\'s National Institute of Standards and Technology (NIST) Manufacturing Extension Partnership (MEP) National Network",
        'hyperlink': "https://www.nist.gov/mep/mep-national-network",
        'info': "This website provides access to data related to manufacturing, including data on productivity, innovation, and workforce development."
    },
    {
        'catalog_name': "Federal Emergency Management Agency (FEMA) Open Datasets",
        'hyperlink': "https://www.fema.gov/about/openfema/data-sets",
        'info': "This website is intended to be a one stop shop for OpenFEMA—FEMA’s data delivery platform which provides datasets to the public in open, industry standard, machine-readable formats. Datasets are available in multiple formats, including downloadable files and through an easily digestible Application Programming Interface (API). Each page includes information about the specific dataset, links to downloadable files, a data dictionary describing each field, and an endpoint link (if applicable for those datasets available via the API)."
    }
]

# %%
# import that data into a dataframe. Pandas makes it simple
df = pd.DataFrame(data)

# if you would like to hyperlink the URLs
#df['hyperlink'] = df['hyperlink'].apply(lambda x: f'<a href="{x}">{x}</a>')

# send to csv file
df.to_csv('government_data_catalogs.csv', index=False)

# show dataframe
df
# Out:
#                                          catalog_name  \
# 0                                    Catalog.data.gov
# 1                                     USASpending.gov
# 2                                      HealthData.gov
# 3                                         Climate.gov
# 4                                          Census.gov
# 5                                          Energy.gov
# 6                           National Archives Catalog
# 7                               NASA Open Data Portal
# 8   National Oceanic and Atmospheric Administratio...
# 9                Federal Reserve Economic Data (FRED)
# 10                                       USAFacts.org
# 11          Department of Education's Ed Data Express
# 12  National Cancer Institute Cancer Data Access S...
# 13            Department of Labor's Data & Statistics
# 14  National Renewable Energy Laboratory's (NREL) ...
# 15  Department of Transportation's National Transp...
# ...
