# %% [markdown]
# # Federal Fleet Data

# %% [markdown]
# ## Idea is to find Federal Vehicle Fleet Data
#
# We conducted a Google search and found:
#
# https://www.gsa.gov/policy-regulations/policy/vehicle-management-policy/vehicle-management-library

# %%
import pandas as pd

# %%
FFD = pd.read_excel('../Data/Federal-Fleet-Data/FY2020-FederalFleetReport.xlsx')

# %%
FFD.head()
# Out:
#   Unnamed: 0
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN

# %%
FFD
# Out:
#                              Unnamed: 0
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
# 5                                   NaN
# 6                                   NaN
# 7                                   NaN
# 8                                   NaN
# 9                                   NaN
# 10                                  NaN
# 11                                  NaN
# 12                                  NaN
# 13  FY 2020 Federal Fleet Open Data Set
# 14                                  NaN
# 15                  2021-05-25 00:00:00

# %% [markdown]
# ## Note that we didn't wrangle anything interesting

# %%
xls = pd.ExcelFile('../Data/Federal-Fleet-Data/FY2020-FederalFleetReport.xlsx')
index = pd.read_excel(xls, 'Index')

# %%
index.head()
# Out:
#                              Unnamed: 0       Unnamed: 1
# 0  FY 2020 Federal Fleet Open Data Set*              NaN
# 1                                   NaN              NaN
# 2                                   NaN              NaN
# 3                                   NaN  Index of Tables
# 4                                   NaN              NaN

# %%
index
# Out:
#                                            Unnamed: 0  \
# 0                FY 2020 Federal Fleet Open Data Set*
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 69                                         Table 5-5T
# 70                                                NaN
# 71                                                NaN
# 72                                                NaN
# 73  *This data is provided in accordance with OMB ...
#
#                                 Unnamed: 1
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                          Index of Tables
# 4                                      NaN
# ..                                     ...
# ...

# %% [markdown]
# ## can't see the data so set max options

# %%
pd.set_option('display.max_rows', 74)

# %%
index
# Out:
#                                            Unnamed: 0  \
# 0                FY 2020 Federal Fleet Open Data Set*
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                    Section 1: Overall Fleet Profile
# 6                                           Table 1-1
# 7                                                 NaN
# 8                                Section 2: Inventory
# 9                                           Table 2-1
# 10                                         Table 2-1T
# 11                                          Table 2-2
# 12                                         Table 2-2T
# 13                                          Table 2-3
# 14                                         Table 2-3T
# 15                                          Table 2-4
# ...

# %% [markdown]
# ## how do we remove the rows with NaNs?

# %%
index.dropna()
# Out:
#      Unnamed: 0                                         Unnamed: 1
# 6     Table 1-1                   Inventory, Cost, and Use Summary
# 9     Table 2-1                                Worldwide Inventory
# 10   Table 2-1T                        Worldwide Inventory by Year
# 11    Table 2-2                                    Vehicle Sources
# 12   Table 2-2T                            Vehicle Sources by Year
# 13    Table 2-3                     Domestic and Foreign Inventory
# 14   Table 2-3T             Domestic and Foreign Inventory by Year
# 15    Table 2-4                                  GSA Fleet Profile
# 16   Table 2-4T                          GSA Fleet Profile by Year
# 17    Table 2-5                                 Passenger Vehicles
# 18   Table 2-5T                         Passenger Vehicles by Year
# 19    Table 2-6                          Trucks and Other Vehicles
# 20   Table 2-6T                  Trucks and Other Vehicles by Year
# ...

# %%
# is that what we wanted? notice if we call the originial dataset we get back the same as before data
index
# Out:
#                                            Unnamed: 0  \
# 0                FY 2020 Federal Fleet Open Data Set*
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                    Section 1: Overall Fleet Profile
# 6                                           Table 1-1
# 7                                                 NaN
# 8                                Section 2: Inventory
# 9                                           Table 2-1
# 10                                         Table 2-1T
# 11                                          Table 2-2
# 12                                         Table 2-2T
# 13                                          Table 2-3
# 14                                         Table 2-3T
# 15                                          Table 2-4
# ...

# %% [markdown]
# ## Lets check out the next tab/sheets in the excel worksheet, but first lets list those sheet names

# %%
print(xls.sheet_names)
# Out:
# ['Cover Sheet', 'Index', '1-1', '2-1', '2-1T', '2-2', '2-2T', '2-3', '2-3T', '2-4', '2-4T', '2-5', '2-5T', '2-6', '2-6T', '2-7', '2-7T', '2-8', '2-8T', '2-9', '3-1', '3-1T', '3-2', '3-2T', '3-3', '3-3T', '3-4', '3-4T', '3-5', '3-5T', '3-6', '3-6T', '3-7', '3-7T', '3-8', '3-8T', '4-1', '4-1T', '4-2', '4-2T', '4-3', '4-3T', '4-4', '4-4T', '4-5', '4-5T', '4-6', '4-6T', '5-1', '5-1T', '5-2', '5-2T', '5-3', '5-3T', '5-4', '5-4T', '5-5', '5-5T']

# %%
one_one = pd.read_excel(xls, '1-1')

# %%
one_one.head()
# Out:
#    Unnamed: 0                                  Unnamed: 1 Unnamed: 2  \
# 0         NaN            Section 1: Overall Fleet Profile        NaN
# 1         NaN  Table 1-1: Inventory, Cost and Use Summary        NaN
# 2         NaN                        Department or Agency  INVENTORY
# 3         NaN                                         NaN      Owned
# 4         NaN                                         NaN        NaN
#
#   Unnamed: 3         Unnamed: 4       Unnamed: 5 Unnamed: 6 Unnamed: 7  \
# 0        NaN                NaN              NaN        NaN        NaN
# 1        NaN                NaN              NaN        NaN        NaN
# 2        NaN                NaN              NaN       COST        NaN
# 3  GSA Fleet  Commercial Leased  Total Inventory      Owned  GSA Fleet
# 4        NaN                NaN              NaN        NaN        NaN
#
#           Unnamed: 8  Unnamed: 9 Unnamed: 10 Unnamed: 11        Unnamed: 12  \
# ...

# %%
two_one = pd.read_excel(xls, '2-1')

# %%
two_one.head()
# Out:
#    Unnamed: 0                            Unnamed: 1  Unnamed: 2 Unnamed: 3  \
# 0         NaN                  Section 2: Inventory         NaN        NaN
# 1         NaN        Table 2-1: Worldwide Inventory         NaN        NaN
# 2         NaN                  Department or Agency  PASSENGER         NaN
# 3         NaN                                   NaN      LSEVs*     Sedans
# 4         NaN  American Battle Monuments Commission           0         22
#
#         Unnamed: 4 Unnamed: 5           Unnamed: 6     Unnamed: 7  \
# 0              NaN        NaN                  NaN            NaN
# 1              NaN        NaN                  NaN            NaN
# 2              NaN        NaN                  NaN         TRUCKS
# 3  Passenger\nVans       SUVs  Passenger\nSubtotal  Light\nTrucks
# 4                4          4                   30             18
#
#        Unnamed: 8     Unnamed: 9      Unnamed: 10 Unnamed: 11 Unnamed: 12  \
# ...
