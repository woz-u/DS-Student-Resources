# %% [markdown]
# # Web Scraping With Pandas
# Matthew Gerardino

# %%
# import pandas
import pandas as pd
# scrape the table and load it into a data frame in one line of code
easy = pd.read_html("https://en.wikipedia.org/wiki/List_of_S%26P_500_companies")[0]

# observe the splendor your new found power
easy.head(10)
# Out:
#   Symbol                Security SEC filings             GICS Sector  \
# 0    MMM                      3M     reports             Industrials
# 1    ABT     Abbott Laboratories     reports             Health Care
# 2   ABBV                  AbbVie     reports             Health Care
# 3   ABMD                 Abiomed     reports             Health Care
# 4    ACN               Accenture     reports  Information Technology
# 5   ATVI     Activision Blizzard     reports  Communication Services
# 6   ADBE                   Adobe     reports  Information Technology
# 7    AMD  Advanced Micro Devices     reports  Information Technology
# 8    AAP      Advance Auto Parts     reports  Consumer Discretionary
# 9    AES                AES Corp     reports               Utilities
#
#                               GICS Sub-Industry     Headquarters Location  \
# 0                      Industrial Conglomerates     Saint Paul, Minnesota
# ...

# %%
# checking Dtypes
easy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 505 entries, 0 to 504
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Symbol                 505 non-null    object
#  1   Security               505 non-null    object
#  2   SEC filings            505 non-null    object
#  3   GICS Sector            505 non-null    object
#  4   GICS Sub-Industry      505 non-null    object
#  5   Headquarters Location  505 non-null    object
#  6   Date first added       457 non-null    object
#  7   CIK                    505 non-null    int64
#  8   Founded                505 non-null    object
# dtypes: int64(1), object(8)
# memory usage: 35.6+ KB

# %%
#saving to CSV
#this should save in your Documents folder on your PC

easy.to_csv("../../../../S&P500.csv", index=False)
