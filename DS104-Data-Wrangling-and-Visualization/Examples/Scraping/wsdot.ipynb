# %%
#Let's get some data to play with. How about the Jupyter Kernels github
import webbrowser
website = 'https://wsdot.maps.arcgis.com/home/item.html?id=5f2f1a66b8fc4b6cb51b40ac28be5d8f#data'
webbrowser.open(website)
# Out:
# True

# %%
import pandas as pd

# %%
#Copy and read to get data
wsdot = pd.read_xml('../../Data/ManualCounts_AllRecords2020.xml')

# %%
wsdot.head()
# Out:
#    citation  descript  status  spdom  keywords accconst  \
# 0       NaN       NaN     NaN    NaN       NaN     None
# 1       NaN       NaN     NaN    NaN       NaN     None
# 2       NaN       NaN     NaN    NaN       NaN     None
# 3       NaN       NaN     NaN    NaN       NaN     None
# 4       NaN       NaN     NaN    NaN       NaN     None
#
#                                             useconst  ptcontac  \
# 0  For Planning use only. The Washington State De...       NaN
# 1                                               None       NaN
# 2                                               None       NaN
# 3                                               None       NaN
# 4                                               None       NaN
#
#                                    datacred  \
# 0  WSDOT - Transportation Data & GIS Office
# 1                                      None
# 2                                      None
# 3                                      None
# 4                                      None
#
#                                               native  ...  ptvctinf detailed  \
# 0  Version 6.2 (Build 9200) ; Esri ArcGIS 10.5.1....  ...       NaN      NaN
# 1                                               None  ...       NaN      NaN
# 2                                               None  ...       NaN      NaN
# 3                                               None  ...       NaN      NaN
# 4                                               None  ...       NaN      NaN
#
#    distrib                                     distliab  stdorder metd  metc  \
# 0      NaN                                         None       NaN  NaN   NaN
# 1      NaN                                         None       NaN  NaN   NaN
# 2      NaN                                         None       NaN  NaN   NaN
# 3      NaN                                         None       NaN  NaN   NaN
# 4      NaN  See access and use constraints information.       NaN  NaN   NaN
#
#    metstdn  metstdv mettc
# 0     None     None  None
# 1     None     None  None
# 2     None     None  None
# 3     None     None  None
# 4     None     None  None
#
# [5 rows x 22 columns]
