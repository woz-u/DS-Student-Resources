# %% [markdown]
# # Railroad accidents

# %%
import pandas as pd

# %%
#pd set options for computer

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
accidents = pd.read_csv("../Data/railroad-accidents-2022.csv")

# %%
accidents.head()
# Out:
#     IYR   IMO    RAILROAD  INCDTNO  IYR2 IMO2  RR2  INCDTNO2  IYR3  IMO3  \
# 22    8  KYLE  KYL169022R      NaN   NaN   UP  NaN        22     8  KYLE
# 22   10    UP   1022HL001      NaN   NaN  NaN  NaN        22    10    UP
# 22   10    UP   1022HL001      NaN   NaN  NaN  NaN        22    10    UP
# 22    8   CSX   000206783      NaN   NaN  NaN  NaN        22     8   CSX
# 22   10    UP   1022GP019      NaN   NaN  NaN  NaN        22    10    UP
#
#            RR3  INCDTNO3 DUMMY1  GXID  YEAR  MONTH  DAY  TIMEHR TIMEMIN  AMPM  \
# 22  KYL169022R       NaN    NaN    22     8     23    6      40      PM   1.0
# 22   1022HL001       NaN    NaN    22    10      2   10      45      PM   1.0
# 22   1022HL001       NaN    NaN    22    10      2   10      45      PM   1.0
# 22   000206783       NaN    NaN    22     8     20    1       8      AM   9.0
# 22   1022GP019       NaN    NaN    22    10     17    2       0      PM   1.0
#
# ...
