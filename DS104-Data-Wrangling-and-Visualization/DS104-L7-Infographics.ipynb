# %% [markdown]
# # DS104 Data Wrangling and Visualization, Lesson Seven : Infographics

# %% [markdown]
# ### Table of Contents <a class="anchor" id="DS104L7_toc"></a>
#
# * [Table of Contents](#DS104L7_toc)
#     * [Page 1 - Introduction](#DS104L7_page_1)
#     * [Page 2 - What are Infographics? ](#DS104L7_page_2)
#     * [Page 3 - Steps for Infographic Creation](#DS104L7_page_3)
#     * [Page 4 - Creating Infographics](#DS104L7_page_4)
#     * [Page 5 - Choose Design Elements](#DS104L7_page_5)
#     * [Page 6 - Color](#DS104L7_page_6)
#     * [Page 7 - What Colors Should you Use?](#DS104L7_page_7)
#     * [Page 8 - Choosing a Font](#DS104L7_page_8)
#     * [Page 9 - Sketch and Draft your Infographic](#DS104L7_page_9)
#     * [Page 10 - Finding Imagery](#DS104L7_page_10)
#     * [Page 11 - What Makes a Good Icon?](#DS104L7_page_11)
#     * [Page 12 - Infographic Creation](#DS104L7_page_12)
#     * [Page 13 - Reviewing your Product](#DS104L7_page_13)
#     * [Page 14 - Key Terms](#DS104L7_page_14)
#     * [Page 15 - Lesson 7: Infographics Hands-On](#DS104L7_page_15)

# %% [markdown]
# <hr style="height:10px;border-width:0;color:gray;background-color:gray">
#
# # Page 1 - Introduction<a class="anchor" id="DS104L7_page_1"></a>
#
# [Back to Top](#DS104L7_toc)
#
# <hr style="height:10px;border-width:0;color:gray;background-color:gray">

# %%
from IPython.display import VimeoVideo
# Tutorial Video Name: Infographics
VimeoVideo('388622180', width=720, height=480)
# Out:
#         <iframe
#             width="720"
#             height="480"
#             src="https://player.vimeo.com/video/388622180"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# The transcript for the above overview video **[is located here](https://repo.exeterlms.com/documents/V2/DataScience/Video-Transcripts/DSO104L07overview.zip)**.
#
# # Introduction
#
# In this lesson, you will learn how to create infographics, a type of visual that is used communicate information and data.  By the end of this lesson, you should be able to:
#
# * Understand what an infographic is and how it differs from a traditional visualization
# * Realize that infographic creation requires planning of the purpose, audience, and message
# * Recognize the five most common infographic layouts
# * Apply design elements such as color, font, flow, and focal point to better emphasize your message
# * Find free, high quality images to use in infographics
# * Create infographics in MS Power Point
# * Evaluate and review infographics
#
# This lesson will culminate with a hands on that requires you to create an infographic of your own based upon a World Health Organization fact sheet on diabetes.

# %% [markdown]
# <hr style="height:10px;border-width:0;color:gray;background-color:gray">
#
# # Page 2 - What are Infographics? <a class="anchor" id="DS104L7_page_2"></a>
#
# [Back to Top](#DS104L7_toc)
#
# <hr style="height:10px;border-width:0;color:gray;background-color:gray">

# %% [markdown]
# # What are Infographics?
#
# An *infographic* is simply a visual used to communicate information and/or data.  An infographic typically goes above and beyond the data visualizations you have learned in R, Python, and Tableau, since they are not tied down to the traditional chart types you have thus far encountered to deal with data. Can you use some of those traditional charts within your infographic? Absolutely! Does the entire visual revolve around a traditional chart? Absolutely not!
#
# With attention spans getting shorter and shorter, it is critical that you can convey all the important information at a glance.  Perusers of your findings should not have to undergo any intense study to understand what is going on with your data! This is true of all data visualizations, but infographics take it to the next level.  They rely on simple graphics, easy-to-read text, and enough space to make perusing the data a joy, not a chore.
#
# ---
#
# ## When to Use an Infographic
#
# You can use an infographic to do the following:
#
# * Illustrate data
# * Reduce complexity
# * Compare things
# * Raise awareness
#
# ---
#
# ## Comparing Data Visualization and Infographics
#
# Infographics are a particular type of data visualization, so they share a lot of overlap.  They both seek order, and are both meant to be informative. Further, they both can involve highly skilled people from a large number of disciplines, such as programmers, designers, statisticians, journalists, developers, geneticists, economists, and so forth. Both data visualization and infographics hopefully lead us to the still more refined state: Knowledge.
#
# However, data visualization can be created for the purposes of making sense of the data, or to change a data set into a more accessible form. Often data sets can be so massive and unwieldy that it can be almost impossible or laborious for a human to process. Therefore data visualizations are far more likely to be generated automatically through the use of algorithms or computer programs than infographics, which may use graphic design software. Infographics often contain summaries of the data, or look at things in aggregate (means, frequencies), while data visualizations are more likely to look at all the data in a chart.
#
# Because infographics typically do not include all the data, this means that they're more focused, which can be a boon.  But it also means that they are slightly more likely to inadvertently introduce bias by not presenting the whole picture.  This is not necessarily a bad thing; typically infographics are created for a specific purpose and are used for marketing or public awareness campaigns.  But it is something to be aware of as you peruse a wide variety of infographics.
#
# ---

# %% [markdown]
# <hr style="height:10px;border-width:0;color:gray;background-color:gray">
#
# # Page 3 - Steps for Infographic Creation<a class="anchor" id="DS104L7_page_3"></a>
#
# [Back to Top](#DS104L7_toc)
#
# <hr style="height:10px;border-width:0;color:gray;background-color:gray">

# %% [markdown]
# # Steps for Infographic Creation
#
# Believe it or not, there is a lot of thinking that goes into creating an infographic before you even begin drawing it up. As a general rule of thumb, you want to really have your goals in mind before you set out, or you are doomed to fail.  You need to define the purpose of your infographic, know your audience, establish your key message, and then start translating your data and findings into plain English.  Then, and only then, are you ready to start creating your actual infographic! This wonderful infographic about how to make infographics says it all (whoa, so meta!):
#
# ![Five steps to translate evaluation findings to infographics. Five circles are placed and they are labeled plan step 1, plan step 2, plan step 3, plan step 4, and create step 5. Step 1: Define your purpose. A person with an undescribed chat bubble. This part of the figure has a caption that reads, why am I creating this piece? what do I hope it will accomplish. Step 2: Two representations of a man and a woman labeled know your audience. This part of the figure has a caption that reads who is my target audience? what knowledge level do they have of the subject. Step 3: A triangular chart labeled establish your key message. This part of the figure has a caption that reads if my audience can only take one point away from my piece, what should it be? Step 4: A group of people labeled translate your data or findings. This part of the figure has a caption that reads what data or findings best support my key message? How can I communicate it in a way that is most understandable and relevant to my target audience. Step 5: Create your infographic.](Media/infographic2.jpg)
#
# As you can see, the first four steps are planning!
#
# ---
#
# ## Step 1: Define your Purpose
#
# You probably won't wake up in the middle of the night with a burning desire to create an infographic, and decide to do so in your spare time just for fun.  Instead, infographics are usually designed for a particular purpose. It may be to help with your company's marketing efforts, it may be to communicate findings to upper leadership, it may be to educate a population...whatever the reason, it is important to really hammer out why the infographic is being created.  Without a clear purpose, you are likely to spend a lot of work on something that doesn't get used much.  No one wants that!
#
# ---
#
# ## Step 2: Know your Audience
#
# Now that you know WHAT you're trying to accomplish, you need to know FOR WHOM you're doing it! Your target audience will determine the language you'll use, the images they'll recognize, and the base knowledge that you'll need to convey. If you don't have a clear picture of who you're trying to reach, you may very well fail to communicate effectively.
#
# ---
#
# ## Step 3: Establish your Message
#
# What do you absolutely need your audience to know to meet your purpose? That is your message.  You don't have much time or space - most people are just going to glance over this bad boy - so make this message a one point take-away that you are going to hit 'em over the head with!
#
#
# Magnolia Consulting provides a **[wonderful worksheet](https://magnoliaconsulting.org/wp-content/uploads/2021/05/Checklist-for-Reviewing-Infographics.pdf)** to walk through on how to create a powerful message.
#
# You are encouraged to use it to walk through the steps as needed.
#
# ---
#
# ## Step 4: Translate your Data and Findings
#
# Now that you know what you're doing, why you're doing it, and who you're doing it for, it's time to pull in the data that will back it up! An infographic is not the time to vomit data everywhere.  You will be carefully choosing only a couple metrics to highlight that back up your message and resonate with your audience, and you'll want to ensure that you're providing aggregate metrics - raw data has no place in the infographic world.
#
# ---
#
# ## Step 5: Create your Infographic
#
# The last step is to actually get to work making an infographic! You'll learn more details in the remainder of the lesson on how to actually execute this daring feat, but always remember that if you don't have the planning details down, no matter how beautiful you create your infographic, it may still end up flopping.
#
# <div class="panel panel-success">
#     <div class="panel-heading">
#         <h3 class="panel-title">Additional Info!</h3>
#     </div>
#     <div class="panel-body">
#         <p>If you would like to read the original blog where this infographic was posted, please visit <a href="https://aea365.org/blog/elissa-schloesser-on-5-steps-for-translating-evaluation-findings-into-infographics/">The American Evaluation Association 365 Blog</a>, which provides a tip a day for evaluators!</p>
#     </div>
# </div>
#
# ---

# %% [markdown]
# <hr style="height:10px;border-width:0;color:gray;background-color:gray">
#
# # Page 4 - Creating Infographics<a class="anchor" id="DS104L7_page_4"></a>
#
# [Back to Top](#DS104L7_toc)
#
# <hr style="height:10px;border-width:0;color:gray;background-color:gray">

# %% [markdown]
# # Creating Infographics
#
# Now that you've got an idea of all the planning that goes into creating an infographic, it's time to get further into the steps you'll take in actually creating one! Luckily, there is **[another infographic](https://magnoliaconsulting.org/wp-content/uploads/2021/05/10-Steps-to-Creating-an-Infographic.pdf)** that picks up where the last one left off!
#
# You'll note that the first four steps are basically what was discussed previously - you will plan out your audience, purpose, message, and potential data. Then you can hit step 5 - which brings you into the beginnings of creation, and has you pick a layout.
#
# # Infographic Layouts
#
# There are many different layouts for infographics, and you should choose the one that best conveys your message to your audience. Here are the most common five:
#
# * Hierarchy
# * Categorical
# * Comparison
# * Descriptive
# * Timeline
#
# ---
#
# ## Hierarchy
#
# The hierarchical infographic is meant to show some sort of ordered relationship or stepped process.
#
# Below is an example of a hierarchical infographic (say that five times fast!):
#
# ![Hierarchy of interface for tabletop games. An icon labeled tools, the actual components of play like character sheets, cheat sheets, boards, and bits. An icon labeled text, the actual documented rules and how they are presented including exact wording, procedures, and game terms. An icon labeled rules, the parameters of play as best recalled by the players. Less formal than text, but more formal than the basic design intent. An icon labeled intent, the assumptions of how a game would be played, often expressed directly by the designer with minimal formal documentation.](Media/infographic4.jpg)
#
# You'll notice that there is clearly an ordered relationship here, with the things on the bottom needing to come first before you can get to the things on the top. Hierarchy infographics often follow a numbered format as well, like this template:
#
# ![Four bars labeled 1 options, 2 options, 3 options, and 4 options. Each bar has a caption labeled your text.](Media/infographic5.png)
#
# Here is one more real-life example.  It's a pretty safe assumption that since this says "5 Reasons," they are listed in order of importance.
#
# ![Five reasons to visit dermatologist. The forehead of the face of a person is indicated as acne, although many people treat acne with over-the-counter products, there are times a dermatologist can help. If these types of treatment aren't working or have stopped working, you are embarrassed of your acne is causing scarring, a dermatologist can help. The skin of the nose is indicated as skin cancer, early detection of skin cancer is important and experts suggest seeing a dermatologist on an annual basis for skin cancer screenings. If you notice any changes, such as shape, sizer or color, of any moles or spots on your skin, you should see a dermatologist. The cheek of the face of the person is indicated as treatment of skin conditions, eczema is a chronic skin condition which causes flaky, itchy patches of skin. Psoriasis is a skin condition characterized by red, itchy, scaly patches on your skin. The cheek of the face is indicated as cosmetic, dermatologists can perform procedures to help with appearance. The chin part of the face is indicated expert advice, dermatologists can help you prepare a skin safety regimen, help you understand your skin type and which products would be best to use.](Media/infographic8.png)
#
# ---
#
# ## Categorical
#
# The categorical infographic is as simple as it sounds - it presents information on different categories.  Often they are subdivided in some way.  Take a look at the infographic below, which subdivides by country and has each country in a distinct box:
#
# ![A page displays work related stress, a world map, and meet the boss of the executive channel TV. Three boxes are labeled in America, in Britain, and in Spain. The first box has five chat boxes labeled 62-percent of workers say their job is their main source of stress, $ 300 estimated cost of job stress at work, 1 in 4 workers have taken a mental health day off from work to cope, 26-percent of workers say they were often or very burned out of their work, and 25-percent of workers view their job as the number one in their life. The second box has four chat boxes labeled 16.7-percent of workers say their jobs are the source of stress, 1.44-percent of workers were affected by stress at work, 11.4, working days lost due to stress, and 30.9-percent of all work sickness absence due to stress. The last box has four chat boxes labeled $ 3 estimated cost of job stress at work. 41-percent of workers self stressed, 30-percent of suicides are work related, and 35 suicides at France telecom since 2008.](Media/infographic6.png)
#
# Here is another categorical example that has the categories subdivided by a dotted line:
#
# ![A page is divided into four panels. The top panel displays a caption that reads, the logo of naval history and heritage, the naval history of Colorado, and a map depicting the location of Colorado. The second panel has the heading ships, a photo of a ship, 32 plus, and USS Colorado open bracket BB 45 close bracket. The third panel has the heading that reads, people. Three sub-headings are described in this panel. The headings are John Kerry, secretary of state, Arleigh Burke, Admiral, and Kati Garner, U S Navy's first female scuba driver. Three photos corresponding to the headings are also present. The fourth panel has the heading that reads, places. The flag of Colorado, the logo of Navy Operational Support Center Denver, and Navy Information Operations Command Colorado.](Media/infographic7.jpg)
#
# ---
#
# ## Comparison
#
# Typically, when you use a comparison layout for an infographic, you are comparing two things side-by-side.  Things can get cluttered or messy when you try to compare more than two items, so keep it simple! Below are two examples that follow the same basic format - horizontal side-by-side, though they are executed quite differently.
#
# ![Delivering a single market for services. The figure has two panels. The left panel has a funnel with the icons for engineering, construction sector, architecture, auditing, and accounting. A box labeled public services has four points described. Five icons labeled market research, tax consultancy, building, travel, and R and D are placed below the funnel. The right panel also has a funnel with the same icons on the left panel. A box labeled public services with free movement of data has five points. Twelve icons labeled tax consultancy, translation and interpretation, travel, building, market research, translation and interpretation, travel, compliance, R and D, advertisement, bridge, and R and D are placed below the funnel.](Media/infographic12.png)
#
# ![A page has a heading that reads, make activity part of your lifestyle. Instead of doing this activity, an arrow, try this activity. The page is divided into two columns and four rows. The entries are as follows. Row 1, riding the elevator or escalator three flights up three kcal, walk three flights up twenty kcal. Row 2, buy pre-sliced vegetables at store 0kcal, wash, slice, chop vegetables 20 kcal. Row 3, order fast food at drive up window three kcal, park, walk in and order food. Row 4, 1 hour of online shopping 35 kcal, 1 hour shopping at mall.](Media/infographic13.jpg)
#
# ---
#
# ## Timeline
#
# A timeline infographic shows how things have progressed over time. They can be vertical, like the one below:
#
# ![U S Soy and China. Thirty years of partnership. Timeline of accomplishments. A map depicting china, American Soybean association opens international marketing development office in China. A map depicting U S, creation of national soy checkoff helps expand and build international markets. A map depicting China, China begins importing U S soybeans. A map depicting U S, China becomes top importer of U S soybeans. A map depicting China, China approves 12th Five-year plan outlining goals for animal production and food security. A map depicting U S, China sets new record for U S soybean purchase commitments.](Media/infographic10.jpg)
#
# But they can also be horizontal, like this one:
#
# ![Geological disposal: making it happen. Three chat bubbles have captions that read, national geological screening, preparing to work with communities, and developing land-use planning processes, a circle labeled around two years. These are pointed to six circles that are labeled taking to communities providing information and investment, up to Euro 1 m in year per community involved in process, up to Euro 2.5 m a year per community, continued investment, site management, and designing and planning for a facility, 15 to 20 years. These are connected to four other circles labeled construction, operation, closure, 100 plus years.](Media/infographic17.jpg)
#
# ---
#
# ## Descriptive
#
# The descriptive infographic is probably the most common you will find.  It covers just about anything that doesn't fit in the other four categories! Anything that doesn't have a hierarchy, categories, comparisons, or a timeline will fit nicely as "descriptive." The sky is the limit as to what these descriptive infographics look like! Below are two very different examples - but both are incredibly compelling and fun to look at.
#
# ![Five fun engineering facts about mars 2020 rover. A photo of a wheel labeled showing off new wheels. This topic describes more durable, better traction, and modified shape. A photo of a rock labeled collecting cool rocks. A photo of a rover labeled hearing the sounds of mars. A photo of a robot labeled getting oxygen out of thin air. An illustration of a rover labeled landing with less drama.](Media/infographic14.png)
#
# ![A page with the title, bringing the farm to school. Growing healthy children and communities. $ 354,599,266 in school food dollars was invested in local communities in the 2011 to 2012 school year. 38, 629 schools are buying local foods for the school cafeteria. 56-percent of schools say they will buy more local food in the future. Healthy habits take root, beyond serving local foods at mealtime, schools are planting gardens, visiting farms and turning the cafeteria into a classroom. 21,008,254 students are learning to make lifelong healthy eating choices.](Media/infographic15.jpg)
#
# While there are absolutely more layouts than what is described here, hopefully these five will cover the majority of your needs.
#
# <div class="panel panel-success">
#     <div class="panel-heading">
#         <h3 class="panel-title">Additional Info!</h3>
#     </div>
#     <div class="panel-body">
#         <p>If you would like to go deeper into infographic layouts, check out <a href="https://www.easel.ly/blog/types-of-infographics/">this website</a>, which provides some additional information and examples about other layouts</p>
#     </div>
# </div>
#
# ---

# %% [markdown]
# <hr style="height:10px;border-width:0;color:gray;background-color:gray">
#
# # Page 5 - Choose Design Elements<a class="anchor" id="DS104L7_page_5"></a>
#
# [Back to Top](#DS104L7_toc)
#
# <hr style="height:10px;border-width:0;color:gray;background-color:gray">

# %% [markdown]
# # Choose Design Elements
#
# Infographics can be incredibly simple, and yet incredibly powerful! Take this one put out by NASA, for instance:
#
# ![Mars reconnaissance orbiter by the numbers. 13 years in orbit, 361 terabits of data returned, 1 Terabit of data relayed from Mars surface missions, 3 landed missions tracked during final descent, 60,000 landing site scout for 7 mars missions, 378,000 plus images taken.](Media/infographic16.jpg)
#
# A simple image in the middle, with numbers highlighted on each side, really pulls you in and makes you want to read further!
#
# There's an old saying, called "KISS," which you should apply to all your data visualizations, whether infographics or not. KISS stands for "Keep it simple, silly!" The more simple you can make your work, the easier it will be to understand and the more traction you'll get in changing the world.
#
# There are four design elements that you'll want to focus on to make your infographic pop:
#
# * Color
# * Font
# * Flow
# * Focal point
#
# You'll learn about the basic principles for each of these design elements and how to KISS them all in the upcoming pages!
#
# ---

# %% [markdown]
# <hr style="height:10px;border-width:0;color:gray;background-color:gray">
#
# # Page 6 - Color<a class="anchor" id="DS104L7_page_6"></a>
#
# [Back to Top](#DS104L7_toc)
#
# <hr style="height:10px;border-width:0;color:gray;background-color:gray">

# %% [markdown]
# # Color
#
# Before you get into using color, you should know a little bit about it.
#
# ---
#
# ## Properties of Color
#
# There are two properties of color you should be familiar with - the *hue* and the *saturation* of a color.  Hue is what you think of right away when you think of colors - red, green, blue, etc.  Saturation is how light or dark that color is; it literally is defined as how much white you have mixed in with the paint, if you were an artist.
#
# Below you have a color wheel.  As you go around the perimeter of the wheel, that is your hue.  As you go from the middle of the wheel out, that is your saturation.  The closer to the edge you get, the more highly saturated your color is.
#
# ![A circle is divided into 12 equal parts that are shaded with different colors.](Media/infographic19.png)
#
# ---
#
# ## How Computers Process Color
#
# There are two main system your computer uses to process colors - the *rgb* system or the *hex code* system. You can think of the rgb system like your print ink.  There are three base colors, a red-ish, a yellow-ish, and a blue-ish, and they can combine to make all the other colors.  The same is true in rgb.  Each color has it's own value from 0-255 that tells you how much of each color you are adding, with 0 being none, and 255 being all. A nice dusky pink, for instance, might be ```255, 153, 204```. These values go in order of the system rgb - so the 255 is for red, the 153 is for green, and the 204 is for blue.
#
# The hex code system uses a six-digit, hexadecimal number to represent color.  Again, there are three blocks of code for red, green, and blue, but instead of a number for each ranging from 0-255, there is now a number ranging from zero to FF. A hex code will always start with a #, and uses the format ```#RRGGBB```. The same dusky pink in hex code is #FF99CC.
#
# You won't need to generate these codes on your own, or even know what they mean just by looking at them, but knowing how color is represented on your computer will allow you greater control of color when you start creating your own infographics and will allow you to match colors if necessary. With over 16 million colors out there, getting back to "that one you used before" can be tricky unless you've saved the code or know how to access it!
#
# <div class="panel panel-success">
#     <div class="panel-heading">
#         <h3 class="panel-title">Additional Info!</h3>
#     </div>
#     <div class="panel-body">
#         <p>Want to go deeper into color? Check out this<a href="https://www.entrepreneur.com/article/336648">infographic on color.</a></p>
#     </div>
# </div>
#
# ---

# %% [markdown]
# <hr style="height:10px;border-width:0;color:gray;background-color:gray">
#
# # Page 7 - What Colors Should you Use?
#
# With color, the general rule of thumb is that you don't want any more than three colors or shades of the same color.  Any more than that, and you are distracting the eye and the reader will spend more time taking in your colors than your message! Generally, if you go with three colors, you want a main color, a secondary color, and a third color that is just used a little bit as an accent.  This third small accent color can be something bright and bold - you are using it sparingly, so it can be a little bit further out there.
#
# ---
#
# ## Basic Color Palettes
#
# When you start putting together different colors, they form a color palette.  There are several ways that a color palette can be built.  The basic ones are shown below:
#
# ![Four bars shaded in different colors are labeled monochromatic, analogous, complementary, and triad.](Media/infographic18.png)
#
# The first is the *monochromatic* color palette.  This uses all the same hue, but has different levels of saturation.
#
# The second is an example of an *analogous* color palette. It keeps the saturation constant, but uses different hues.
#
# The third row demonstrates the *complementary* color palette.  If you follow a traditional color wheel, then complementary colors are on the exact opposite side of the color wheel from each other.  This can look a bit jarring at first, especially if you keep the saturation up really high, like the red and green colors all the way to the left.  But if you start to bring down the saturation, like the pair all the way on the right hand side, using a complementary color palette can really look keen.
#
# The last row demonstrates the *triad* color palette.  No, you're not suddenly learning about the Chinese mafia here. The triad is when your three colors are evenly spaced out along your color wheel.
#
# If you're thinking to yourself that this is all a bit complicated, and that as a data scientist you're much more comfortable with numbers than colors, never fear! There are plenty of websites out there that provide you with ready-made color palettes you can utilize. **[Adobe Color](https://color.adobe.com/create)** is one of the better ones, and even provides you with the basic color palette options! From there, it's up to you to move around the color wheel and pick something you find visually appealing. It provides you with the hex codes for each color so you can easily replicate them in your own work.
#
# ---
#
# ## Accessibility is Key
#
# In all cases, but especially if your infographic is far-reaching or for government and non-profit organizations, you will want it to be accessible! This means that anyone who has a disability can still use and understand your work.  For websites and things, there are lots of laws about accessibility, but for infographics, the number one issue you need to be concerned with is those who are color-blind. There are two types of color blindness - red/green color blindness, in which the person can't differentiate between red and green, and blue/purple color blind, in which the person can't differentiate between blue and purple colors. Here's the traditional color-blind test:
#
# ![A circle filled with shaded small circles represents a pattern of number two.](Media/infographic20.png)
#
# If you were color-blind, you wouldn't be able to see the number two printed within the circles at all, because red and green look exactly the same! And since, in most cases, you want EVERYONE to be able to fully read and enjoy your infographic, you'll want to take this into account.  Luckily, **[Color Brewer](https://colorbrewer2.org/#type=sequential&scheme=PuBu&n=3)** has got you covered - this is a website that shows color palettes with colorblind safe options!
#
# ![A window is displayed in two panels. The left panel has a text field labeled the number of data classes and it is given as three. Next, three radio buttons are placed. The radio buttons are labeled sequential, diverging, and qualitative. Two color palates labeled multi-hue and single hue. Three checkboxes labeled colorblind safe, print friendly, and photocopy safe. Another set of checkboxes is placed. The checkboxes are labeled roads, cities, and borders. Two radio buttons are placed to select the background. The radio buttons are labeled solid color and terrain. The right panel has four tabs on top. The tabs read, how to use, updates, downloads, and credits.](Media/infographic21.png)
#
# Above is what that webpage looks like, and on the left hand side, there are check boxes for not only colorblind safe palettes, but also printer friendly and photocopy safe options! How smart is that? If you know that you are producing an infographic that will be distributed primarily in print, and not on the web, it is strongly encouraged that you choose those options, so that your colors don't end up completely washed out and your message lost with numerous photocopies!
#
# ---
#
# ## Matching Colors
#
# If you're working for a company, there's a good chance that you will not have the luxury of choosing your own color scheme, but will instead be forced into the company's color scheme or to make your color scheme fit their logo. This can be a bummer if your company has chosen their logo / webpage scheme poorly, but can be a blessing if it was properly designed.
#
# You can pull either the rgb or the hex code off ANY webpage so that you get an exact match. All you have to do is right click on the image or element, choose the ```Inspect``` option, and then look in the color section for the information. There can be a lot of info, and it can be confusing, though.  So what if there was a better way? What if you could upload an image and instantly end up with the hex codes for it? Lucky for you, **[HTML Color Codes](https://html-color-codes.info/colors-from-image/)** has your back! Simply upload a file, like your company logo, and then you'll be able to click in all the different parts and explore the hex codes!
#
# ---
# <a class="anchor" id="DS104L7_page_7"></a>
#
# [Back to Top](#DS104L7_toc)
#
# <hr style="height:10px;border-width:0;color:gray;background-color:gray">

# %% [markdown]
# # What Colors Should you Use?
#
# With color, the general rule of thumb is that you don't want any more than three colors or shades of the same color.  Any more than that, and you are distracting the eye and the reader will spend more time taking in your colors than your message! Generally, if you go with three colors, you want a main color, a secondary color, and a third color that is just used a little bit as an accent.  This third small accent color can be something bright and bold - you are using it sparingly, so it can be a little bit further out there.
#
# ---
#
# ## Basic Color Palettes
#
# When you start putting together different colors, they form a color palette.  There are several ways that a color palette can be built.  The basic ones are shown below:
#
# ![Four bars shaded in different colors are labeled monochromatic, analogous, complementary, and triad.](Media/infographic18.png)
#
# The first is the *monochromatic* color palette.  This uses all the same hue, but has different levels of saturation.
#
# The second is an example of an *analogous* color palette. It keeps the saturation constant, but uses different hues.
#
# The third row demonstrates the *complementary* color palette.  If you follow a traditional color wheel, then complementary colors are on the exact opposite side of the color wheel from each other.  This can look a bit jarring at first, especially if you keep the saturation up really high, like the red and green colors all the way to the left.  But if you start to bring down the saturation, like the pair all the way on the right hand side, using a complementary color palette can really look keen.
#
# The last row demonstrates the *triad* color palette.  No, you're not suddenly learning about the Chinese mafia here. The triad is when your three colors are evenly spaced out along your color wheel.
#
# If you're thinking to yourself that this is all a bit complicated, and that as a data scientist you're much more comfortable with numbers than colors, never fear! There are plenty of websites out there that provide you with ready-made color palettes you can utilize. **[Adobe Color](https://color.adobe.com/create)** is one of the better ones, and even provides you with the basic color palette options! From there, it's up to you to move around the color wheel and pick something you find visually appealing. It provides you with the hex codes for each color so you can easily replicate them in your own work.
#
# ---
#
# ## Accessibility is Key
#
# In all cases, but especially if your infographic is far-reaching or for government and non-profit organizations, you will want it to be accessible! This means that anyone who has a disability can still use and understand your work.  For websites and things, there are lots of laws about accessibility, but for infographics, the number one issue you need to be concerned with is those who are color-blind. There are two types of color blindness - red/green color blindness, in which the person can't differentiate between red and green, and blue/purple color blind, in which the person can't differentiate between blue and purple colors. Here's the traditional color-blind test:
#
# ![A circle filled with shaded small circles represents a pattern of number two.](Media/infographic20.png)
#
# If you were color-blind, you wouldn't be able to see the number two printed within the circles at all, because red and green look exactly the same! And since, in most cases, you want EVERYONE to be able to fully read and enjoy your infographic, you'll want to take this into account.  Luckily, **[Color Brewer](https://colorbrewer2.org/#type=sequential&scheme=PuBu&n=3)** has got you covered - this is a website that shows color palettes with colorblind safe options!
#
# ![A window is displayed in two panels. The left panel has a text field labeled the number of data classes and it is given as three. Next, three radio buttons are placed. The radio buttons are labeled sequential, diverging, and qualitative. Two color palates labeled multi-hue and single hue. Three checkboxes labeled colorblind safe, print friendly, and photocopy safe. Another set of checkboxes is placed. The checkboxes are labeled roads, cities, and borders. Two radio buttons are placed to select the background. The radio buttons are labeled solid color and terrain. The right panel has four tabs on top. The tabs read, how to use, updates, downloads, and credits.](Media/infographic21.png)
#
# Above is what that webpage looks like, and on the left hand side, there are check boxes for not only colorblind safe palettes, but also printer friendly and photocopy safe options! How smart is that? If you know that you are producing an infographic that will be distributed primarily in print, and not on the web, it is strongly encouraged that you choose those options, so that your colors don't end up completely washed out and your message lost with numerous photocopies!
#
# ---
#
# ## Matching Colors
#
# If you're working for a company, there's a good chance that you will not have the luxury of choosing your own color scheme, but will instead be forced into the company's color scheme or to make your color scheme fit their logo. This can be a bummer if your company has chosen their logo / webpage scheme poorly, but can be a blessing if it was properly designed.
#
# You can pull either the rgb or the hex code off ANY webpage so that you get an exact match. All you have to do is right click on the image or element, choose the ```Inspect``` option, and then look in the color section for the information. There can be a lot of info, and it can be confusing, though.  So what if there was a better way? What if you could upload an image and instantly end up with the hex codes for it? Lucky for you, **[HTML Color Codes](https://html-color-codes.info/colors-from-image/)** has your back! Simply upload a file, like your company logo, and then you'll be able to click in all the different parts and explore the hex codes!
#
# ---

# %% [markdown]
# <hr style="height:10px;border-width:0;color:gray;background-color:gray">
#
# # Page 8 - Choosing a Font<a class="anchor" id="DS104L7_page_8"></a>
#
# [Back to Top](#DS104L7_toc)
#
# <hr style="height:10px;border-width:0;color:gray;background-color:gray">

# %% [markdown]
# # Choosing a Font
#
# The same general rule that applies for colors applies for fonts - no more than two to three different types on an infographic! Make sure they work well with each other and are easy to read.  Have you ever had to squint to make out a weird, curly font, or something that was just too small? That is NOT what you are going for here. You can have some variety in how you use those 2-3 fonts you've chosen; for instance, you could use italics, bold, or vary the sizing to emphasize certain points, but again, don't go crazy - remember to KISS!
#
# ---
#
# # Flow
#
# The flow of an infographic is very important - you want it to draw the reader in and ensure that they are being navigated through your infographic properly.  You don't want their eyes to randomly flit around; instead you want to ensure that they move smoothly from one section to the other in the order you have decided! How do you make that happen? By controlling the flow! Use visual elements like color, sizing, and font to draw attention and then transition that attention around the page.
#
# In the below infographic, your eye immediately starts up top, with the header ```Food + Fuel```.  Then you're drawn to the middle, where you see that 80% of soy beans are eaten.  You're then drawn down to the large statistics on the bottom left, since a) they are larger and b) in the English language, you read left to right. All three of these main headers also make use of the same color brown, so you know that they are primary information.  All the secondary information, that is text heavy, is located on the right side of the page, and has a green header.
#
# ![A page has a heading that reads, food plus fuel. A passage has a heading that reads, with soybeans, we don't have to choose. 80-percent meal and 20-percent oil. 97-percent animal feed, 3-percent food products. 68-percent food, 25-percent biodiesel and bioheat, 7-percent industrial uses.](Media/infographic23.jpg)
#
# Planning where the eye will naturally travel and making the most of that space is critical to getting your message across! If you don't make use of those natural spaces, or if you're going to utilize a somewhat unusual flow, it's important to ensure that all your font, color, and sizing markers are really doing their job! You may even end up adding some markers of your own in to hit them over the head with it - actual "roadmaps" are not uncommon, as shown in the infographic below.
#
# ![Agricultural youth opportunities. Eight boxes labeled ages 9 plus membership and ages 9 plus programs, ages 14 plus membership and ages 14 plus programs, ages 18 plus membership, ages 25 plus programs, student membership, collegiate membership, post-collegiate opportunities, and alumni membership.](Media/infographic24.jpg)
#
# You may also utilize arrows or other connections to lead the reader from point to point, like this one:
#
# ![A page has a heading that reads, what does creative commons mean? A circle has a picture of a person holding a camera and it is labeled creatives. A chat bubble has a caption that reads, problem: what license?. Another circle has a caption that reads, creative commons. Four boxes labeled attributes, no derivatives, non commercial, and share alike. All four boxes are connected and point to a table labeled as result of the combination of these conditions, there are six different CC licenses. The table is represented in three columns labeled icon, short-text, and means.](Media/infographic25.jpg)
#
# A good test to ensure that your infographic flows well is to ask yourself "where does my eye hit first?" and "where does it go next?" You may find the answers to be unexpected and thus need to adjust accordingly.
#
# ---
#
# # Focal Point
#
# The focal point of your infographic is THE main message or take-away that you want readers to leave with.  You will need to utilize all your design elements such as color, size, and font to ensure that your most important information is highlighted and that readers hit upon it quickly (ideally, first). In designs where there are circular elements involved, the focal point may actually be literal - right at the center. The infographic below is a wonderful example of what a circular infographic with the focal point in the middle looks like.
#
# ![A circle is formed with four terms consumption, production, distribution, and processing. The circle is labeled community food system at the center of the circle. A few icons labeled start with farmers, get engaged, improve access, support local food economies, boost sustainability, and learn together are placed around the circle.](Media/infographic26.jpg)
#
# An example of a non-circular focal point is shown below.  You'll note that the eye starts on the left, with the title, and is drawn beautifully across the page.
#
# ![A semi-circle is placed on the left side of a page. The semi-circle labeled solar power explorers. Two lines connect a satellite. The two lines are labeled where they have come and where they will do. A box labeled going the distance NASA's juino spacecraft.](Media/infographic27.png)
#
# ---

# %% [markdown]
# <hr style="height:10px;border-width:0;color:gray;background-color:gray">
#
# # Page 9 - Sketch and Draft your Infographic<a class="anchor" id="DS104L7_page_9"></a>
#
# [Back to Top](#DS104L7_toc)
#
# <hr style="height:10px;border-width:0;color:gray;background-color:gray">

# %% [markdown]
# # Sketch and Draft your Infographic
#
# Now that you have a good idea of what your audience, purpose, message, data, layout, and design will be, it's time to hop in there and really get the party started!
#
# ---
#
# ## Sketch Ideas
#
# You will want to start by sketching out your ideas on paper if possible.  Even if you have no artist talent whatsoever, just kind of blocking things out with simple lines will help you better understand where you're headed as you reach for your computer, and thus will save you time.
#
# Once again, Mongolia Consulting has come up with a wonderful resource for you: **[The Infographic Design Workbook](https://magnoliaconsulting.org/wp-content/uploads/2019/07/Infographic-Design-Workbook_7-9-19.pdf)**. You can use it to prep all the previous steps, and it even has a place to sketch your infographic at the end.
#
# ---
#
# ## Draft Infographic
#
# Once you have a simple little sketch on paper, you can begin to create your infographic on the computer.  This does not require as much graphic design experience as you might think, and if you have none at all, you're in good company. The remainder of this lesson is geared towards infographic creation in MS Power Point, a readily available and easy to use program with which most of you have some familiarity. If you're experienced in other graphic design software, such as Adobe Illustrator or it's free compatriot, Inkscape, or even MS Publisher, feel free to use them if you wish - but know that those are not necessary for the infographic design you will embark upon today.
#
# ---
#
# ## Using MS Power Point for Infographics
#
# Although you may typically think of using MS Power Point only for slide decks, it can be used for so much more - from conference-sized posters to infographics!
#
# ---
#
# ### Change Slide Format
#
# The first thing you will want to do is to change the format of the slide to "blank." Go to the ```Home``` ribbon, select ```Layout```, and then select ```Blank```:
#
# ![A window labeled AutoSave, a toggle button, icons for save, back, and refresh are placed on the top of the window. The next bar displays nine tabs labeled file, home, insert, design, transitions, animations, slide show, review, and view. The home tab is selected. The option layout is selected and it shows six office theme layouts.](Media/infographic28.png)
#
# ---
#
# ### Change Slide Size
#
# Next, you will change the size of your "slide" to match up with a standard size of a piece of paper.  You can go to the ```Design``` ribbon, the ```Customize``` box, and then select ```Slide Size```.  Once you are there, you will want to choose the ```Custom Slide Size``` option. You can choose portrait or landscape orientation, based on the needs of your infographic, and then change the size to whatever you'd like.  In this case, you'll replicate a full size piece of paper, so you'll make the size 9.5" x 11".
#
# ![A window labeled AutoSave, a toggle button, icons for save, back, and refresh are placed on the top of the window. The next bar displays nine tabs labeled file, home, insert, design, transitions, animations, slide show, review, and view. The design tab is selected. A dialog box labeled slide size has four text fields labeled slides sized for, width, height, and number slides from. Ok and cancel buttons are placed at the bottom of the dialog box.](Media/infographic29.png)
#
# Now your slide should look like this:
#
# ![A window labeled AutoSave, a toggle button, icons for save, back, and refresh are placed on the top of the window. The next bar displays nine tabs labeled file, home, insert, design, transitions, animations, slide show, review, and view. The design tab is selected. The window displays a blank page.](Media/infographic30.png)
#
# ---
#
# ### Add Design View
#
# Next, go to the ```View``` ribbon, and under the ```Show``` section, you will want to select the checkboxes for ```Ruler```, ```Gridlines```, and ```Guides```.  This will help you get things even and symmetrical as you move forward.
#
# ![A window labeled AutoSave, a toggle button, icons for save, back, and refresh are placed on the top of the window. The next bar displays nine tabs labeled file, home, insert, design, transitions, animations, slide show, review, and view. The view tab is selected. Icons for normal is selected in the next bar. An icon labeled color is also selected.](Media/infographic31.png)
#
# ---
#
# ### Insert All the Things
#
# The basic functionality you will be using for infographics in MS Power Point are located on the ```Insert``` ribbon. Here you can add pictures, shapes, icons, text boxes, and more. Shapes can be used to build basic graphics and for sectioning off the different pieces of your infographic and helping with flow.  Pictures, often used sparingly in infographics, can nevertheless be used on occasion as a focal point.  Text boxes mean that you can place text anywhere on your infographic, and can easily change their size, shape, color, and even the background and border of the area in which the text is placed. *Icons*, great simple pictures, are the backbone of any infographic, and the latest version of MS Power Point has a wide range of them that you can utilize. Don't worry, though - even if your version of MS Power Point does not include an icon feature, you will learn about the different sources of all kinds of imagery on the next page, including icons.
#
# ---

# %% [markdown]
# <hr style="height:10px;border-width:0;color:gray;background-color:gray">
#
# # Page 10 - Finding Imagery<a class="anchor" id="DS104L7_page_10"></a>
#
# [Back to Top](#DS104L7_toc)
#
# <hr style="height:10px;border-width:0;color:gray;background-color:gray">

# %% [markdown]
# # Finding Imagery
#
# Where does the hip developing data scientist go to find free icons and pictures that are of high quality and licensed for re-use? You will learn about many different sources of stock photos, icons, and fonts below.
#
# ---
#
# ## Finding Icons with Google Images
#
# Although there are many websites with icons out there, and you will learn many of them, the first place you should check out is Google Images. There are some tricks of the trade to navigating Google Images with infographics in mind.
#
# ---
#
# ### Change Usage Settings
#
# First, it is absolutely critical that you have permission to use these images.  The last thing that you want to do is get your company in trouble with copyright law! Google has cleverly developed a button with just this problem in mind.  Click on the ```Tools``` button, then in the middle section where it says ```Usage rights```.  The most stringent, or rigorous, option here is ```Labeled for reuse with modification```.  This means you can reuse the graphic in any way you like! It can be for a business or for your own private use, and you can even change it if you see fit! After that is ```Labeled for reuse```.  This is the filter you most likely want to use if you are working for a company and don't intend to modify the image, since it will cover commercial use.  If you're doing something for personal demonstration, however, your options get a little broader - you can choose ```Labeled for noncommercial reuse with modification`` or ```Labeled for noncommercial reuse```, depending on what your needs are.  Typically, ```Labeled for reuse``` will cover most of your needs. You'll know you've activated a filter when the text for it turns blue and is shown in the toolbar.
#
# ![A browser displays the search result page for the umbrella icon. The page shows different umbrella icons. Five tabs are placed below the search bar. The tabs are labeled all, images, shopping, news, maps, and more. Six dropdown list boxes are placed after the tab and they are labeled size, color, usage rights, type, time, and more tools. The dropdown list box for usage rights shows a menu in which the option not filtered by license is selected.](Media/infographic32.png)
#
# ---
#
# ### Add the Magic Word - "Icon"
#
# Say you are looking for a nice, simple, easily recognized image of an umbrella. Type in just the word umbrella, and you get all sorts of ridiculous things, from adverts to photos to cartoons and everything in between. But add the magic word "icon" after, and you will miraculously receive images that are ready-made for infographics.  These are, as your search suggests, icons, and will bear the brunt of your infographic imagery.  They are powerhouses - easily recognized, simple in design, and understood at a glance!
#
# ---
#
# ## Other Icon Sources
#
# Although Google Images is a great resource, there are times when it won't have what you want. In those cases, your next stop should be **[The Noun Project](https://thenounproject.com/)**. The Noun Project is all icons, and they are all high quality.  The kicker is that you need to cite most of them, which can make for an unwieldy infographic if you have to keep putting reference near the image or at the bottom.
#
# **[Icon Monster](https://iconmonstr.com/)** is another good free site for icons as well.
#
# ---
#
# # Finding Stock Photos
#
# Google Images with the appropriate use permissions is another good place to find stock photos; use the same process as what you might for finding icons, but omit "icon" at the end of your search string.  As a word of warning, you'll need to carefully evaluate the quality of these photos, as they tend to be lower than some of the other sites to find stock photos.
#
# Here are some of the others that provide high-quality photos for free:
#
# * **[Pixabay](https://pixabay.com/)**
# * **[Pexels](https://www.pexels.com/)**
#
# ---

# %% [markdown]
# <hr style="height:10px;border-width:0;color:gray;background-color:gray">
#
# # Page 11 - What Makes a Good Icon?<a class="anchor" id="DS104L7_page_11"></a>
#
# [Back to Top](#DS104L7_toc)
#
# <hr style="height:10px;border-width:0;color:gray;background-color:gray">

# %% [markdown]
# # What Makes a Good Icon?
#
# A good icon is one that is:
#
# * Moderately detailed
# * Not too complex
# * Not an SVG file (if using MS Power Point)
# * High resolution
# * Lacking a watermark or other distracting markings
# * Transparent in background (ideally, though there are tricks to remove backgrounds)
# * Not humorous
#
# Here is an example of a good icon:
#
# ![An umbrella icon.](Media/infographic35.png)
#
# ---
#
# ## Transparency
#
# A note on transparency: Anything that shows with the grey and white background, like this one below, is most likely transparent, though be careful, because sometimes these images will be embedded with copyright info that stay put, and there's really no way to tell until you paste it into MS Power Point. There are plenty of icons that are transparent without the grey and white as well, though.
#
# ![An umbrella icon is placed in a box.](Media/infographic37.png)
#
# Looking at this same image once it has been downloaded (not in the Google Images arena) shows that it is, in fact, transparent:
#
# ![An umbrella icon.](Media/infographic38.png)
#
# ---
#
# ## Bad Icon - Too Simple
#
# Here is an example of an icon that is too simplistic in nature:
#
# ![The outline of an umbrella icon.](Media/infographic33.png)
#
# ---
#
# ## Bad Icon - Too Complex
#
# And here is an example of one that is too complex.  It is more like an illustration than an icon - the shading and detailed lines should tip you off.  It won't read well from far away, and when it's small, all the detail will be lost anyway, so it may be harder to understand what it is.
#
# ![An umbrella icon.](Media/infographic34.jpg)
#
# ---
#
# ## Bad Icon - Low Resolution
#
# Here is one that is not in high enough resolution. Anytime your graphic looks fuzzy to you, it will look fuzzy to everyone else as well unless shown so tiny it will be useless.
#
# ![An umbrella icon.](Media/infographic36.png)
#
# ---

# %% [markdown]
# <hr style="height:10px;border-width:0;color:gray;background-color:gray">
#
# # Page 12 - Infographic Creation<a class="anchor" id="DS104L7_page_12"></a>
#
# [Back to Top](#DS104L7_toc)
#
# <hr style="height:10px;border-width:0;color:gray;background-color:gray">

# %% [markdown]
# # Infographic Creation
#
# Now that you know where to find resources, you can pull them all together in MS Power Point. This page will go over some of the more helpful tips and tricks to make infographic creation nice and easy for you!
#
# ---
#
# ## Removing the Background
#
# Many icons are available with transparent backgrounds, so that they will blend seamlessly into any color background you have.  But what if you find one that has a white background, or any other color, for that matter? It might blend fine if you have an exact match, like below:
#
# ![A window labeled AutoSave, a toggle button, icons for save, back, and refresh are placed on the top of the window. The next bar displays nine tabs labeled file, home, insert, design, transitions, animations, slide show, review, and view. The home tab is selected. The screen displays an icon labeled secure data.](Media/infographic40.png)
#
# But when you try to put it against a different colored background, it will stick out like a sore thumb:
#
# ![A window labeled AutoSave, a toggle button, icons for save, back, and refresh are placed on the top of the window. The next bar displays nine tabs labeled file, home, insert, design, transitions, animations, slide show, review, and view. The design tab is selected and it lists a few themes. The first theme is selected and it is applied to the blank page.](Media/infographic41.png)
#
# So, you can remove the background color.  This tool isn't perfect, and it won't work in all cases, but worth a shot. All you need to do is go to the ```Picture Format``` ribbon, and look for the  ```Remove Background``` button. Once you do that, here is the result for this particular image:
#
# ![A window labeled AutoSave, a toggle button, icons for save, back, and refresh are placed on the top of the window. The next bar displays nine tabs labeled file, home, insert, design, transitions, animations, slide show, review, and view. The home tab is selected. The selected background design is applied.](Media/infographic42.png)
#
# You can see that things are a little blurry around the edge, which is not ideal. It works better for some images than others.
#
# ---
#
# ## Setting Colors Transparent
#
# If you get an icon or picture with a weird colored background that doesn't remove well using the above option, or if you have an image with a watermark across it that you'd like to remove, sometimes it's possible to remove it by setting the color to transparent. Do so by zooming all the way in to the watermark (enough so that you can easily click on it) and then click on the ```Picture Format``` ribbon.  Once there, you will want to look for the ```Color``` menu in the ```Adjust``` box, and all the way at the bottom of that menu, there is an option to ```Set Transparent Color```.
#
# ![A window labeled AutoSave, a toggle button, icons for save, back, and refresh are placed on the top of the window. The next bar displays nine tabs labeled file, home, insert, design, transitions, animations, slide show, review, view, add-ins, help, storyboarding, and picture format. The picture format tab is selected. An icon labeled color is selected and it shows four options in which set transparent color is chosen.](Media/infographic39.png)
#
# This will produce a pointer that you can use to select the color you want to make transparent. This trick will not work in all cases, but it is certainly worth a shot if you have found the perfect icon, but it's got gross grey lines across it.
#
# ---
#
# ## Changing Colors
#
# Coincidentally, the ```Picture Format``` ribbon and the ```Color``` menu is the same place where you will change colors for your icon. The possibilities are endless! You'll immediately notice that MS Power Point suggests some options for you, but if you go down to ```More Variations``` and then ```More Colors```, you have the ability to choose a custom color as well.
#
# ![A window labeled AutoSave, a toggle button, icons for save, back, and refresh are placed on the top of the window. The next bar displays nine tabs labeled file, home, insert, design, transitions, animations, slide show, review, view, add-ins, help, storyboarding, and picture format. The picture format tab is selected. An icon labeled color is selected and it shows four options in which more variations is chosen.](Media/infographic44.png)
#
# Once you click on ```More Colors```, you'll see a menu like this:
#
# ![A window labeled AutoSave, a toggle button, icons for save, back, and refresh are placed on the top of the window. The next bar displays nine tabs labeled file, home, insert, design, transitions, animations, slide show, review, view, add-ins, help, storyboarding, and picture format. The picture format tab is selected. A dialog box labeled color shows two tabs standard and custom in which the custom tab is selected. The ok and cancel buttons are placed at the right side of the dialog box.](Media/infographic43.png)
#
# You'll want to get on the ```Custom``` tab, and then you can enter in either RGB codes (default) or hex codes, which Power Point calls ``HSL```.  Regardless of the name, the values will still work just fine! Making use of these custom colors allows you to execute a color scheme you found or created online, and also allows you to match colors in logos, etc. for your company.
#
# ---
#
# ## Cropping
#
# Say you really like the image below, but you only want the center picture. You're not interested in all those people hanging off the sides.  That's easy enough to fix with cropping!
#
# Staying in the ```Picture Format``` ribbon, you can hit the ```Size``` section and the ```Crop``` section.
#
# ![A window labeled AutoSave, a toggle button, icons for save, back, and refresh are placed on the top of the window. The next bar displays nine tabs labeled file, home, insert, design, transitions, animations, slide show, review, view, add-ins, help, storyboarding, and picture format. The picture format tab is selected. An icon labeled crop is selected and it shows a list of options in which the option crop is selected.](Media/infographic45.png)
#
# This will bring up an ability to edit the sides of your image.  Simply drag them to where you want to crop your figure:
#
# ![A window labeled AutoSave, a toggle button, icons for save, back, and refresh are placed on the top of the window. The next bar displays nine tabs labeled file, home, insert, design, transitions, animations, slide show, review, view, add-ins, help, storyboarding, and picture format. The picture format tab is selected. An icon labeled crop is selected and it shows a list of options in which the option crop is selected. The picture is cropped in the screen.](Media/infographic46.png)
#
# You can do this anywhere there is a little black toggle.
#
# And the end result for this graphic looks like this:
#
# ![A window labeled AutoSave, a toggle button, icons for save, back, and refresh are placed on the top of the window. The next bar displays nine tabs labeled file, home, insert, design, transitions, animations, slide show, review, view, add-ins, help, storyboarding, and picture format. The picture format tab is selected. The screen displays a picture.](Media/infographic47.png)
#
# <div class="panel panel-danger">
#     <div class="panel-heading">
#         <h3 class="panel-title">Caution!</h3>
#     </div>
#     <div class="panel-body">
#         <p>If you end up cropping off an attribution about who made it, make sure you include it somewhere else to remain legal.</p>
#     </div>
# </div>
#
# ---
#
# ## Lining Things Up
#
# Now that you know all the different things you can do to an image, how about starting to work with more than one image or element (like a text box or shape) at a time? MS Power Point has a very handy "snap to grid" like function that allows you to easily align objects with other objects. For instance, take a look at the image down below.  These three servers were copied and pasted next to each other, but they're a little higgeldy piggeldy, and it would be nice if they would be perfectly aligned.  Simply hold down the left mouse button and drag an object around to move it, and as you do so, pay attention to the markers that appear and disappear. Just like below, you'll find lines helping guide the centering of your object as well as the alignment of your object with others on the screen.  They are now perfectly center and the same height!
#
# ![A window labeled AutoSave, a toggle button, icons for save, back, and refresh are placed on the top of the window. The next bar displays nine tabs labeled file, home, insert, design, transitions, animations, slide show, review, view, add-ins, help, storyboarding, and picture format. The picture format tab is selected. The screen displays a picture.](Media/infographic47.png)
#
# ---
#
# ## Sizing Text Boxes to Better Align
#
# Getting text boxes centered or left and right aligned can be tricky! One of the reasons is because MS Power Point creates the automatic grid snaps you learned about above from the size of the text box.  But sometimes, your text actually fills only a small part of the box, like this:
#
# ![A window labeled AutoSave, a toggle button, icons for save, back, and refresh are placed on the top of the window. The next bar displays nine tabs labeled file, home, insert, design, transitions, animations, slide show, review, view, add-ins, help, storyboarding, and picture format. The picture format tab is selected. The screen displays a picture and a box labeled data storage.](Media/infographic54.png)
#
# If you resize the box to be exactly the size of the text, you will have a much easier time getting things to align properly.
#
# ---
#
# ## Grouping Objects Together
#
# MS Power Point has a very handy feature that allows you to group objects together, so you can move them or work with them as one set, rather than as each individual element. This gets used a lot when you're using clusters of things to represent percentages or proportions, and it also gets used a lot when you're labeling images or otherwise adding text to them, and then decide to leave the label in the same relative position to the text, but want to move the whole kit and kaboodle around.
#
# Starting somewhere on the page that is not directly on top of any of the objects you wish to group, hold down your left mouse and drag so that a box covers all of the content you want to group together.  It should turn grey, so you can confirm you've got everything you want:
#
# ![A window labeled AutoSave, a toggle button, icons for save, back, and refresh are placed on the top of the window. The next bar displays nine tabs labeled file, home, insert, design, transitions, animations, slide show, review, view, add-ins, help, storyboarding, and picture format. The picture format tab is selected. The screen displays a picture and the text data storage and both are selected.](Media/infographic48.png)
#
# Then release, and you will be left with all the objects selected, like this:
#
# ![A window labeled AutoSave, a toggle button, icons for save, back, and refresh are placed on the top of the window. The next bar displays nine tabs labeled file, home, insert, design, transitions, animations, slide show, review, view, add-ins, help, storyboarding, and picture format. The picture format tab and shape format are selected. The screen displays a picture and the text data storage and both are selected.](Media/infographic49.png)
#
# You can then right click in a shared area between them, which brings up a menu.  You'll want ```Group```, and then next to that, ```Group``` again.
#
# ![A window labeled AutoSave, a toggle button, icons for save, back, and refresh are placed on the top of the window. The next bar displays nine tabs labeled file, home, insert, design, transitions, animations, slide show, review, view, add-ins, help, storyboarding, and picture format. The picture format tab and shape format are selected. The screen displays a picture and the text data storage and both are selected. The option group is selected from the right-click menu.](Media/infographic50.png)
#
# Once you do that, you'll notice that all of the objects now appear in the same large box, rather each in their own separate box:
#
# ![A window labeled AutoSave, a toggle button, icons for save, back, and refresh are placed on the top of the window. The next bar displays nine tabs labeled file, home, insert, design, transitions, animations, slide show, review, view, add-ins, help, storyboarding, and picture format. The picture format tab and shape format are selected. The screen displays a picture and the text data storage and both are selected.](Media/infographic51.png)
#
# You can now move everything around, make size, color, font changes, etc.  as one if you'd like, which is quite handy! But you can also deal with them individually indside their grouping if you have to by clicking directly on the one object:
#
# ![A window labeled AutoSave, a toggle button, icons for save, back, and refresh are placed on the top of the window. The next bar displays nine tabs labeled file, home, insert, design, transitions, animations, slide show, review, view, add-ins, help, storyboarding, and picture format. The picture format tab and shape format are selected. The screen displays a picture and the text data storage and both are selected.](Media/infographic52.png)
#
# If you no longer want your objects grouped together, you can right click on the shared, large box and then in the menu choose ```Group``` and then the option to ```Ungroup```:
#
# ![A window labeled AutoSave, a toggle button, icons for save, back, and refresh are placed on the top of the window. The next bar displays nine tabs labeled file, home, insert, design, transitions, animations, slide show, review, view, add-ins, help, storyboarding, and picture format. The picture format tab and shape format are selected. The screen displays a picture and the text data storage and both are selected. The option group is selected from the right-click menu.](Media/infographic53.png)
#
# And there you have it! Probably the single most helpful thing you will ever learn in MS Power Point.
#
# ---
#
# # Online Templates and Infographic Programs
#
# There are also some online infographic makers that may be quite helpful.  Feel free to investigate and explore any of these, if working in MS Power Point just isn't your thing:
#
# * **[Piktochart](https://piktochart.com/)**
# * **[Canva](https://www.canva.com/)**
# * **[Venngage](https://venngage.com/)**
# * **[Visme](https://www.visme.co/)**
# * **[Luicidpress](https://www.lucidpress.com/)**
#
# ---

# %% [markdown]
# <hr style="height:10px;border-width:0;color:gray;background-color:gray">
#
# # Page 13 - Reviewing your Product<a class="anchor" id="DS104L7_page_13"></a>
#
# [Back to Top](#DS104L7_toc)
#
# <hr style="height:10px;border-width:0;color:gray;background-color:gray">

# %% [markdown]
# # Reviewing your Product
#
# Now that you've created a draft of your infographic, it's time to review it and make sure it is the best it can be! Once again, Magnolia Consulting comes in with a great checklist for reviewing infographics, located **[here](https://magnoliaconsulting.org/wp-content/uploads/2017/10/Checklist-for-Reviewing-Infographics.pdf)**. Whether you use it to review your own work or another's work, it is a great resource to look over the Story, Content, Design, and Visuals.
#
# ---
#
# ## What's Wrong with these Infographics?
#
# This first infographic is very busy! In addition, you have no focal point - the word "libraries" appears three times, so where do you look? Your eye skips right over the blue text at the top, so you land in the "libraries libraries libraries" section next. As you proceed down the page, the numbers are the focal point, not what those numbers represent, so you are left confused and unsatisfied. Lastly, the image in the middle on the very bottom shows a counter-intuitive depiction, with full smileys on the right, and full frownies on the left.  Typically in our culture, you would see this in reverse, so it has the potential to confuse people greatly.
#
# ![A page displays a heading that reads, libraries are helping people to live healthier and happier lives and an icon for LOFE. The content describes that libraries provided people, reduced social isolation, 95-percent of participants strongly agreed that the project had increased their well being. The page also has three quoted texts that read, it has been the best thing I have done for my mental health and confidence, I have a reason to leave the house, and I'm more mindful to a few minutes of quiet to listen to my child playing. I don't need to control the situation, just enjoy the process with her.](Media/infographic9.jpg)
#
# This second infographic is also very busy! Although the title does serve as a better focal point, it is too text heavy, and the images are too detailed and too big.  All of this detracts from the main message.  Further, the headers for the timeline are all over the place - some are vertical, some are horizontal, some go onto two lines, they all have different colors - and it's a good idea when comparing things to keep the format consistent. While the color scheme is overall good, it includes four colors: orange, grey, black, and white. It's not all bad news, though - one of the things this infographic did well is to establish a good flow about the page.
#
# ![A page has a heading that reads how Jetstar reached 100 million passengers. The page lists a few events with the date. Nov 2003, Jetstar business case approved by the Qantas board. May 2004, Jetstar an operational launch with a flight from Newcastle to Melbourne. May 2004, we started with 700 staff, flying to 10 domestic destinations within Australia and in its first year of operations Jetstar flew 4 million passengers. Dec 2004, launch of Jetstar Asia. Dec 2005, won our first CAPA award for low cost carrier of the year. Dec 2005, first short-haul international flights to New Zealand. Nov 2006, first long-haul international flight to Bangkok. May 2007, launched Jetstar pacific in Vietnam. Jul 2007, first skytrax award for world's best low cost carrier. Jun 2009, domestic New Zealand flying commences. Dec 2009, first flights to mainland China. May 2010, reached the milestone of 50 million passengers network wide. Jun 2011, skytrax award for best low cost carrier Asia Pacific. Jul 2011, record 19 million passengers carried in 7th year of operations. Oct 2011, 10th mainland China destination announced. Mar 2012, Jetstar Hong Kong partnership announced. Jul 2012, Jetstar Japan launched. Oct 2012, we now have 7000 staff, flying to 60 destinations in 16 countries, with over 3000 flights per week.](Media/infographic11.jpg)

# %% [markdown]
# <hr style="height:10px;border-width:0;color:gray;background-color:gray">
#
# # Page 14 - Key Terms<a class="anchor" id="DS104L7_page_14"></a>
#
# [Back to Top](#DS104L7_toc)
#
# <hr style="height:10px;border-width:0;color:gray;background-color:gray">

# %% [markdown]
# # Key Terms
#
# Below is a list and short description of the important keywords learned in this lesson. Please read through and go back and review any concepts you do not fully understand. Great Work!
#
# <table class="table table-striped">
#     <tr>
#         <th>Keyword</th>
#         <th>Description</th>
#     </tr>
#     <tr>
#         <td style="font-weight: bold;" nowrap>Infographic</td>
#         <td>A visual used to communicate information or data.</td>
#     </tr>
#     <tr>
#         <td style="font-weight: bold;" nowrap>Hierarchy Layout</td>
#         <td>An infographic layout used to convey order or processes.</td>
#     </tr>
#     <tr>
#         <td style="font-weight: bold;" nowrap>Categorical Layout</td>
#         <td>An infographic layout used to examine different groups.</td>
#     </tr>
#     <tr>
#         <td style="font-weight: bold;" nowrap>Comparison Layout</td>
#         <td>An infographic layout used to compare two things.</td>
#     </tr>
#     <tr>
#         <td style="font-weight: bold;" nowrap>Descriptive Layout</td>
#         <td>An infographic layout used to describe data or situations.</td>
#     </tr>
#     <tr>
#         <td style="font-weight: bold;" nowrap>Timeline Layout</td>
#         <td>An infographic layout used to show change over time.</td>
#     </tr>
#     <tr>
#         <td style="font-weight: bold;" nowrap>Hue</td>
#         <td>A property of color that distinguishes them from each other (red from green, etc.).</td>
#     </tr>
#     <tr>
#         <td style="font-weight: bold;" nowrap>Saturation</td>
#         <td>How light or dark a color is.</td>
#     </tr>
#     <tr>
#         <td style="font-weight: bold;" nowrap>rgb System</td>
#         <td>A method for computers to represent color in which values for red, green, and blue range from 0-255.</td>
#     </tr>
#     <tr>
#         <td style="font-weight: bold;" nowrap>Hex Codes</td>
#         <td>A method for computers to represent color in which values for red, green and blue go from 0-FF.</td>
#     </tr>
#     <tr>
#         <td style="font-weight: bold;" nowrap>Monochromatic Palette</td>
#         <td>Colors all use the same hue, but have different levels of saturation.</td>
#     </tr>
#     <tr>
#         <td style="font-weight: bold;" nowrap>Analogous Palette</td>
#         <td>Colors all have the same saturation, but use different hues.</td>
#     </tr>
#     <tr>
#         <td style="font-weight: bold;" nowrap>Complementary Palette</td>
#         <td>Colors are on the opposite side of the color wheel from each other.</td>
#     </tr>
#     <tr>
#         <td style="font-weight: bold;" nowrap>Triad Palette</td>
#         <td>Colors are evenly spaced on the color wheel.</td>
#     </tr>
#     <tr>
#         <td style="font-weight: bold;" nowrap>Flow</td>
#         <td>How your eye moves across the page for an infographic.</td>
#     </tr>
#     <tr>
#         <td style="font-weight: bold;" nowrap>Focal Point</td>
#         <td>What your eye lands on first when looking at an infographic; should contain your main message.</td>
#     </tr>
#     <tr>
#         <td style="font-weight: bold;" nowrap>Icon</td>
#         <td>Simple pictures that convey things at a glance.</td>
#     </tr>
#     <tr>
#         <td style="font-weight: bold;" nowrap>Usage Settings</td>
#         <td>A setting in Google Images that allows you to filter results based on copyright information.</td>
#     </tr>
# </table>

# %% [markdown]
# <hr style="height:10px;border-width:0;color:gray;background-color:gray">
#
# # Page 15 - Lesson 7 Hands-On<a class="anchor" id="DS104L7_page_15"></a>
#
# [Back to Top](#DS104L7_toc)
#
# <hr style="height:10px;border-width:0;color:gray;background-color:gray">

# %% [markdown]
# For your Lesson 7 Hands-On, you will create an infographic from World Health Organization Fact Sheet data. This Hands-On will **not** be graded, but you are encouraged to complete it. The best way to become a great data scientist is to practice! When you are done, please submit one document with all of your findings for grading.
#
# <div class="panel panel-danger">
#     <div class="panel-heading">
#         <h3 class="panel-title">Caution!</h3>
#     </div>
#     <div class="panel-body">
#         <p>Do not submit your project until you have completed all requirements, as you will not be able to resubmit.</p>
#     </div>
# </div>
#
# <div class="panel panel-success">
#     <div class="panel-heading">
#         <h3 class="panel-title">Additional Info!</h3>
#     </div>
#     <div class="panel-body">
#         <p>You may want to watch <a href="https://vimeo.com/459412103">this recorded live workshop on infographics </a> before beginning the hands-on. </a> </p>
#     </div>
# </div
#
# ---
#
# ## Requirements
#
# Using the data from **[this World Health Organization fact sheet on diabetes](https://www.who.int/news-room/fact-sheets/detail/diabetes)** create an infographic. You do not need to utilize all the information provided; just ensure that you follow the steps of infographic creation to determine your own purpose, audience, and message before starting! Make sure to focus on the data elements as much as possible, and your infographic should be **just one page.**
#
# You can use any program you like - MS Power Point or equivalents such as Keynote or Open Office; any of the online infographic designs if you're feeling froggy (ready to take a leap!), or any other graphic design software with which you may be familiar. Ensure that you utilize an appropriate layout and design elements.
#
# You will be graded using **[this checklist](https://magnoliaconsulting.org/wp-content/uploads/2021/05/Checklist-for-Reviewing-Infographics.pdf)** for reviewing infographics, so ensure you run your creation through this review before you turn it in.  Above all, your infographic should be easy to read at a glance, convey a message, and be compelling.
#
# <div class="panel panel-danger">
#     <div class="panel-heading">
#         <h3 class="panel-title">Caution!</h3>
#     </div>
#     <div class="panel-body">
#         <p>Be sure to zip and submit your entire directory when finished!</p>
#     </div>
# </div>
