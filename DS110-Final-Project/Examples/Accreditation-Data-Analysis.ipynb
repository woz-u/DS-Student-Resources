# %% [markdown]
# # Accreditation Data Analysis

# %%
import pandas as pd

# %%
df = pd.read_csv('../Data/DAPIPData/AccreditationActions.csv')

# %%
df
# Out:
#        DapipId  AgencyId                                         AgencyName  \
# 0       117016        27  Academy of Nutrition and Dietetics, Accreditat...
# 1       117016        27  Academy of Nutrition and Dietetics, Accreditat...
# 2       117016        27  Academy of Nutrition and Dietetics, Accreditat...
# 3       123323        27  Academy of Nutrition and Dietetics, Accreditat...
# 4       123323        27  Academy of Nutrition and Dietetics, Accreditat...
# ...        ...       ...                                                ...
# 39388   150747         8  Western Association of Schools and Colleges, A...
# 39389   150747         8  Western Association of Schools and Colleges, A...
# 39390   151607         8  Western Association of Schools and Colleges, A...
# 39391   150738         8  Western Association of Schools and Colleges, A...
# 39392   150738         8  Western Association of Schools and Colleges, A...
#
# ...

# %%
df2 = pd.read_csv('../Data/DAPIPData/InstitutionCampus.csv')

# %%
df2
# Out:
#          DapipId     OpeId IpedsUnitIds  \
# 0         100016  01230800       100636
# 1      100016002       NaN          NaN
# 2         100025  00100200       100654
# 3         100034  00105200       100663
# 4      100034002       NaN          NaN
# ...          ...       ...          ...
# 33552     252944       NaN          NaN
# 33553     252953       NaN          NaN
# 33554     252962       NaN          NaN
# 33555     252971       NaN          NaN
# 33556     252980       NaN          NaN
#
#                                             LocationName  \
# 0                     Community College of the Air Force
# 1                     Community College of the Air Force
# 2                               Alabama A & M University
# 3                    University of Alabama at Birmingham
# 4                                UAB School of Optometry
# ...                                                  ...
# 33552  Naval Safety and Enviromental Training Center ...
# ...
