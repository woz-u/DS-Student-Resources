# %%
import pandas as pd

# %%
FPsteam = pd.read_csv('../Data/FPsteam.csv')

# %%
FPsteam.head()
# Out:
#    appid                       name release_date  english         developer  \
# 0   10.0             Counter-Strike    11/1/2000      1.0             Valve
# 1   20.0      Team Fortress Classic     4/1/1999      1.0             Valve
# 2   30.0              Day of Defeat     5/1/2003      1.0             Valve
# 3   40.0         Deathmatch Classic     6/1/2001      1.0             Valve
# 4   50.0  Half-Life: Opposing Force    11/1/1999      1.0  Gearbox Software
#
#   publisher          platforms  required_age  \
# 0     Valve  windows;mac;linux           0.0
# 1     Valve  windows;mac;linux           0.0
# 2     Valve  windows;mac;linux           0.0
# 3     Valve  windows;mac;linux           0.0
# 4     Valve  windows;mac;linux           0.0
#
#                                           categories  genres  \
# 0  Multi-player;Online Multi-Player;Local Multi-P...  Action
# 1  Multi-player;Online Multi-Player;Local Multi-P...  Action
# ...
