# %%
import pandas as pd

# %%
Hulu = pd.read_csv("../Data/HuluRaw.csv")

# %%
Hulu.head(1)
# Out:
#    HuluRaw       Unnamed: 1           Unnamed: 2        Unnamed: 3  \
# 0  show/id  show/cache_time  show/canonical_name  show/clips_count
#
#          Unnamed: 4           Unnamed: 5                Unnamed: 6  \
# 0  show/description  show/episodes_count  show/feature_films_count
#
#               Unnamed: 7  Unnamed: 8   Unnamed: 9  ...  \
# 0  show/film_clips_count  show/genre  show/genres  ...
#
#                                    Unnamed: 172  \
# 0  show/show_rollups/showtime/html5_games_count
#
#                                         Unnamed: 173  \
# 0  show/show_rollups/showtime/html5_feature_films...
#
#                                         Unnamed: 174  \
# 0  show/show_rollups/showtime/html5_film_clips_count
#
#                                         Unnamed: 175  \
# 0  show/show_rollups/showtime/html5_film_trailers...
#
#                                     Unnamed: 176  \
# 0  show/show_rollups/showtime/html5_videos_count
#
# ...

# %%
Hulu.columns = Hulu.iloc[0]
Hulu = Hulu[1:]

# %%
Hulu.head(1)

# %%
Hulu.columns
# Out:
# Index([                                             'show/id',
#                                             'show/cache_time',
#                                         'show/canonical_name',
#                                            'show/clips_count',
#                                            'show/description',
#                                         'show/episodes_count',
#                                    'show/feature_films_count',
#                                       'show/film_clips_count',
#                                                  'show/genre',
#                                                 'show/genres',
#        ...
#                'show/show_rollups/showtime/html5_games_count',
#        'show/show_rollups/showtime/html5_feature_films_count',
#           'show/show_rollups/showtime/html5_film_clips_count',
#        'show/show_rollups/showtime/html5_film_trailers_count',
#               'show/show_rollups/showtime/html5_videos_count',
# ...

# %%
pd.set_option('display.max_columns', None)

# %%
Hulu.head(1)
# Out:
# 0 show/id            show/cache_time show/canonical_name show/clips_count  \
# 1      54  2017-08-10T14:53:04+00:00          family-guy              288
#
# 0                                   show/description show/episodes_count  \
# 1  The adventures of an endearingly ignorant dad ...                 288
#
# 0 show/feature_films_count show/film_clips_count              show/genre  \
# 1                        0                     0  Animation and Cartoons
#
# 0                                        show/genres show/is_movie  \
# 1  Animation and Cartoons~Primetime Animation|Tee...         FALSE
#
# 0 show/is_showtime_only show/is_subscriber_only  \
# 1                 FALSE                   FALSE
#
# 0                              show/link_description   show/name show/rating  \
# 1  For insider news, photos, and more visit the o...  Family Guy  4.35370739
#
# 0 show/seasons_count show/series_id  \
# 1                 15          11730
#
# ...
