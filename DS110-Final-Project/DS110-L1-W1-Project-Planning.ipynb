# %% [markdown]
# # DS110 Final Project : Lesson One Week One Project Planning

# %% [markdown]
# ### Table of Contents <a class="anchor" id="DS110L1_toc"></a>
#
# * [Table of Contents](#DS110L1_toc)
#     * [Page 1 - Introduction](#DS110L1_page_1)
#     * [Page 2 - Work Cycle of a Data Scientist](#DS110L1_page_2)
#     * [Page 3 - Minimum Project Requirements](#DS110L1_page_3)
#     * [Page 4 - Group Communication](#DS110L1_page_4)
#     * [Page 5 - Get to Know your Team](#DS110L1_page_5)
#     * [Page 6 - Group Organization](#DS110L1_page_6)
#     * [Page 7 - Group Meetings](#DS110L1_page_7)
#     * [Page 8 - Kanban Board](#DS110L1_page_8)
#     * [Page 9 - Time Management](#DS110L1_page_9)
#     * [Page 10 - Project Planning](#DS110L1_page_10)
#     * [Page 11 - Choosing a Topic](#DS110L1_page_11)
#     * [Page 12 - Choosing your Data](#DS110L1_page_12)
#     * [Page 13 - Submit your Data](#DS110L1_page_13)
#     * [Page 14 - Choosing your Evaluation Questions](#DS110L1_page_14)
#     * [Page 15 - Choosing your Analyses](#DS110L1_page_15)
#     * [Page 16 - Choosing your Questions and Analyses](#DS110L1_page_16)
#     * [Page 17 - Determine the Best Language to Use](#DS110L1_page_17)
#     * [Page 18 - Project Proposal](#DS110L1_page_18)
#     * [Page 19 - Project Proposal and Requirements](#DS110L1_page_19)

# %% [markdown]
# <hr style="height:10px;border-width:0;color:gray;background-color:gray">
#
# # Page 1 - Introduction<a class="anchor" id="DS110L1_page_1"></a>
#
# [Back to Top](#DS110L1_toc)
#
# <hr style="height:10px;border-width:0;color:gray;background-color:gray">

# %%
from IPython.display import VimeoVideo
# Tutorial Video Name: Week 1 Project Planning
VimeoVideo('388139103', width=720, height=480)
# Out:
#         <iframe
#             width="720"
#             height="480"
#             src="https://player.vimeo.com/video/388139103"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# The transcript for the above overview video **[is located here](https://repo.exeterlms.com/documents/V2/DataScience/Video-Transcripts/DSO110L01overview.zip)**.
#
# # Introduction
#
# Congratulations on reaching the group project phase! You are in the home stretch now of your journey to being a data scientist. It's time to put everything you have learned so far into practice as part of an application that will serve as the centerpiece of your portfolio.
#
# The group project is intended to be done as a group.  However, if there are no other students at the point of beginning the group project, you may do an individual project.  All of the instructions below are written as though you are working on the project as a group, so if you are doing an individual project you will need to make modifications to the instructions.
#
# <div class="panel panel-danger">
#     <div class="panel-heading">
#         <h3 class="panel-title">Caution!</h3>
#     </div>
#     <div class="panel-body">
#         <p>Remember, you still need to make attendance by logging in at least four times a week for fifteen minutes in this module! You will also still have graded hands-on assignments, and if you do not complete them as you go along, you will not pass. </p>
#     </div>
# </div>
#
# This lesson will assist you in the planning of your project.  First, you will learn some about how to work in a group and manage your project, and then you'll dive right into picking a project and planning it!
#
# You will tackle the first five things on your "to do" list for this project, which mainly involve getting your head on straight and getting organized! By the end of this lesson, and the end of week one of your final project, you should have:
#
# * Created a Kanban board on Trello
# * Decided upon a topic
# * Found data on that topic
# * Determined at least two questions that you can answer using the data you have chosen
# * Chosen your analyses

# %% [markdown]
# <hr style="height:10px;border-width:0;color:gray;background-color:gray">
#
# # Page 2 - Work Cycle of a Data Scientist<a class="anchor" id="DS110L1_page_2"></a>
#
# [Back to Top](#DS110L1_toc)
#
# <hr style="height:10px;border-width:0;color:gray;background-color:gray">

# %% [markdown]
# This group project is designed to mimic real life as a data scientist.
#
# <div class="panel panel-success">
#     <div class="panel-heading">
#         <h3 class="panel-title">Additional Info!</h3>
#     </div>
#     <div class="panel-body">
#         <p>You may want to watch this <a href="https://vimeo.com/463278627"> recorded live workshop that gives you an introduction to final project. </a> </p>
#     </div>
# </div>
#
# ---
#
# # Work Cycle of a Data Scientist
#
# The typical work cycle of a data scientist goes something like this:
#
# -  Talk to the process owners and try to gain some clarity on the data: where it comes from, how it is generated, are there any knobs or dials that can be turned to change the outcome, etc.
# -  Explore, clean up, and wrangle the data to better understand it. This can include performing some simple visualizations to better understand the data and determining which variables make sense as independent versus dependent variables.
# -  Return to the data owner and present findings.  This provides an opportunity to learn more about the data, discuss key findings, and do a preliminary presentation.  This almost always leads to more questions from the data owner, more ideas about where to go next, and even more data that might not have been available earlier or might not have seemed important to the process owner at the time.
#
# After that, it is wash, rinse, repeat.  In theory, projects like this could go on for the rest of your career, but in all likelihood, your company will not want to lose you to a single data set for the rest of time.  The big exception to this is if you are doing research - in this case, you could literally spend 20 years or more focusing on a single data set.
#
# Statistical analysis is an iterative process.  It is very unusual for someone to bring you a pristine data set and ask for one simple analysis. The reality is that you usually have some freedom to explore the data, and go where your nose leads you.  You might end up going down a bunch of rabbit holes that produce no results, but this, too, is part of the job. As a data scientist, you have a chance to utilize both your creativity and your curiosity.
#
# ---
#
# # How Does this Apply to You?
#
# You and your team will be both the process owner and the data scientist in this project! This means that you will be in charge of finding the data, directing yourselves to analyze data, and the iterative process involved.
#
# Here is a basic overview of the steps you will take in your final project:
#
# * Decide on a topic.  Your world is wide open, so pick something that interests you, either personally or professionally.
# * Find data on that topic.
# * Determine at least two questions that you can answer using the data you have chosen.
# * Choose your analyses.  What statistical or machine learning techniques will you use to answer your questions?
# * Understand the requirements for that analysis.  What data will you need? What wrangling needs to be done in order to complete the analysis?
# * Wrangle your data.
# * Analyze your data.
# * Visualize your data and the analyses you did with it.
# * Build your presentation.
# * Practice your presentation.
# * Give your presentation and graduate with pride!
#
# Each week, you will be provided with the general steps you will need to take to stay on track for a six-week final project.  It will be up to you to determine the specifics for your particular project, however, which is all part of the learning process.
#
# ---

# %% [markdown]
# <hr style="height:10px;border-width:0;color:gray;background-color:gray">
#
# # Page 3 - Minimum Project Requirements<a class="anchor" id="DS110L1_page_3"></a>
#
# [Back to Top](#DS110L1_toc)
#
# <hr style="height:10px;border-width:0;color:gray;background-color:gray">

# %% [markdown]
# # Minimum Project Requirements
#
# Although you will have the latitude to choose whatever data you would like, and you will choose your own questions to explore with the data, there are some minimum technical requirements your project must have:
#
# * Data analysis in R and/or Python
# * Github Repository (information included later on this)
# * Formulation and answering of at least two evaluation questions
# * At least two statistical or machine learning techniques
#
# ---

# %% [markdown]
# <hr style="height:10px;border-width:0;color:gray;background-color:gray">
#
# # Page 4 - Group Communication<a class="anchor" id="DS110L1_page_4"></a>
#
# [Back to Top](#DS110L1_toc)
#
# <hr style="height:10px;border-width:0;color:gray;background-color:gray">

# %% [markdown]
# #  Group Communication
#
# Good communication within your team is vital to your success.  Your instructor is _not_ in charge of communication within your group.  **YOU ARE.**  That means you must take an active role in talking with the rest of your team to work on the necessary steps in completing this course.
#
# There are several ways to stay in touch with your fellow workers.
#
# * **[Zoom](https://exeterlms.zoom.us)**
# * **[Slack](https://woz-u.slack.com)**
# * Email
# * Text
# * Phone
#
# **Zoom** is a great way to conduct meetings with video and audio.  Face to face and verbal communication is the best way to discuss your project.
#
# **Slack** is also another great way to stay in contact with your fellow workers.  You can establish a channel to communicate asynchronously (at different times) with everyone in your group.  Slack can also notify you when there is a message intended for you which can help you stay on top of what you need to know.
#
# Email, text, and phone are all possible ways to stay in communication with your team but are not as effective as face to face communication or real time chatting with the group.  They should be done sparingly and only if other systems are not readily available.
#
# <div class="panel panel-info">
#     <div class="panel-heading">
#         <h3 class="panel-title">Tip!</h3>
#     </div>
#     <div class="panel-body">
#         <p>If you want to call, email, or text, make sure you exchange personal contact information with your teammates! Your instructor cannot legally give out your contact information to others.</p>
#     </div>
# </div>
#
#
# ---
#
# ## Video Conferencing
#
# Good communication within the team is vital to their success. Each student should sign up for a **[Zoom account](https://exeterlms.zoom.us)**, which will allow virtual meetings and chat for the group.  You should be holding a virtual meeting at least once a week, if not once a day.  Zoom is free for you to use and should be taken advantage of as often as possible.
#
# There are other video conference applications your team could utilize such as **[Join.me](https://join.me)**, **[Appear.in](https://appear.in)**, and Slack.
#
# ---
#
# ## Slack
#
# Your team should establish a channel to stay connected with one another.  To create a new private channel simply click on the plus sign next to the Channels header:
#
# ![New Slack Channel](Media/SlackCreateNewChannel.png)
#
# The next screen you see is for information about the private channel you want to create.  Here is where you give your channel a name, description, and add the members of your team to the channel.
#
# ![New Slack Channel Inputs](Media/SlackNewChannelInputs.png)
#
# Once you have created this channel you and your teammates can stay in contact with each other.  You can also start video calls by clicking on the phone icon at the top of the channel screen.
#
# ![Start Slack Call](Media/StartSlackCall.png)
#
# ---

# %% [markdown]
# <hr style="height:10px;border-width:0;color:gray;background-color:gray">
#
# # Page 5 - Get to Know your Team<a class="anchor" id="DS110L1_page_5"></a>
#
# [Back to Top](#DS110L1_toc)
#
# <hr style="height:10px;border-width:0;color:gray;background-color:gray">

# %% [markdown]
# # Get to Know your Team
#
# Since you'll be working closely with each other for the next six weeks, it is important that you get to know your team. A good team works together well because they understand each others' strengths, weaknesses, and motivations.
#
# <div class="panel panel-danger">
#     <div class="panel-heading">
#         <h3 class="panel-title">Caution!</h3>
#     </div>
#     <div class="panel-body">
#         <p>Do not submit your project until you have completed all requirements, as you will not be able to resubmit.</p>
#     </div>
# </div>
#
# Please submit a document answering each question for every team member you have:
#
# * What does this team member consider his or her strengths?
# * What does this team member consider his or her weaknesses?
# * How does this team member feel he or she works best? This could be anything from the time of day he or she likes to work to the type of work he or she likes to do, the resources he or she frequently utilizes, or even the best way to communicate with him or her.
# * How would the team member like to receive feedback? In an ideal world, feedback would be primarily good - everyone is tackling their assigned tasks with aplomb. But sometimes, things don't run as smoothly. Having a plan in place ahead of time to have these hard conversations is smart!
#
# <div class="panel panel-danger">
#     <div class="panel-heading">
#         <h3 class="panel-title">Caution!</h3>
#     </div>
#     <div class="panel-body">
#         <p>Be sure to zip and submit your entire <code>LESSON-HandsOn</code> directory when finished!</p>
#     </div>
# </div>

# %% [markdown]
# <hr style="height:10px;border-width:0;color:gray;background-color:gray">
#
# # Page 6 - Group Organization<a class="anchor" id="DS110L1_page_6"></a>
#
# [Back to Top](#DS110L1_toc)
#
# <hr style="height:10px;border-width:0;color:gray;background-color:gray">

# %% [markdown]
# # Group Organization
#
# Staying organized is often one of the greater challenges a team can encounter.  Having well defined roles, schedules, and tasks is how you and your team can ensure you stay on track to completion of the project.
#
# ---
#
# ## Scrum Master
#
# The **SCRUM Master** should be elected each week during a retrospective meeting at the end of a sprint.  Ideally, the same person should not be elected twice until each member of the team has held the position.  The SCRUM Master has many responsibilities for the group.
#
# * Facilitate daily stand up meetings
# * Facilitate weekly retrospective meetings
# * Ensure the team follows the guidelines agreed upon by the team
# * Communicate issues to the Product Owner (instructor)
#
# The Scrum master is in charge of group organization and task adherence.  This includes arranging for the date and times of the daily and weekly meetings, communicating to the product owner about the team progress, and ensuring each team member has the tools necessary to complete their task.
#
# The Scrum Master will report to the Product Owner (instructor) the progress of the team and demonstrate the product after the sprint is done.  Any issues that are being experienced by the team should be examined by the Scrum Master for possible solutions before being presented to the Product Owner.
#
# ---
#
# ## Individual Responsibilities
#
# Each sprint you will be assigned a set of tasks to complete.  These tasks will be arranged around a feature of the application.  *You are responsible for ensuring each of your assigned tasks are completed before the end of the sprint.*  Your ability to complete these tasks will be how you are graded for that sprint.
#
# ---
#
# ## Sprint
#
# Each week a new sprint begins on **Monday** and ends on **Sunday**.  Each week you will assign tasks for each sprint. At the end of the sprint a retrospective should be conducted by the Scrum Master.  It is important that all of your tasks are completed, committed to Github, and tracked on the Kanban Board.
#
# ---

# %% [markdown]
# <hr style="height:10px;border-width:0;color:gray;background-color:gray">
#
# # Page 7 - Group Meetings<a class="anchor" id="DS110L1_page_7"></a>
#
# [Back to Top](#DS110L1_toc)
#
# <hr style="height:10px;border-width:0;color:gray;background-color:gray">

# %% [markdown]
# # Group Meetings
#
# You will be required to attend regular meetings.  During the meetings you should keep the Kanban board open so you can visually see the progress of each task.
#
# ---
#
# ## Daily Stand Ups
#
# There will be a daily stand up hosted by the Scrum Master of that week. Each student should state the following during the meeting:
#
# - **What they did the day before**.
# - **What they are going to do that day**.
# - **Any obstacles preventing them from meeting their goal for that day**.
#
# The Scrum Master should facilitate a proposed solution for any obstacles stated by the student. If no solution can be determined then the Scrum Master should notify and discuss the issue with the product owner (instructor). The Scrum Master should also notify the product owner (instructor) if a fellow worker did not attend or complete the Scrum Daily Stand Up Form on time.
#
# <div class="panel panel-info">
#     <div class="panel-heading">
#         <h3 class="panel-title">Tip!</h3>
#     </div>
#     <div class="panel-body">
#         <p>If your schedules prevent you from meeting daily, try doing a standup in slack where everyone starts his or her day by stating the three stand up points.</p>
#     </div>
# </div>
#
#
# ---
#
# ## Weekly Retrospective
#
# Each week your team will conduct a live video conference call to do the following:
#
# - Close any remaining tasks on the Kanban board
# - Finalize merges on your Github repository
# - Each member demonstrates the tasks they implemented that week
# - Plan the tasks and assign new tasks for the next sprint
# - Complete the lesson activity for that week
#
# It is the responsibility of the Scrum Master to arrange for the meeting time and follow the meeting agenda.
#
# <div class="panel panel-success">
#     <div class="panel-heading">
#         <h3 class="panel-title">Why are spring retrospective meetings so important?</h3>
#     </div>
#     <div class="panel-body">
#         <p> <a href="https://blog.trello.com/sprint-retrospective-meetingm"> Take a peek at Trello's answer!</a> </p>
#     </div>
# </div>
#
# ---
#
# ## Weekly 1on1 with Instructor
#
# Up until this point, you have had a weekly 30-minute meeting with your mentor.  In similar form, your group will meet with the instructor instead for 30 minutes weekly.  If you have not yet set up a time for that "1on1" meeting (it may be several to one - don't gang up on your instructor!), please reach out to do so.
#
# ---

# %% [markdown]
# <hr style="height:10px;border-width:0;color:gray;background-color:gray">
#
# # Page 8 - Kanban Board<a class="anchor" id="DS110L1_page_8"></a>
#
# [Back to Top](#DS110L1_toc)
#
# <hr style="height:10px;border-width:0;color:gray;background-color:gray">

# %% [markdown]
# # Kanban Board
#
# You will create a Kanban Board for you to track and manage your tasks.  This will be a vital part of your project phase.  Knowing which tasks are assigned to you and your teammates as well as being able to track their progress is one of the ways you will be graded each week.
#
# ---
#
# ## The Columns
#
# There will be four columns to the Kanban board.  A `Backlog`, `Sprint`, `In Progress`, and `Done` column.  As your team creates future tasks, they must first be placed in the `Backlog` column.
#
# ![Kanban Setup](Media/KanbanSetup.png)
#
# - **Backlog:** Column for initial task creation
# - **Sprint:** Column for tasks which have been added to the sprint and should be done by the next retrospective
# - **In Progress:** Column for the tasks that are currently being worked on
# - **Done:** Column for tasks which have been completed and pushed to the Github repository
#
# Each column represents a status of the task.
#
# ---
#
# ## Ticket Status
#
# If a task is in the `Backlog` column then it has simply been added as a future task that needs to be completed, but no deadline has yet been given.
#
# During the weekly retrospective team meeting, a task has been determined to be something which should be completed by the end of the next sprint will be moved from the `Backlog` column to the `Sprint` column.  It is also at this time that the task should be converted to an `issue` and a description should be added to the task.
#
# ![Convert To Issue](Media/ConvertToIssue.png)
#
# ![Issue Description](Media/IssueDescription.png)
#
# Then the `issue` should be assigned to one of the team members by clicking on title of the ticket which has now become a hyperlink, and the gear icon next to `Assignees`.
# ![Issue Description](Media/AddAssignees.png)
#
# Then you can assign up to 10 people to the issue, however there typically are no more than 1 or 2 people assigned to any issue.
#
# ![Issue Description](Media/SelectAssignees.png)
#
# When it comes time for you to begin working on a task that has been assigned to you, it should be moved from the `Sprint` column to the `In Progress` column.  This way other members of your team will know that you are working on that particular task and can plan accordingly with their own tasks.
#
# ![Issue Description](Media/MoveToInProgress.png)
#
# After you have completed the task and the code for that task has been pushed to GitHub, you can then move the task from the `In Progress` column to the `Done` column indicating that the code is ready for production.
#
# ![Issue Description](Media/MoveToDone.png)
#
# <div class="panel panel-info">
#     <div class="panel-heading">
#         <h3 class="panel-title">Tip!</h3>
#     </div>
#     <div class="panel-body">
#         <p>Don't forget to add your instructor to your Trello Kanban board so that he or she can see your work and help direct you!</p>
#     </div>
# </div>
#
# ---

# %% [markdown]
# <hr style="height:10px;border-width:0;color:gray;background-color:gray">
#
# # Page 9 - Time Management<a class="anchor" id="DS110L1_page_9"></a>
#
# [Back to Top](#DS110L1_toc)
#
# <hr style="height:10px;border-width:0;color:gray;background-color:gray">

# %% [markdown]
# # Time Management
#
# You probably haven't survived bootcamp this long without some decent time management skills, but they become critical at this stage. **The project phase can be incredibly time consuming.**  You should be planning for at least **20 hours** of your week to be dedicated toward the group project.  Allocating this time does not ensure success, however.  Much of your time will be spent doing research and further planning.  Try to remain as flexible as you can with your activities outside of the project.
#
# To help keep you organized and on time, please do the following tasks:
#
# 1. Determine a Scrum Master for Week 2 (this position will rotate each week).
# 2. Establish a Team Name to help identify the team.
# 3. Establish a Kanban board.
# 5. Establish a time each day for the daily stand up or time which the SCRUM Daily Stand up Form must be completed so the Scrum Master can be made aware of everyone’s progress.
# 6. Establish a time each week for the team retrospective.
#
# ---

# %% [markdown]
# <hr style="height:10px;border-width:0;color:gray;background-color:gray">
#
# # Page 10 - Project Planning<a class="anchor" id="DS110L1_page_10"></a>
#
# [Back to Top](#DS110L1_toc)
#
# <hr style="height:10px;border-width:0;color:gray;background-color:gray">

# %%
from IPython.display import VimeoVideo
# Tutorial Video Name: Week 1 Project Planning
VimeoVideo('388139884', width=720, height=480)
# Out:
#         <iframe
#             width="720"
#             height="480"
#             src="https://player.vimeo.com/video/388139884"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# The transcript for the above overview video **[is located here](https://repo.exeterlms.com/documents/V2/DataScience/Video-Transcripts/DSO110L03overview.zip)**.

# %% [markdown]
# <hr style="height:10px;border-width:0;color:gray;background-color:gray">
#
# # Page 11 - Choosing a Topic<a class="anchor" id="DS110L1_page_11"></a>
#
# [Back to Top](#DS110L1_toc)
#
# <hr style="height:10px;border-width:0;color:gray;background-color:gray">

# %% [markdown]
# # Choosing a Topic
#
# The world is your oyster! You are free to pick whatever topic you like, as long as it is unoffensive.  Pick something that sparks interest for you, and something you care about.  You will be heavily involved in this topic and this data for six weeks, so choose a topic that you won't get bored with or grow to hate.  If your mind is blank, ask yourself some of these questions to brainstorm:
#
# * What are your hobbies?
# * About what are you passionate?
# * Do you have any work experience in a particular field and want to remain in that field?
# * Have you completed any additional schooling in a particular field and want to build upon that knowledge?
# * Are there any problems you wish you could solve? Always stuck in traffic? Want to end world hunger? Need to know where the cheapest grocery sales are?
# * Do you have family or friends that want to know the answers to questions? You could be poised to answer them!
# * Does your current employer have any issues at work that you could potentially help them solve with data?
# * What do you consider fun and interesting?
#
# If you like the topic, your enthusiasm will show throughout your presentation and will indoubtably make a better, more interesting, and more engaging presentation.  Wouldn't it be nice if your audience was on the edges of their seats rather than on the edge of passing out from boredom?!
#
# ---

# %% [markdown]
# <hr style="height:10px;border-width:0;color:gray;background-color:gray">
#
# # Page 12 - Choosing your Data<a class="anchor" id="DS110L1_page_12"></a>
#
# [Back to Top](#DS110L1_toc)
#
# <hr style="height:10px;border-width:0;color:gray;background-color:gray">

# %% [markdown]
# # Choosing your Data
#
# For this project, you will be free to work on a dataset of your own choosing.  It should be a dataset that aligns with the topic you pick, and if for some reason there is not readily available data on that topic, it most likely makes sense to change your topic, unfortunately.  You **do not want** to spend most of your six weeks finding and selecting data, and having a useful dataset is the number one goal.
#
# <div class="panel panel-success">
#     <div class="panel-heading">
#         <h3 class="panel-title">Additional Info!</h3>
#     </div>
#     <div class="panel-body">
#         <p>You may want to watch this <a href="https://vimeo.com/465045798"> recorded live workshop that gives you an introduction to finding good data. </a> </p>
#     </div>
# </div>
#
# ---
#
# ## Sources of Data
#
# You can basically choose data from anywhere, as long as it is freely available and you have permission to use it.  Consider the following data source options:
#
# * Collecting your own data
# * Asking your employer for data to help solve his or her work problems
# * Asking a family member or friend for data to help solve their problems
# * Using readily available data from the internet
#
# There are pros and cons to all of these options.
#
# ---
#
# ### Collecting Your Own Data
#
# If you feel strongly about collecting your own data, you will need to undergo a review to ensure that your data collection will not cause harm to others.  It will also take a lot of extra time to create a survey, distribute that survey, and receive results upon that survey, so make sure you are really excited about demonstrating surveying techniques and that the data does not already exist elsewhere.  Your analyses will most likely be less involved, due to the time sink of data collection.
#
# ---
#
# ### Asking Others for their Data
#
# Whether you are getting data from an employer, a friend, or a family member, you will need their explicit permission to utilize that data.  This can also take time, especially if you're using data from your company - your request for data may need to work its way up the chain of command.  It may also put limits on how you can use and present upon that data.  Someone may require you to anonymize the data or to not record your presentation. However, using "real-world" data that actually solves an actual need can give you a leg up in the employment world, and if you are using data from your company, you can list it under your job description on your resume, and thus increases your chances of employment.
#
# ---
#
# ### Using Internet Data
#
# If none of the options above interest you or apply, you will make use of the interest, which has a wide variety of free and publically available data of which you can make use.
#
# Here are some suggestions as to where to begin looking for data:
#
# * **[Google's Dataset Search in Beta](https://www.blog.google/products/search/making-it-easier-discover-datasets/)**
# * **[Kaggle](https://www.kaggle.com/datasets?utm_medium=paid&utm_source=google.com+search&utm_campaign=datasets&gclid=Cj0KCQjwuLPnBRDjARIsACDzGL19NgcvKrkZC9SU6MXBmsfmOzcYtWfejvxBGZYzmv3FO4g_G0aui4YaAqbcEALw_wcB)**
# * **[University of California at Irvine Machine Learning Repository](https://www.welcome.ai/tech/machine-learning/uc-irvine-machine-learning-repository)**
# * **[data.gov](https://www.data.gov/)**
#
# There are also many ideas for starter projects, etc., such as **[this one](https://www.analyticsvidhya.com/blog/2018/05/24-ultimate-data-science-projects-to-boost-your-knowledge-and-skills/)**.  However, one of your challenges as a boot camper is to stand out from the crowd - you may not want to go a route that someone else has already trod.
#
# ---
#
# ## Considerations when Picking Data
#
# There are many things to consider when picking a dataset.
#
# * **Do you like data wrangling?** Some datasets are already nice and clean, and ready for analysis.  You just need to pop 'em in a statistical analysis or machine learning algorithm and you are good to go.  Others, especially those found on data.gov, may require a lot of wrangling.  How much are you willing to do? Keep in mind that data wrangling is often 90% of real projects and that employers will expect you to have some wrangling skills.
#
# * **Do you have enough data?** Most of the more complicated analyses require at least 200 rows as a rough guideline.
#
# * **Do you have too much data?** Given that you don't actually have a big data cluster running multiple nodes, and you probably don't want to pay for one, choose a dataset that is manageable in size so that you can run it yourself.
#
# * **How much data is missing?** If you find that 75% of the data is missing, then you may end up not having enogh data after all.  And if that data is essentatial to the topic at hand, then that's another reason you might not be able to use it.
#
# * **Is there data on your topic?** Again, if you can't find any data on a particular topic, it may be better to pick your second favorite topic that go on a wild goose chase.
#
# * **Will you have to piece together data from different sources?** Doing so can be awesome and fun, and demonstrates a wider range of skills.  But it can also be a nightmare! If you are interested in doing some data joining, then make sure you pick data that has a common key and that makes sense to combine.
#
# * **What stipulations, if any, are put on the use of the data?** Do you need to pay a fee? Report on your findings somewhere? Make everything anonymous? Add in a reference to the data source? It's a good idea to find out in advance so you are not surprised later.
#
# * **Is the data commonly used?** You want to demonstrate to employers that you can work off the beaten track.  If you pick a very common dataset that has lots of tutorials about how to analyze it, then you run the chance of being "same old, same old" and not drawing attention to yourself, no matter how well you completed the project. Especially avoid datasets built into Python and R, since those are some of the most overused datasets out there!
#
# Paying attention to some of these considerations can really make or break you - thinking through the ramifications of your dataset in advance can make the difference between a project in which you spend all of your time cursing your data and a project that is a breeze and moves along smoothly. Snooping very briefly through the data and considering the above questions will save you a lot of time later.
#
# ---

# %% [markdown]
# <hr style="height:10px;border-width:0;color:gray;background-color:gray">
#
# # Page 13 - Submit your Data<a class="anchor" id="DS110L1_page_13"></a>
#
# [Back to Top](#DS110L1_toc)
#
# <hr style="height:10px;border-width:0;color:gray;background-color:gray">

# %% [markdown]
# # Choosing your Data
#
# It is incredibly important to pick your dataset in the first week, so that you can get to work on it in the upcoming weeks! It is more important to have made a dataset decision than it is to have picked the absolute perfect dataset - because there is no perfect dataset!
#
# ---
#
# ## First Choice Dataset
#
# Please include your first-choice dataset and/or a link to where the data is located online. You can proceed project planning using this dataset.
#
# ---
#
# ## Backup Dataset
#
# Not everything always goes to plan, so its a good idea to have a backup just in case. If you have a backup dataset, please include the dataset and/or link here as well.
#
# <div class="panel panel-danger">
#     <div class="panel-heading">
#         <h3 class="panel-title">Caution!</h3>
#     </div>
#     <div class="panel-body">
#         <p>Be sure to zip up all of your documents in order to submit them</p>
#     </div>
# </div>

# %% [markdown]
# <hr style="height:10px;border-width:0;color:gray;background-color:gray">
#
# # Page 14 - Choosing your Evaluation Questions<a class="anchor" id="DS110L1_page_14"></a>
#
# [Back to Top](#DS110L1_toc)
#
# <hr style="height:10px;border-width:0;color:gray;background-color:gray">

# %% [markdown]
# # Choosing your Evaluation Questions
#
# Now that you have your data picked out, its time to figure out what questions you want to answer with that data!
#
# ---
#
# ## What is an Evaluation Question?
#
# Yes, you're asking questions about questions now! So meta! An *evaluation question* is an intelligent question you can ask about your data in order to help out your company.  These questions will be the guiding principles that help organize your data exploration.  They can be relatively general, as long as you can translate them into specifics.  For instance, you might ask a question like "How do health metrics differ between ethnicities?" Although that is somewhat general, as "health metrics" and "ethnicities" can encompass many different components and variables, you can use your data to point towards specific components there.  If you have columns in your data about disability level, number of times someone has gone to the doctor in the last month, and the amount of money they have spent on medications, you have now quantified, or translated, "health metrics" into something that you can actually look at and measure.
#
# You should have at least two evaluation questions for your final project, and you should most likely be able to use several different data pieces in order to answer them.
#
# ---

# %% [markdown]
# <hr style="height:10px;border-width:0;color:gray;background-color:gray">
#
# # Page 15 - Choosing your Analyses<a class="anchor" id="DS110L1_page_15"></a>
#
# [Back to Top](#DS110L1_toc)
#
# <hr style="height:10px;border-width:0;color:gray;background-color:gray">

# %% [markdown]
# # Choosing your Analyses
#
# Once you have at least two evaluation questions, your next step is to determine what data and analyses you can use to actually answer those questions.
#
# ## Variable Types and Levels
# There are several major factors that go into choosing what type of analysis you will run, but the most important component of all is what data and variables you have. Reviewing variable types and levels as they pertain to choosing statistical analyses is critical!
# Independent vs. Dependent Variables
# First, start by identifying your independent, or predictor, variable, and your dependent, or outcome, variable.
# The independent variable, also known as the predictor variable, and abbreviated IV, is the variable or variables that influence your dependent variable. They are causing some sort of effect. Your independent variable or variables (most advances analyses will allow you to have more than one) are the things that you think might influence the dependent variable.
#
# The dependent variable, also known as the outcome variable, or abbreviated DV is what you are influencing. It's what you're predicting. It is the effect that is being caused by your independent variable. The dependent variable depends on the independent variable.
# In choosing an analysis, after you know the purpose of the analysis, typically you'll need to choose the data types of your IVs and DVs. Being able to distinguish between continuous and categorical variables, understand the levels of the variables, and identify your independent and dependent variables, are essential skills for data scientists.
#
# ## Data Types
# ### Continuous Variables
# A continuous variable is one that is numeric, and where a bigger number actually means that you have more of something. For instance, height is continuous - the bigger the number of feet tall you are, the taller you are. Don't be fooled - sometimes data can be in numbers, but not actually be continuous. This happens a lot after recoding. What if you recode hair color from black, brown, and blonde into 0, 1, and 2? This is numeric, but does the number actually mean anything? Are blondes, given a 2, any better or larger than those with black hair, given a 0? No. So make sure that when you are assessing your variables, you take into account not only whether it is numeric or not, but if the numbers have meaning.
#
# ### Categorical Variables
# A categorical variable is a category - it's right there in its name. You have distinct things that are grouped into like sections. Often a categorical variable is a string variable, meaning that it is in letters. Something like writing out the names of each hair color. But sometimes, numbers can be substituted for the groups to make analysis easier. You still have categories underlying it though - you've just substituted a number for the name.
# A special kind of categorical variable is one that is dichotomous or binary. All those terms mean is that you have only two groups, instead of more. So something like "pass / fail" categories or "dead / alive" categories etc. are great examples of dichotomous or binary categorical variables.
#
# ### Variable Levels
# When you have categorical variables, those variables can have levels. The number of levels is the number of groups that variable has. For instance, in the hair color situation, where the options are black, brown, or blonde, hair color is one variable, but it has three levels, or three choices, of hair color. It's all one variable - hair color - but has multiple responses that someone could have, which is the levels. Certain analyses require variables to have only two levels, so its important to identify the number of variable levels.
#
#
# <div class="panel panel-info">
#     <div class="panel-heading">
#         <h3 class="panel-title">Tip!</h3>
#     </div>
#     <div class="panel-body">
#         <p>You may want to revisit the flow charts on choosing analyses located in DSO104 Data Wrangling and Visualization Lesson 9.</p>
#     </div>
# </div>
#
# ---

# %% [markdown]
# <hr style="height:10px;border-width:0;color:gray;background-color:gray">
#
# # Page 16 - Submit your Evaluation Questions and Analyses<a class="anchor" id="DS110L1_page_16"></a>
#
# [Back to Top](#DS110L1_toc)
#
# <hr style="height:10px;border-width:0;color:gray;background-color:gray">

# %% [markdown]
# # Choosing your Questions and Analyses
#
# One of the most difficult parts of the project is just nailing down what you will do with the data! In order to do this effectively, please fill out **[this form](https://repo.exeterlms.com/documents/V2/DataScience/Final-Project/AnalysisPlanningWorksheet.zip)** that helps you determine how you will answer your evaluation questions. You should have one worksheet for every evaluation question you have. This means that, with a minimum requirement of two questions, you will need to submit two analysis planning worksheets!
#
# Starting with the evaluation question, ask yourself what are you trying to predict, classify, or solve. That is typically your dependent variable. The other variables, which help make the predictions, classifications, or solutions, will be your independent variables. Remember that your independent variable has some sort of effect on your dependent variable.
#
# You can have multiple IVs and multiple DVs. Make sure you specify not only what the variable type is, but whether it is continuous (numeric) or categorical (string). If it is categorical, how many categories, or levels, are there?
#
# Thinking through this worksheet for each question will help you then apply **[these "Choosing the Right Statistic" charts](https://repo.exeterlms.com/documents/V2/DataScience/Final-Project/ChoosingStatisticsFlowcharts.zip)** better.
#
# <div class="panel panel-danger">
#     <div class="panel-heading">
#         <h3 class="panel-title">Caution!</h3>
#     </div>
#     <div class="panel-body">
#         <p>Be sure to zip up all of your documents in order to submit them</p>
#     </div>
# </div>

# %% [markdown]
# <hr style="height:10px;border-width:0;color:gray;background-color:gray">
#
# # Page 17 - Determine the Best Language to Use <a class="anchor" id="DS110L1_page_17"></a>
#
# [Back to Top](#DS110L1_toc)
#
# <hr style="height:10px;border-width:0;color:gray;background-color:gray">

# %% [markdown]
# # Determine the Best Language to Use
#
# Both Python and R have their pros and cons.  It will be important to choose the best language for your tasks, or you may spend a lot of extra time spinning your wheels.  R's strengths usually lie in statistics, and it does not always require you to remove missing data, which means that if you have a smaller sample size, R may be your best bet.  If you want to complete advanced statistics or modeling like regression, ANOVAS, or MANOVAs, you most likely want to take advantage of R's ability to rigorously test assumptions and easily conduct those analyses.
#
# However, if you will be using machine learning, or have lots of data wrangling to do, you may want to hit Python instead.
#
# ---

# %% [markdown]
# <hr style="height:10px;border-width:0;color:gray;background-color:gray">
#
# # Page 18 - Project Proposal<a class="anchor" id="DS110L1_page_18"></a>
#
# [Back to Top](#DS110L1_toc)
#
# <hr style="height:10px;border-width:0;color:gray;background-color:gray">

# %% [markdown]
# # Project Proposal
#
# For this week's hands-on, you will be asked to create a project proposal document, like you did in your Project Management module. Here you will learn exactly how each section in that project proposal relates to starting a data project. This is something you may be asked to do on the job, so it's great to get extra practice!
#
# ---
#
# ## Executive Summary
#
# The executive summary is a quick review of **everything** that is in the rest of your document. Especially if you have a military background, you may have heard this also referred to as a *"BLUF" - bottom line up front*. It's a way for the important people in your company to get the down and dirty details quickly and without a lot of extra reading.
#
# Even though it comes at the beginning, sometimes it can be easier to write the executive summary at the end - it's easier to summarize all the details once you already know them!
#
# ---
#
# ## Business Objectives
#
# Your business objectives should include your evaluation questions. What are you trying to answer or solve with your data work?
#
# ---
#
# ## Background
#
# You can't assume that everyone has the same level of subject matter expertise on a particular topic, so in the background section, you want to give an overview of the topic, the problem, and why it matters. Think about this in terms of building a business case: if you were to ask for funding to do this project, what would convince a client, manager, or other stakeholder to give it the green light? You want to include that information here.
#
# ---
#
# ## Scope
#
# Imagine your project is on a stage, and it can only be followed by one spotlight. What are the components that the spotlight will hit? Those factors are considered *in scope*. Anything that is relevant to your project and you're willing to tackle will be included, but anything that is a "rabbit trail" leading you out of the spotlight or off the stage altogether will be excluded, which is called *out of scope*. It's very important to define your scope thoroughly because if you don't, its easy for other people to shift you off course. Getting derailed by others is called *scope creep*, and it can be deadly to delivering a project on-time and on-target. When other people suddenly start asking you for additional other components, and you haven't budgeted for those other needs, resources, and time, your project can get off track quickly. Sometimes this happens because of genuine interest or enthusiasm on the part of others, and sometimes it can happen because they have their own political agenda within the organization.
#
# The stalwart guardian against scope creep is a well-defined scope! What are you willing to do for this project, and what are you unwilling to do? Think about things like:
#
# * What programs are you willing to use and what are you unwilling to use?
# * Are you willing to learn any new skills for this?
# * Are you willing to work more than 20 hours per week to finish?
# * Are you willing to add or change data if asked?
# * What analyses are you willing to complete and which ones are you not?
#
# While your instructor will not throw you out of scope, really thinking through this section will help you tremendously in the business world.
#
# ---
#
# ## Functional Requirements
#
# The functional requirements are the bread-and-butter of your project proposal document. This is where you will outline all your plans for the completion of your project. Items you'll need to include in this section are:
#
# * Programs / languages to be used
# * Information about your dataset and source
# * Variables and analyses you'll utilize to answer the questions in the business objectives section
#
# You should already have a fair amount of this section thought through from the other activities in this lesson.
#
# ---
#
# ## Personnel Requirements
#
# Personnel means people, which means you and your project partners if you have them! You'll also want to mention your instructor and mentors, since they will help along your journey.
#
# Estimate your time, and your teammates time, that you plan to spend on this project throughout the weeks. You can assume an average of approximately 20 hours per week per person, as a guide. When will you complete individual work? How about work as a team? When will team meetings take place, both with your instructor and without? Make sure you discuss all these factors and get a game plan together for how you will complete your work each week.
#
# ---
#
# ## Delivery Schedule
#
# HooBoy, this is where things get real! In the delivery schedule section, you will want to plan out the remaining five weeks of your final project lives as best you can! For every week, you should have a list of tasks that need to be completed. Remember, this is the basic outline to go by:
#
# * Week 1: Project Planning
# * Week 2: Data Wrangling
# * Week 3: Data Exploration
# * Week 4: Data Analysis
# * Week 5: Data Visualization
# * Week 6: Data Reporting and Presentation
#
# You will present your final project to the career services team, your instructor, fellow peers, and potential employers in Week 6 (please remember to turned in your last documents on or before the deadline).
#
# This brief outline is not enough. Push yourself to dive in deeper. Based on the data and questions you have picked, you should be able to outline what analyses you will complete, what visualizations make sense, and what data wrangling will be required. Getting tasks and time worked out ahead of time means that you'll spend less time contemplating your navel and more time doing project-related work in the next five weeks!
#
# Overachievers, make sure you leave yourself a little wiggle room, because indubitably, something will not go to plan. You may realize you didn't take care of all the wrangling required or that a certain analysis just isn't possible after all. That is ok! These things happen, and data work tends to be an iterative cycle: proceed until you hit an error, go back through and do work to solve the error, lather, rinse, repeat. Just make sure you have a time cushion to handle it.
#
# <div class="panel panel-info">
#     <div class="panel-heading">
#         <h3 class="panel-title">Tip!</h3>
#     </div>
#     <div class="panel-body">
#         <p>Data wrangling and data analysis weeks are the ones that tend to take the most time and are the ones that tend to throw the most roadblocks into your path. The data exploration and visualization weeks can be part of your built-in buffer, as you can complete the project without any exploration, and data visualization does not always take a full week.</p>
#     </div>
# </div>
#
# ---
#
# ## Other Requirements
#
# Thought of something else that doesn't fit anywhere in the document? Throw it here. If not, it's ok to leave this section blank.
#
# ---
#
# ## Assumptions
#
# Assumptions are outside factors that the project depends upon, but which you have little to no control over. For instance, you may assume a program such as Python will be working and not buggy. It's important to note the things you are depending upon, because their failure could severely derail you project. A good project manager is able to navigate around failed assumptions if they happen.
#
# ---
#
# ## Limitations
#
# A limitation is a threat to your project that is internal to you and your team. It's a known weakness that you want to document so that you can plan around it. Remember that saying, "plan for the worst and hope for the best?" That is exactly what you are doing here, both in this limitations section and also in this proposal document as a whole. Limitations could be known gaps in your knowledge or skills, or they could be things like scheduling, communication, and timing issues. It's a great idea to discuss limitations with your team, because again, it allows you to plan for them instead of letting them derail you.
#
# ---
#
# ## Risks
#
# A risk is similar to a limitation in that it is a threat to your project, but instead of being internal, a risk is external to your project or team. Risks are things that you don't necessarily have control over. This makes them a little more difficult to think through and plan, but the more you do so, the more stable your project will be if you hit some waves.
#
# A great example of a risk is loss of internet due to bad weather. What will you or your teammates do if you lose internet? You can't control that, but you can plan ahead to deal with it. Maybe you can head to a family or friend's house. Maybe you can hit a public library or a cafe with internet.
#
# Your goal is to put on your pessimism hat and think through all the weird and wooly scenarios, and then put an action plan in place with which to deal with them!

# %% [markdown]
# <hr style="height:10px;border-width:0;color:gray;background-color:gray">
#
# # Page 19 - Project Proposal and Requirements<a class="anchor" id="DS110L1_page_19"></a>
#
# [Back to Top](#DS110L1_toc)
#
# <hr style="height:10px;border-width:0;color:gray;background-color:gray">

# %% [markdown]
# # Project Proposal and Requirements
#
# Your first activity is to submit a project proposal that will be evaluated by your instructor for approval.
#
# In addition, you should plan your project using the Waterfall Business Requirements template, provided **[here](https://github.com/woz-u/student-materials/blob/master/018_Agile%20Project%20Management/sample_business_requirements.md).**
#
# You'll need to:
#
# * Flesh out what your main goals are
# * Gather any background information you need to explain your work or the data
# * Set the scope of the project
# * Detail all the requirements
# * Plan for trouble ahead by detailing limitations and risks
#
# Make sure to include:
# * Programming languages / technology you'll use
# * Evaluation questions you'll plan to answer with your data
# * How this project will meet the minimum project requirements
# * Who will be scrum master each week
#
# <div class="panel panel-success">
#     <div class="panel-heading">
#         <h3 class="panel-title">Additional Info!</h3>
#     </div>
#     <div class="panel-body">
#         <p><a href="https://repo.exeterlms.com/documents/V2/DataScience/Final-Project/SampleProjectProposal.zip">Here is an excellent example of what that document should look like as it relates to the final project</a></p>
#     </div>
# </div>
#
# <div class="panel panel-danger">
#     <div class="panel-heading">
#         <h3 class="panel-title">Caution!</h3>
#     </div>
#     <div class="panel-body">
#         <p>Be sure to zip up all of your documents in order to submit them</p>
#     </div>
# </div>
