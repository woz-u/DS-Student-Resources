# %% [markdown]
# # Creating a To-Read List

# %%
books = [
    {'name' : 'The Jewel', 'read' : True},
    {'name' : 'Cinder', 'read' : False},
    {'name' : 'The Train to Impossible Places', 'read' : False}
]

def list_books():
    for index, book in enumerate(books):
        print(str.format('{} : {} (Completed: {})', index, book['name'], book['read']))
        
def add_book(): 
    book_text = input('Please add a book:')
    new_book = {'name' : book_text, 'read': False}
    books.append(new_book)

def remove_book():
    list_books()
    remove_book = int(input('Please enter the number of the book to be removed:'))
    books.remove(books[remove_book])

def read_book():
    list_books()
    read_text = int(input('Please enter the number of the book you read:'))
    books[read_text]['read'] = True

menu_text = """
====================
1. List the books
2. Add a book
3. Remove a book
4. Mark a book read
5. Quit

What would you like to do? """

program_is_running = True

while program_is_running:
    decision = input(menu_text)
    if decision == '1':
        list_books()

    elif decision == '2':
        add_book()
    
    elif decision == '3':
        remove_book()
    
    elif decision == '4':
        read_book()
    
    elif decision == '5':
        program_is_running = False
    else:
        print('please choose a valid option')
# Out:
# ====================
# 1. List the books
# 2. Add a book
# 3. Remove a book
# 4. Mark a book read
# 5. Quit
#
# What would you like to do? 1
# 0 : The Jewel (Completed: True)
# 1 : Cinder (Completed: False)
# 2 : The Train to Impossible Places (Completed: False)
#
# ====================
# 1. List the books
# 2. Add a book
# 3. Remove a book
# 4. Mark a book read
# 5. Quit
#
# What would you like to do? 2
# Please add a book:Harry Potter and the Chamber of Secrets
#
# ====================
# 1. List the books
# 2. Add a book
# 3. Remove a book
# 4. Mark a book read
# 5. Quit
#
# What would you like to do? 1
# 0 : The Jewel (Completed: True)
# 1 : Cinder (Completed: False)
# 2 : The Train to Impossible Places (Completed: False)
# 3 : Harry Potter and the Chamber of Secrets (Completed: False)
#
# ====================
# 1. List the books
# 2. Add a book
# 3. Remove a book
# 4. Mark a book read
# 5. Quit
#
# What would you like to do? 3
# 0 : The Jewel (Completed: True)
# 1 : Cinder (Completed: False)
# 2 : The Train to Impossible Places (Completed: False)
# 3 : Harry Potter and the Chamber of Secrets (Completed: False)
# Please enter the number of the book to be removed:0
#
# ====================
# 1. List the books
# 2. Add a book
# 3. Remove a book
# 4. Mark a book read
# 5. Quit
#
# What would you like to do? 1
# 0 : Cinder (Completed: False)
# 1 : The Train to Impossible Places (Completed: False)
# 2 : Harry Potter and the Chamber of Secrets (Completed: False)
#
# ====================
# 1. List the books
# 2. Add a book
# 3. Remove a book
# 4. Mark a book read
# 5. Quit
#
# What would you like to do? 4
# 0 : Cinder (Completed: False)
# 1 : The Train to Impossible Places (Completed: False)
# 2 : Harry Potter and the Chamber of Secrets (Completed: False)
# Please enter the number of the book you read:2
#
# ====================
# 1. List the books
# 2. Add a book
# 3. Remove a book
# 4. Mark a book read
# 5. Quit
#
# What would you like to do? 1
# 0 : Cinder (Completed: False)
# 1 : The Train to Impossible Places (Completed: False)
# 2 : Harry Potter and the Chamber of Secrets (Completed: True)
#
# ====================
# 1. List the books
# 2. Add a book
# 3. Remove a book
# 4. Mark a book read
# 5. Quit
#
# What would you like to do? 5
