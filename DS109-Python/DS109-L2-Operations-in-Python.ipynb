# %% [markdown]
# # DS109 Python : Lesson Two Operations in Python

# %% [markdown]
# ### Table of Contents <a class="anchor" id="DS109L2_toc"></a>
#
# * [Table of Contents](#DS109L2_toc)
#     * [Page 1 - Overview of this Module](#DS109L2_page_1)
#     * [Page 2 - Setup](#DS109L2_page_2)
#     * [Page 3 - Strings](#DS109L2_page_3)
#     * [Page 4 - Converting Data to Strings](#DS109L2_page_4)
#     * [Page 5 - String Operations](#DS109L2_page_5)
#     * [Page 6 - Replacing Text in a String](#DS109L2_page_6)
#     * [Page 7 - Splitting Text Strings Into Substrings](#DS109L2_page_7)
#     * [Page 8 - Operators](#DS109L2_page_8)
#     * [Page 9 - Assignment Operators](#DS109L2_page_9)
#     * [Page 10 - Comparison Operators](#DS109L2_page_10)
#     * [Page 11 - Logical Operators](#DS109L2_page_11)
#     * [Page 12 - Logical Operator - or](#DS109L2_page_12)
#     * [Page 13 - Logical Operator - not](#DS109L2_page_13)
#     * [Page 14 - Combining Logical Operators](#DS109L2_page_14)
#     * [Page 15 - Operations Activity](#DS109L2_page_15)
#     * [Page 16 - Operations Activity II](#DS109L2_page_16)
#     * [Page 17 - Operations Activity III](#DS109L2_page_17)
#     * [Page 18 - Indentation](#DS109L2_page_18)
#     * [Page 19 - Decision-Making](#DS109L2_page_19)
#     * [Page 20 - Multiple Decision Making Blocks per Variable](#DS109L2_page_20)
#     * [Page 21 - Key Terms](#DS109L2_page_21)
#     * [Page 22 - Lesson 2 Hands-On](#DS109L2_page_22)

# %% [markdown]
# <hr style="height:10px;border-width:0;color:gray;background-color:gray">
#
# # Page 1 - Overview of this Module<a class="anchor" id="DS109L2_page_1"></a>
#
# [Back to Top](#DS109L2_toc)
#
# <hr style="height:10px;border-width:0;color:gray;background-color:gray">

# %%
from IPython.display import VimeoVideo
# Tutorial Video Name: Performing Operations in Python
VimeoVideo('238447724', width=720, height=480)
# Out:
#         <iframe
#             width="720"
#             height="480"
#             src="https://player.vimeo.com/video/238447724"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# In the last lesson, you learned about variables and the two types of data that they can contain: numbers and strings. In this lesson, the discussion on strings will be extended by showing you how you can manipulate them. You will also learn about another data type called a _boolean_ which is often used to control the flow of an app and make decisions. Finally, you will learn about the various arithmetic operators and how to perform operations using them.
#
# By the end of this lesson, you should be able to:
#
# * Combine and split string variables
# * Convert data to strings
# * Understand and use arithmetic, assignment, and logical operators
# * Utilize combinations of logical operators
# * Make decisions in your programming using if else statements
#
# This lesson will culminate in a hands-on in which you create a program to determine who is allowed to view certain movies based on the age of the viewer and the rating of the movie.

# %% [markdown]
# <hr style="height:10px;border-width:0;color:gray;background-color:gray">
#
# # Page 2 - Setup<a class="anchor" id="DS109L2_page_2"></a>
#
# [Back to Top](#DS109L2_toc)
#
# <hr style="height:10px;border-width:0;color:gray;background-color:gray">

# %% [markdown]
# # Setup
#
# Follow the below setup instructions so you are prepared to start learning!
#
# 1. First, open up your command prompt (Windows) or your terminal (Mac/Linux)
#     - For Windows, navigate to your search bar in the bottom left hand corner. Type in `Command Prompt` and it should pop up. Click on `Command Prompt` and a separate window should appear on your screen.
#     - For Mac, press `command` and the space bar at the same time. Type in `terminal` and press `enter`. A separate Terminal window will pop up.
# 2. Now that you are in your Command Prompt/Terminal, run the following command:
#     ```text
#     cd desktop
#     ```
# 3. Next, move your command prompt/terminal's location to the new `python_course` you just created by running the following:
#     ```text
#     cd python_course
#     ```
# 4. Create a _new_ directory within the `python_course` directory. This new folder is the project you will be working in for this lesson. Run the following:
#     ```text
#     mkdir lesson_two
#     ```
# 5. Open up a new window in VSCode.
# 6. The first thing you should see a Welcome page. You can close this window.
# 7. Now, its time to open the `lesson_two` directory. Click on the "Explorer" button on the left-hand side of the VSCode window.
# 8. You will now see a button that says `Open Folder`, as shown below. Click this button.
# 9. A new window will open that will allow you to search for files and folders. Locate the `python_course` folder you just created on your Desktop. Click on that folder and then locate the `lesson_two` folder. Select the `lesson_two` directory and click the `Open` button.
# 10. Create a new file named `main.py` by one of the following three ways:
#     - To the right of __LESSON_TWO__ in the EXPLORER is a button that looks like a piece of paper with a plus symbol in its top-left corner. If you hover your mouse over this button for a moment, a popup will appear indicating that this button will create a new file:
#
#         ![VSCode new file button. An arrow points to a file icon in a menu bar that says lesson 1, located in the directory open editors. ](Media/newFileButton.png)
#         _Figure 2-1: VSCode New File Button_
#
#     - Choose `File > New File` from the app's menu.
#     - Press `Control + N` in Windows or `Command + N` on a Mac (the plus means "and at the same time").
#
# Once the `main.py` file is created, you are ready to go! As you work through this lesson, add the code examples into your project so you can see the output yourself. Remember, to see the output within the VSCode terminal, right-click within your file and choose "Run Python File in Terminal".
#
# The creation of this new project is for you to practice your new skills. It is highly recommended that you add the code from this lesson into your `lesson_two` project as you learn it. As you are going through this lesson and adding code to your project, you may find it helpful to include `comments` with a brief sentence explaining what is going on in the code. That way, you will have an easy reference to the topics explained in this lesson. Happy coding!

# %% [markdown]
# <hr style="height:10px;border-width:0;color:gray;background-color:gray">
#
# # Page 3 - Strings<a class="anchor" id="DS109L2_page_3"></a>
#
# [Back to Top](#DS109L2_toc)
#
# <hr style="height:10px;border-width:0;color:gray;background-color:gray">

# %% [markdown]
# # Strings
#
# You should recall from the last lesson that a _string_ is text &mdash; words, greetings, titles, names, etc. You saw how you can set a string by using single and double quotes and special characters like tabs and newlines. Now, you will learn about a few operations that you can perform with strings like combining and manipulating them.
#
# ----
# ## String Concatenation
#
# The word *concatenation* means to combine. When concatenating strings, you use the `+` operator similarly to how you would add two numbers together. The difference, however, is that no arithmetic is performed. Instead, it simply glues the pieces together. Take a look at the example below:
#
# ```python
# my_message = "Hello"
# my_other_message = "how are you?"
#
# # concatenate the above variables with a comma in between
# my_final_message = my_message + ", " + my_other_message
#
# print(my_final_message)
# ```
#
# The output of the above print() statement would be: `"Hello, how are you?"` The value of the `my_message` variable is concatenated with `", "` and the value of the `my_other_message` variable using the `+` operator. The result of that concatenation is set as the value of the `my_final_message` variable, before it is printed.
#
# Here's another example:
#
# ```python
# day = "1"
# year = "2017"
# month = "August"
#
# today_is = month + " " + day + ", " + year
#
# print(today_is)
# ```
#
# The `today_is` variable is assigned to the value of the `month`, `day`, and `year` variables concatenated together with separators. The output would be `August 1, 2017`.

# %% [markdown]
# <hr style="height:10px;border-width:0;color:gray;background-color:gray">
#
# # Page 4 - Converting Data to Strings<a class="anchor" id="DS109L2_page_4"></a>
#
# [Back to Top](#DS109L2_toc)
#
# <hr style="height:10px;border-width:0;color:gray;background-color:gray">

# %% [markdown]
# # Converting Data to Strings
#
# As a data scientist, there will be many times when you need to modify the type of variable you have! Below is a great example - what if some of your variables are set to integers, not strings, but you want to concatenate them? Well guess what? You can't! If you run the code below, you will see that you get an error:
#
# ```python
# day = 1
# year = 2017
# month = "August"
#
# today_is = month + " " + day + ", " + year
#
# print(today_is)
# ```
#
# The reason is because you cannot concatenate an integer (int) with a string. This is because the program will read the `+` sign as a `plus` sign rather than concatenation (you will be learning more about arithmetic operations with integers later in this lesson).
#
# ---
#
# ## Using the str() Function
#
# To handle this, you need to turn the integers into strings with the str() function as shown below:
#
# ```python
# day = 1
# year = 2017
# month = "August"
#
# today_is = month + " " + str(day) + ", " + str(year)
#
# print(today_is)
# ```
# Now, when you run this, it will work. Pretty cool, right?
#
# ---
# ## Formatting Strings
#
# Alternatively, instead of using `str()` on every piece of your concatenation, you could instead use the function `str.format()`. If you use it at the beginning in place of concatenation, then you can tell Python what to expect regarding the variables and tell it to format each as a string. For instance:
#
# ```python
# day = 1
# year = 2017
# month = "August"
#
# today_is = str.format("The date is {} {}, {} ", month, day, year)
#
# print(today_is)
# ```
#
# The output of the above will be:
#
# ```text
# The date is August 1, 2017
# ```
#
# ---
#
# ### Variable Order Matters
#
# The `str.format` takes in the string and within the string are empty curly braces `{}`. These curly braces are defined _after_ the string. The definitions of the curly braces are in the order you want the variables to be shown. So, in the above example, you want to see the month, day then year. If you change around those variables, the date will change:
#
# ```python
# day = 1
# year = 2017
# month = "August"
#
# today_is = str.format("The date is {}, {} {} ", year, month, day)
#
# print(today_is)
# ```
#
# Now the output will be:
#
# ```
# The date is 2017, August 1
# ```
#
# When you want to print a string using predefined variables, string concatenation and string formatting are both acceptable ways to accomplish this.

# %% [markdown]
# <hr style="height:10px;border-width:0;color:gray;background-color:gray">
#
# # Page 5 - String Operations<a class="anchor" id="DS109L2_page_5"></a>
#
# [Back to Top](#DS109L2_toc)
#
# <hr style="height:10px;border-width:0;color:gray;background-color:gray">

# %% [markdown]
# # String Operations
#
# In Python, you can do so much more than just add two strings together. You can add or remove spacing, convert letters to lowercase or uppercase, and you can even replace one word with another.
#
# ---
#
# ## Making Text Strings Lowercase
#
# The function `lower()` returns a string where all letters have been converted to lowercase.
#
# The `lower()` function can be performed on a string to convert _all_ letters to lowercase. As you can see in the example below, a dot `.` and the `lower()` operation are appended to the string variable `my_message`.
#
# ```python
# my_message = "THESE ARE ALL CAPS"
#
# print(my_message.lower())
# ```
#
# **OUTPUT**:
#
# ```
# these are all caps
# ```
#
# ---
# ## Making Text Strings Uppercase
#
# Great! You can also use `upper()` to do the opposite - it will return a string where all letters have been converted to uppercase.
#
# Similar to the `lower()` operation, the `upper()` operation can be called on strings. The result is that _all_ letters will be converted to uppercase.
#
# ```python
# my_message = "these are all lower"
#
# print(my_message.upper())
# ```
#
# OUTPUT:
#
# ```
# THESE ARE ALL LOWER
# ```
#
# These operations can be handy in data wrangling, when you need to ensure that all your response options for a categorical variable are the same.  You don't want to count the frequencies of `cat` different from `CAT` or `Cat` or `cAt`, do you?

# %% [markdown]
# <hr style="height:10px;border-width:0;color:gray;background-color:gray">
#
# # Page 6 - Replacing Text in a String<a class="anchor" id="DS109L2_page_6"></a>
#
# [Back to Top](#DS109L2_toc)
#
# <hr style="height:10px;border-width:0;color:gray;background-color:gray">

# %% [markdown]
# # Replacing Text in a String
#
# You can use the function `.replace()` to return a string where you replace all instances of something with something else.  This function takes on the format `.replace('old', 'new')` where all occurrences of `old` have been replaced by `new`.
#
# If you need to replace some text in a string, you use the `replace` string operation. Unlike the previous two string operations, this one requires two extra inputs called parameters. One parameter specifies the string occurrences that are to be changed and the other parameter specifies what they should be changed to. These parameters are related to functions and methods, and you’ll learn about all of these soon!
#
# This is easier to understand with examples.
#
# ```python
# experience = "this game is fun"
# better_experience = experience.replace("fun", "awesome")
#
# print(experience)
# print(better_experience)
# ```
#
# **OUTPUT**:
# ```
# this game is fun
# this game is awesome
# ```
#
# In the above example, the variable `better_experience` is set to the result of calling `.replace()` on the `experience` string variable to change _all_ occurrences of the word `fun` to the word `awesome`.
#
# In the next example, more than one word is changed from a single call of the function `.replace()`. You can also see that single quotes are used instead of double quotes &mdash; both are acceptable.
#
# ```python
# message = "I like cats, because cats are friendly"
# new_message = message.replace('cats', 'dogs')
#
# print(new_message)
# ```
#
# **OUTPUT**:
#
# ```
# I like dogs, because dogs are friendly
# ```
#
# As with the `.upper()` and `.lower()` functions, `.replace()` will come in very handy when you start doing data wrangling! It can make it much easier to change data values if necessary.

# %% [markdown]
# <hr style="height:10px;border-width:0;color:gray;background-color:gray">
#
# # Page 7 - Splitting Text Strings Into Substrings<a class="anchor" id="DS109L2_page_7"></a>
#
# [Back to Top](#DS109L2_toc)
#
# <hr style="height:10px;border-width:0;color:gray;background-color:gray">

# %% [markdown]
# # Splitting Text Strings Into Substrings
#
# Using the `.split()` function, you can split a text string into substrings. A _substring_ is a portion of another string. The `.split()` operation has two optional parameters: one to specify how the string should be split (the _separator_), and another to specify the maximum number of splits that will be performed.
#
# <div class="panel panel-success">
#     <div class="panel-heading">
#         <h3 class="panel-title">Fun Fact!</h3>
#     </div>
#     <div class="panel-body">
#         <p>Splitting is often called "delimiting". When data is parsed into formats such as CSV, you are essentially using the split function to define each column by a separator!</p>
#     </div>
# </div>
#
# ---
#
# ## Splitting with Defaults
#
# If no value is specified for the separator, it will default to splitting a string where it finds a _space_. If you do not specify a maximum number of splits, the default is -1. This means that all of them will be split.
#
# As always, this is best shown using examples:
#
# ```python
# my_message = "Split these words for me"
# split_at_spaces = my_message.split()
#
# print(split_at_spaces)
# ```
#
# **OUTPUT**:
#
# The output is a list that has each word in its own set of quotes and separated by a comma.
#
# ```python
# ['Split', 'these', 'words', 'for', 'me']
# ```
#
# ---
#
# ## Splitting with a Specified Separator
#
# Now, an example where a separator is specified:
#
# ```python
# my_message = "apples,oranges,bananas"
# split_at_commas = my_message.split(",")
#
# print(split_at_commas)
# ```
#
# **OUTPUT**:
# ```
# ['apples', 'oranges', 'bananas']
# ```
#
# Again, the output is a list.  But this time, instead of being split by spaces, (which is the Python default), you have asked Python to split by commas so each word before the comma becomes its own list object.
#
# <div class="panel panel-success">
#     <div class="panel-heading">
#         <h3 class="panel-title">Additional Info!</h3>
#     </div>
#     <div class="panel-body">
#         <p>There are numerous string operations that can be used to manipulate text; too many to cover in the lesson. However, you can read about the other operations that are available <a href="https://docs.python.org/3/library/stdtypes.html#string-methods">  at the following web page. </a></p>
#     </div>
# </div>

# %% [markdown]
# <hr style="height:10px;border-width:0;color:gray;background-color:gray">
#
# # Page 8 - Operators<a class="anchor" id="DS109L2_page_8"></a>
#
# [Back to Top](#DS109L2_toc)
#
# <hr style="height:10px;border-width:0;color:gray;background-color:gray">

# %% [markdown]
# # Operators
#
# You have already seen a few operators in use in this course, such as when you combined two strings together using the `+` operator. The plus operator &mdash; like the minus, multiplication, and division operators &mdash; is an arithmetic operator. There are also operators for assigning values and comparing them.
#
# ---
# ## Arithmetic Operators
#
# The operators for performing arithmetic are the same as your would use with a calculator. For example: 1 + 1, 3 * 2, 5 - 4, and 3 / 1. These operators can be used with both integer and floating-point numbers. Below you'll find a description of each. Some descriptions refer to an *operand*, which is a value the operator operates on. For most arithmetic operators, there are two operands. However, there is a special case, *not*, that only has one operand.  You will learn more about `not` later!
#
# <table class="table table-striped">
#   <thead>
#     <th>Operator</th>
#     <th>Operation</th>
#     <th>Description</th>
#   </thead>
#   <tbody>
#     <tr>
#       <td style="font-weight:bold; text-align:center;">+</td>
#       <td>Addition</td>
#       <td>Adds the values on either side of the operator.<br/>
#           <code>3 + 3</code> = 6</td>
#     </tr>
#     <tr>
#       <td style="font-weight:bold; text-align:center;">-</td>
#       <td>Subtraction</td>
#       <td>Subtracts the right-hand operand from the left-hand operand.<br/>
#           <code>3 - 3</code> = 0</td>
#     </tr>
#     <tr>
#       <td style="font-weight:bold; text-align:center;">*</td>
#       <td>Multiplication</td>
#       <td>Multiplies both operands together.<br/>
#           <code>5 * 5</code> = 25</td>
#     </tr>
#     <tr>
#       <td style="font-weight:bold; text-align:center;">/</td>
#       <td>Division</td>
#       <td>Divides the left-hand operand by the right-hand operand.<br/>
#           <code>9 / 3</code> = 3</td>
#     </tr>
#     <tr>
#       <td style="font-weight:bold; text-align:center;">%</td>
#       <td>Modulo</td>
#       <td>Divides the left-hand operand by the right-hand operand and returns the remainder.<br/>
#           <code>10 % 3</code> = 1 or <code>20 % 10</code> = 0</td>
#     </tr>
#     <tr>
#       <td style="font-weight:bold; text-align:center;">//</td>
#       <td>Floor division</td>
#       <td>The division of operands where the result is the quotient in which the digits after the decimal point are removed. If one of the operands is negative, the result is floored or rounded away from zero.<br/>
#           <code>9 // 2</code> = 4 or <code>-11 // 3</code> = -4</td>
#     </tr>
#     <tr>
#       <td style="font-weight:bold; text-align:center;">**</td>
#       <td>Exponential</td>
#       <td>Performs exponential calculations on operators.<br/>
#           <code>10 ** 20</code> is read as 10 to the power of 20.</td>
#     </tr>
#   </tbody>
# </table>
#
# ---
#
# ## Code Examples
#
# Below are some arithmetic operations that you can try:
#
# ```python
# # addition
# result = 2 + 2 + 3      #result = 7
#
# # subtraction
# result = 22.2 - 3 - 11  # result = 8.2
#
# # multiplication
# result = 2 * 3 * 1.1    # result = 6.6 (SEE NOTE BELOW)
#
# # division
# result = 10 / 4         # result = 2.5
#
# # modulo (remainder)
# result = 10 % 4         # result = 2
#
# # floor division
# result = 10 // 4        # result = 2
#
# # exponent
# result = 2 ** 3         # result = 8 (2 to the power of 3, or 2 * 2 * 2)
# ```
#
# In the example above marked with _SEE NOTE BELOW_, the actual result of the multiplication is `6.6000000000000005`. This is due to rounding errors that you can encounter when performing arithmetic operations.
# ---
#
# ### Order of Mathematical Operations
#
# In Python, as in traditional mathematics, an order of operations does exist. The expressions are not truly read from left to right. The operators will be evaluated in order of precedence. You can use the common technique for remembering the order of arithmetic operations with the abbreviation `PEMDAS`.
#
# `PEMDAS` stands for:
#
# 1. <b>P</b>arentheses (simplify inside of them)
# 2. <b>E</b>xponents
# 3. <b>M</b>ultiplication and <b>D</b>ivision (from left to right)
# 4. <b>A</b>ddition and <b>S</b>ubtraction (from left to right)
#
# If two operators share an operand the operator with the higher precedence goes first:
#
# ```python
# a + b * c
# ```
#
# The above expression would be treated like `a + (b * c)`, because the multiplication operator has the higher precedence.
#
# Now, you can try the following operations by adding them to your `lesson_2.py` file and running them (remember, save the file, then right-click and select `Run Python File in Terminal` from the popup menu).
#
# ```python
# # expressions within parentheses are evaluated first
# result = (5 * 2) + (4 * 2)
# print(result)
# # after simplifying the expressions within the parentheses...
# # result = (10) + (8) = 18
#
# # ---
#
# # do you understand how the final result, below, is computed?
# result = 2 ** 3 * (5 - (3 - 2)) / 4 + 9 // 4
# print(result)
# # result = 8 * (4) / 4 + 2 = 8 * 1 + 2 = 10.0
# ```
#
# <div class="panel panel-info">
#     <div class="panel-heading">
#         <h3 class="panel-title">Tip!</h3>
#     </div>
#     <div class="panel-body">
#         <p>If you have trouble understanding or remembering the order of operations, you can always use parentheses to force the operations to be performed as desired.</p>
#     </div>
# </div>

# %% [markdown]
# <hr style="height:10px;border-width:0;color:gray;background-color:gray">
#
# # Page 9 - Assignment Operators<a class="anchor" id="DS109L2_page_9"></a>
#
# [Back to Top](#DS109L2_toc)
#
# <hr style="height:10px;border-width:0;color:gray;background-color:gray">

# %% [markdown]
# # Assignment Operators
#
# In Python, *assignment operators* are used to assign values to variables. `a = 10` where `=` is an assignment operator that assigns the value `10` to the variable `a`. There are a few more complex assignment operators as well. Below is a list of the assignment operators and a description followed by a short example.
#
# For this list, assume that variables `a = 5` and `b = 10`.
#
# <table class="table table-striped">
#   <thead>
#     <th>Operator</th>
#     <th>Operation</th>
#     <th>Description</th>
#   </thead>
#   <tbody>
#     <tr>
#       <td style="font-weight:bold; text-align:center;">=</td>
#       <td>Assignment</td>
#       <td>Assigns values from the right side operand to the left side operand.<br/>
#           <code>a = 5</code> : assigns the value of <b>5</b> to the variable <b>a</b><br/>
#           <code>c = a + b</code> : assigns the value of <b>a + b</b> to the variable <b>c</b></td>
#     </tr>
#     <tr>
#       <td style="font-weight:bold; text-align:center;">+=</td>
#       <td>Addition</td>
#       <td>Adds the right operand to the left operand and assigns the result to the left operand.<br/>
#           <code>c += a</code> is equivalent to <b>c = c + a</b></td>
#     </tr>
#     <tr>
#       <td style="font-weight:bold; text-align:center;">-=</td>
#       <td>Subtraction</td>
#       <td>Subtracts the right operand from the left operand and assigns the result to the left operand.<br/>
#           <code>c -= a</code> is equivalent to <b>c = c - a</b></td>
#     </tr>
#     <tr>
#       <td style="font-weight:bold; text-align:center;">*=</td>
#       <td>Multiplication</td>
#       <td>Multiplies the right operand by the left operand and assigns the result to the left operand.<br/>
#           <code>c *= a</code> is equivalent to <b>c = c * a</b></td>
#     </tr>
#     <tr>
#       <td style="font-weight:bold; text-align:center;">/=</td>
#       <td>Division</td>
#       <td>Divides the left operand by the right operand and assigns the result to the left operand.<br/>
#           <code>c /= a</code> is equivalent to <b>c = c / a</b></td>
#     </tr>
#     <tr>
#       <td style="font-weight:bold; text-align:center;">%=</td>
#       <td>Modulo</td>
#       <td>Gets the modulus of the two operands and assigns the result to the left operand.<br/>
#           <code>c %= a</code> is equivalent to <b>c = c % a</b></td>
#     </tr>
#     <tr>
#       <td style="font-weight:bold; text-align:center;">//=</td>
#       <td>Floor division</td>
#       <td>Performs a floor division and assigns the result to the left operand.<br/>
#           <code>c //= a</code> is equivalent to <b>c = c // a</b></td>
#     </tr>
#     <tr>
#       <td style="font-weight:bold; text-align:center;">**=</td>
#       <td>Exponential</td>
#       <td>Performs an exponential calculation and assigns the result to the left operand.<br/>
#           <code> c **= a</code> is equivalent to <b>c = c ** a</b></td>
#     </tr>
#   </tbody>
# </table>
#
# ---
#
# ## Code Examples
#
# Below are some assignment operations that you can try. If you look closely, you will see that the value of `c` is not reset; the value is continually modified as the code progresses. There is one exception, however, where the value of `c` is set to `2` before the final exponential operation.
#
# ```python
# a = 15
# b = 5
# c = 0
#
# c = a + b
# print("1. C =", c)
#
# c += a
# print("2. C =", c)
#
# c *= a
# print("3. C =", c)
#
# c /= a
# print("4. C =", c)
#
# c %= a
# print("5. C =", c)
#
# c //= b
# print("6. C =", c)
#
# c = 2
# c **= a
# print("7. C =", c)
# ```
#
# **OUTPUT:**
#
# ```html
# 1. C = 20
# 2. C = 35
# 3. C = 525
# 4. C = 35.0
# 5. C = 5.0
# 6. C = 1.0
# 7. C = 32768
# ```

# %% [markdown]
# <hr style="height:10px;border-width:0;color:gray;background-color:gray">
#
# # Page 10 - Comparison Operators<a class="anchor" id="DS109L2_page_10"></a>
#
# [Back to Top](#DS109L2_toc)
#
# <hr style="height:10px;border-width:0;color:gray;background-color:gray">

# %% [markdown]
# # Comparison Operators
#
# Another type of operator is a *comparison operator*. These operators are used to compare two values, such as determining if the variables are equal. These operators can also be referred to as _relational_ operators. The _result_ of an expression using a comparison operator is a boolean value.
#
# <table class="table table-striped">
#   <thead>
#     <th>Operator</th>
#     <th>Comparison</th>
#     <th>Description</th>
#   </thead>
#   <tbody>
#     <tr>
#       <td style="font-weight:bold; text-align:center;">==</td>
#       <td>Equals</td>
#       <td>If the values of the two operands are equal, then the condition becomes true.<br/>
#           <code>3 == 3</code> would equal <code>True</code>, but <code>3 == 2</code> is <code>False</code></td>
#     </tr>
#     <tr>
#       <td style="font-weight:bold; text-align:center;">!=</td>
#       <td>Does not equal</td>
#       <td>If the values of the two operands are <b>not</b> equal, then the condition becomes true.<br/>
#           <code>2 != 5</code> would equal <code>True</code>, because 2 does not equal 5</td>
#     </tr>
#     <tr>
#       <td style="font-weight:bold; text-align:center;">&gt;</td>
#       <td>Is greater than</td>
#       <td>If the value of the right operand is greater than the left operand, then the condition becomes true.<br/>
#           <code>5 > 2</code> would be <code>True</code>, because 5 is greater than 2</td>
#     </tr>
#     <tr>
#       <td style="font-weight:bold; text-align:center;">&lt;</td>
#       <td>Is less than</td>
#       <td>If the value of the right operand is less than the left operand, then the condition becomes true.<br/>
#           <code>2 < 2</code> would be <code>False</code>, because 2 is <b>not</b> less than 2<br/>
#           <code>2 < 5</code> would be <code>True</code>, because 2 is less than 5</td>
#     </tr>
#     <tr>
#       <td style="font-weight:bold; text-align:center;">&gt;=</td>
#       <td>Is greater than <b>or</b> equals</td>
#       <td>If the value of the right operand is greater than or equal to the left operand, then the condition becomes true.<br/>
#           <code>5 >= 2</code> would be <code>True</code>, because 5 is greater than <b>or</b> equal to 2<br/></td>
#     </tr>
#     <tr>
#       <td style="font-weight:bold; text-align:center;">&lt;=</td>
#       <td>Is less than <b>or</b> equals</td>
#       <td>If the value of the right operand is less than or equal to the left operand, then the condition becomes true.<br/>
#           <code>2 <= 2</code> would be <code>True</code>, because 2 is less than <b>or</b> equal to 2<br/></td>
#     </tr>
#   </tbody>
# </table>
#
# ---
#
# ## Code Examples
#
# Here are some code examples you can try:
#
# ```python
# my_burger_price = 15
#
# is_fifteen_dollars = my_burger_price == 15
# # is_fifteen_dollars = `True` - price equals 15
#
# is_not_twenty_dollars = my_burger_price != 20
# # is_not_twenty_dollars = `True` - price does not equal 20
#
# is_affordable = my_burger_price <= 10
# # is_affordable = `False` - price is NOT less than or equal to 10
#
# is_pricey = my_burger_price >= 15
# # is_pricey = `True` - price is greater than or equal to 15
#
# your_burger_price = 20
#
# my_burger_costs_more = my_burger_price > your_burger_price
# # my_burger_costs_more = `False` - your price is greater than mine
#
# my_burger_costs_less = my_burger_price < your_burger_price
# # my_burger_costs_less = `True` - my price is less than yours
# ```
#
# ---
#
# ## Comparison Operators with Strings
#
# You can use comparison operators with strings in addition to numbers:
#
# ```python
# my_name = "Sally"
# your_name = "Billy"
# some_name = "Sally"
#
# print(my_name == your_name)
# print(my_name != your_name)
# print(some_name == my_name)
#
# print("---")
#
# my_name = "Joe"   # uppercase j
# some_name = "joe" # lowercase j
#
# print(my_name == some_name)
# print(my_name.upper() == some_name.upper())
# ```
#
# **OUTPUT**:
# ```
# False
# True
# True
# ---
# False
# True
# ```
#
# <div class="panel panel-info">
#     <div class="panel-heading">
#         <h3 class="panel-title">Tip!</h3>
#     </div>
#     <div class="panel-body">
#         <p>The assignment operator <code>=</code> is not the same as the comparison operator <code>==</code>. The double equals is for string comparisons, while the equals is for numeric comparisons.</p>
#     </div>
# </div>

# %% [markdown]
# <hr style="height:10px;border-width:0;color:gray;background-color:gray">
#
# # Page 11 - Logical Operators<a class="anchor" id="DS109L2_page_11"></a>
#
# [Back to Top](#DS109L2_toc)
#
# <hr style="height:10px;border-width:0;color:gray;background-color:gray">

# %% [markdown]
# # Logical Operators
#
# Earlier, you learned about comparison operators, such as `==,` `!=,` and <code>&lt;=</code>. The result of an operation using a comparison operator is a boolean; it either results in `True` or `False`. So, for instance, `person_age < 10` is an operation using the less than operator, and the result will be true if `person_age` is less than 10, otherwise false. But what happens if you need to test for multiple conditions? Just like multiple event probability, where you can make use of your boolean operators of "and", "or", and "not", you can use them in Python as well.  You'll start by working with `and`.
#
# ---
# ## and
#
# In Python, you can test for multiple conditions using a *logical operator*. For example, say you need to know whether someone can watch a movie. The movie is rated R, so they must be at least 18 years of age. They must also have enough money to pay for the ticket. Take a look at the code below, which combines these conditions:
#
# ```python
# # details of the person who wants to watch the movie
# person_age = 17
# person_money = 25
#
# # the requirements to watch the movie
# age_restriction = 18
# movie_price = 10
#
# # conditions
# is_old_enough = person_age >= age_restriction
# has_enough_money = person_money >= movie_price
#
# # two conditions combined using 'and'
# can_watch_movie = is_old_enough and has_enough_money
# print(can_watch_movie)
#
# # the output is False, because the person's age is less than the required age
# ```
#
# In the code above, `and` is used to combine the two conditions. The final check (`can_watch_movie`) basically says:
#
# > The person can watch the movie if they're old enough AND they have enough money.
#
# When using the `and` logical operator, you are not limited to only two conditions. For instance, this code adds a third condition:
#
# ```python
# # multiple conditions
# result = (10 > 3) and (3 < 9) and ("this" != "that")
# ```

# %% [markdown]
# <hr style="height:10px;border-width:0;color:gray;background-color:gray">
#
# # Page 12 - Logical Operator - or<a class="anchor" id="DS109L2_page_12"></a>
#
# [Back to Top](#DS109L2_toc)
#
# <hr style="height:10px;border-width:0;color:gray;background-color:gray">

# %% [markdown]
# # or
#
# What if only one condition of multiple needs to be true? In that case, you would use the `or` logical operator. For instance, this code will allow someone to see hang out if the either have $25 or are a friend. They don't need to be both a friend and have the money; just one or the other will do.
#
# ```python
# amount_of_money = 10
# is_a_friend = True
#
# can_hangout_with_me = amount_of_money >= 25 or is_a_friend
# print(can_hangout_with_me)
#
# # the output is `True`, because although they don't have enough money, they are a friend
# ```

# %% [markdown]
# <hr style="height:10px;border-width:0;color:gray;background-color:gray">
#
# # Page 13 - Logical Operator - not<a class="anchor" id="DS109L2_page_13"></a>
#
# [Back to Top](#DS109L2_toc)
#
# <hr style="height:10px;border-width:0;color:gray;background-color:gray">

# %% [markdown]
# # not
#
# The operator `not` takes a single boolean operand (or expression) and returns `True` if the boolean variable or the result of the boolean expression is `False`. Take a look at the example below:
#
# ```python
# person_age = 12
# is_old_enough = person_age >= 18
#
# must_leave = not is_old_enough
# print(must_leave)
#
# # output is True (must leave), because the person is NOT old enough (age < 18)
# ```
#
# As another example, consider an app that has settings like whether you want sounds played. A boolean variable could be used to store the current setting.
#
# ```python
# settings_sound_on = True
# turn_sound_off = not settings_sound_on
#
# # turn_sound_off will be False, because settings_sound_on = True
# ```

# %% [markdown]
# <hr style="height:10px;border-width:0;color:gray;background-color:gray">
#
# # Page 14 - Combining Logical Operators<a class="anchor" id="DS109L2_page_14"></a>
#
# [Back to Top](#DS109L2_toc)
#
# <hr style="height:10px;border-width:0;color:gray;background-color:gray">

# %% [markdown]
# # Combining Logical Operators
#
# When combining `and` and `or`, you may need to use parentheses in order to ensure that the operations are performed in the appropriate order. This is the order that Python will automatically perform your logical operators, unless you distinctly specify:
#
# * not
# * and
# * or
#
# The `and` logical operator takes precedence over the `or` operator. The `not` operator takes precedence over the other two.
#
# Consider an example where someone can watch a movie if:
# - they are at least 18 years of age, and they have at least $15
# - OR, they are a friend and have at least $5
# - they must NOT have any food, regardless of the above
#
# You can code this into Python in the following way:
#
# ```python
# my_age = 17
# my_money = 7
# is_friend = True
# has_food = False
#
# can_watch_movie = not has_food and ((my_age >= 18 and my_money >= 15) or (is_friend and my_money >= 5))
#
# print(can_watch_movie)
# ```
#
# The first operation performed, above, is the `not has_food`. This condition must always hold true. If it is, then it confirms that either the person is old enough with enough money __OR__ they are a friend with a lower amount of money, but still enough.
#
# If the first check (has_food) were `False`, the remainder of the expressions are not computed, because it would be a waste of time; they are skipped. It knows it will fail immediately.

# %%
try:
    from DS_Students import MultipleChoice  
except:
    # !pip install DS_Students
    from DS_Students import MultipleChoice
from ipynb.fs.full.DS109Questions import *

# %%
try:
    display(L2P14Q1, L2P14Q2, L2P14Q3, L2P14Q4, L2P14Q5, L2P14Q6)
except:
    pass

# %% [markdown]
# <hr style="height:10px;border-width:0;color:gray;background-color:gray">
#
# # Page 15 - Operations Activity<a class="anchor" id="DS109L2_page_15"></a>
#
# [Back to Top](#DS109L2_toc)
#
# <hr style="height:10px;border-width:0;color:gray;background-color:gray">

# %% [markdown]
# Create two variables `a` and `b` and assign values to them using the `=` assignment operator. The value of `a` should be set to `2`, while the value of `b` should be set to `5`.

# %%
a = 2

# %%
b = 5

# %%
print(a)
# Out:
# 2

# %%
print(b)
# Out:
# 5

# %% [markdown]
# <hr style="height:10px;border-width:0;color:gray;background-color:gray">
#
# # Page 16 - Operations Activity II<a class="anchor" id="DS109L2_page_16"></a>
#
# [Back to Top](#DS109L2_toc)
#
# <hr style="height:10px;border-width:0;color:gray;background-color:gray">

# %% [markdown]
# Given the three variables `a`, `b`, and `c`, write an expression using an arithmetic operator that subtracts the value of `b` from `a` and assigns the result to `c`.

# %%
a = 25
b = 19
c = a - b

# %%
print(c)
# Out:
# 6

# %% [markdown]
# <hr style="height:10px;border-width:0;color:gray;background-color:gray">
#
# # Page 17 - Operations Activity III<a class="anchor" id="DS109L2_page_17"></a>
#
# [Back to Top](#DS109L2_toc)
#
# <hr style="height:10px;border-width:0;color:gray;background-color:gray">

# %% [markdown]
# Given the three variables `a`, `b`, and `c`, write an expression using an arithmetic operator that adds `a` to `b` and assigns the result to `c`.

# %%
a = 5
b = 7
c = a + b

# %%
print(c)
# Out:
# 12

# %% [markdown]
# <hr style="height:10px;border-width:0;color:gray;background-color:gray">
#
# # Page 18 - Indentation<a class="anchor" id="DS109L2_page_18"></a>
#
# [Back to Top](#DS109L2_toc)
#
# <hr style="height:10px;border-width:0;color:gray;background-color:gray">

# %% [markdown]
# # Indentation
#
# Now that you've learned about boolean values and comparison operators, you can make decisions and control the flow of your programming. However, before you dive into decision-making, you need to understand how indentation works in Python.
#
# In Python, whitespace is extremely important. The whitespace at the beginning of a line &mdash; which is referred to as *indentation*` &mdash; is what indicates which blocks of code go together. Indentation, which is just spaces or tabs at the beginning of a line, is used to determine the grouping of statements.
#
# What this means is that statements that go together must have the same indentation. Each set of statements is referred to as a block. If you have the indentation wrong, your program will throw an error. Take a look at the example below:
#
# ```python
# my_message = "Hello World"
#   print(my_message)
# ```
#
# **OUTPUT**:
# ```python
# File "/Users/andrewstefanik/Desktop/my_Python/lesson_2.py", line 2
#     print(my_message)
#     ^
# IndentationError: unexpected indent
# ```
#
# When you run the above code, Python will detect an error and output the location and cause of the error. In this case, it is an __IndentationError__ that is caused by the extra whitespace before the line containing the _print_ operation.
#
# <div class="panel panel-info">
#     <div class="panel-heading">
#         <h3 class="panel-title">Tip!</h3>
#     </div>
#     <div class="panel-body">
#       <p>When writing Python code, the official recommendation is that indentation should be four spaces. With nested indentations, each indentation should be four spaces.</p>
#     </div>
# </div>

# %% [markdown]
# <hr style="height:10px;border-width:0;color:gray;background-color:gray">
#
# # Page 19 - Decision-Making<a class="anchor" id="DS109L2_page_19"></a>
#
# [Back to Top](#DS109L2_toc)
#
# <hr style="height:10px;border-width:0;color:gray;background-color:gray">

# %% [markdown]
# # Decision-Making
#
# As you write programs in Python, you will undoubtedly encounter situations that will require making decisions. Programming often involves checking a certain set of conditions and choosing an action based upon those conditions. This is done in code much like in real life. Consider the following example:
#
# > A person can watch a movie __if__ they have $10
#
# This can be translated to Python pretty easily:
#
# ```python
# person_money = 12
#
# if person_money >= 10:
#   print("This person can watch the movie")
# ```
#
# The output of the above code will be "This person can watch the movie." Why? Because they have $12, which is more than $10. The text is printed to the console only if the variable `person_money` has a value that is greater than or equal to 10, because you are only going to execute that command **if** the first statement is true.
#
# What if you changed the value of `person_money` to 8, as shown below?
#
# ```python
# person_money = 8
#
# if person_money >= 10:
#   print("This person can watch the movie")
# ```
#
# Well, nothing gets printed to the console. But why?
#
# The condition test of whether `person_money >= 10` fails, so the line to print is skipped. This is how `if` statements work. The thing only happens when the condition is true.
#
# ---
#
# ## General `if` syntax:
#
# When using `if`, the syntax is the following:
#
# ```
# if <condition>:
#   <operations>
# ```
#
# The above is generic code, so it won't run.  But it gives you the general format of how things should be written, and you will fill in the `<>` with your own conditions and operations. You will always start with the keyword `if`, and then follow that with the condition to test.  In the earlier example, the condition that was being tested was whether `person_money` was at least $10 or more.
#
# Following the condition, you'll find a colon (`:`). A colon is required after the `if` and condition tests, or it won't run.  Python will be thinking that everything following is conditional, and will never recognize that it needs to stop and do the operation without that colon! You can think of the colon like a stopsign.  Without stop signs on the road, everyone would just continue driving forward forever without recognizing that there is a need to stop driving, look both ways, and then proceed in another direction.
#
# Remember that the block of operations to be performed __IF__ the condition is met (true) is indented to the right. Python will also be angry if you forget that indent; luckily VSC will indent for you automatically when you include the colon.  So get the first part right, and you should automatically get the second part right as well!
#
# ---
#
# ## else
#
# In the example above, the print operation is only performed if the condition is true. So, what if you wanted to print something if the condition fails? Like to tell them "Sorry, but you don't have enough money." This is where the `else` keyword comes into play.
#
# ```python
# person_money = 8
#
# if person_money >= 10:
#   print("This person can watch the movie")
# else:
#   print("Sorry, but you don't have enough money")
# ```
#
# The output of the above code will be `"Sorry, but you don't have enough money"`, because `person_money` is __not__ greater than or equal to 10. It is something else.
#
# So, both possible outcomes are handled above: they either have enough money, or they don't. Either way, the appropriate message is printed to the console.
#
# ---
#
# ### Syntax for else
#
# The `else` statement is aligned with the `if` statement (the indentation is the same). In addition, the operation that is performed for the `else` block is indented like for the `if` statement.
#
# The `else` statement also requires the use of the colon after the keyword.
#
# ---
#
# ## elif
#
# Finally, if there are more than two possible outcomes, you can use the `elif` statement. Consider the following scenario:
#
# > If your age is 18 or higher, you can watch R-rated movies. If your age is 13 or higher, you can watch PG13-rated movies. If your age is less than 13, you can only watch G-rated movies.
#
# Below, you'll find the Python code to represent the above:
#
# ```python
# person_age = 18
#
# if person_age >= 18:
#   print("I can watch an R-rated movie")
# elif person_age >= 13:
#   print("I can watch a PG13-rated movie")
# else:
#   print("I can watch a G-rated movie")
# ```
#
# The `elif` statement is essentially a combination of two words: _else_ and _if_. Like an `if` statement, a condition test must follow the `elif` statement. And, like both `if` and `else`, a colon must reside at the end of the line for `elif` statements. Similarly, the operations must be indented like the other blocks.
#
# The order in which you test the conditions can matter. The output from the above example is "I can watch an R-rated movie", which is what you would expect given the value of `person_age` (18). However, what happens if you change the order of condition tests?
#
# ```python
# person_age = 13
#
# if person_age >= 13:
#   print("I can watch a PG13-rated movie")
# elif person_age >= 18:
#   print("I can watch an R-rated movie")
# else:
#   print("I can watch a G-rated movie")
# ```
#
# The output of the above would be "I can watch a PG13-rated movie", which is different than the previous example. This is due to the change in sequence of the checks. Since the first condition (`person_age >= 13`) is true, it succeeds, printing out the message about the PG-13 movie. The remainder of the checks are skipped, because the first one was satisfied.
#
# Now, try the following:
#
# ```python
# person_age = 5
#
# if person_age >= 18:
#   print("I can watch an R-rated movie")
# elif person_age >= 13:
#   print("I can watch a PG13-rated movie")
# else:
#   print("I can watch a G-rated movie")
# ```
#
# In the above code, the first test is whether the age is >= 18, which is false (5 < 18). So, it moves to the next test. However, this test fails, as well, since 5 is less than 13. Thus, the final `else` block is hit and the print operation is performed (there is no test for the final else).

# %% [markdown]
# <hr style="height:10px;border-width:0;color:gray;background-color:gray">
#
# # Page 20 - Multiple Decision Making Blocks per Variable<a class="anchor" id="DS109L2_page_20"></a>
#
# [Back to Top](#DS109L2_toc)
#
# <hr style="height:10px;border-width:0;color:gray;background-color:gray">

# %% [markdown]
# # Multiple Decision Making Blocks per Variable
#
# Another example, but with multiple if/elif/else blocks:
#
# ```python
# person_age = 16
#
# # first if/elif/else block
# if person_age >= 18:
#   print("I can watch an R-rated movie")
# elif person_age >= 13:
#   print("I can watch a PG13-rated movie")
# else:
#   print("I can watch a G-rated movie")
#
# # second if/else block
# if person_age >= 16:
#   print("I can drive!")
# else:
#   print("I need to walk")
# ```
#
# What do you think the output will be?

# %%
person_age = 16

# first if/elif/else block
if person_age >= 18:
  print("I can watch an R-rated movie")
elif person_age >= 13:
  print("I can watch a PG13-rated movie")
else:
  print("I can watch a G-rated movie")

# second if/else block
if person_age >= 16:
  print("I can drive!")
else:
  print("I need to walk")
# Out:
# I can watch a PG13-rated movie
# I can drive!

# %% [markdown]
# **OUTPUT**:
#
# ```text
# I can watch a PG13-rated movie
# I can drive!
# ```
#
# As you can see from the output of the above code, the two if/elif/else blocks are separate. They are not related. That is why there are two lines of text printed to the output.
#
# ---
#
# ## Combining Decision Making Blocks
#
# Next, say you need to perform several operations if a condition is true. All you need to do is maintain the indentation.
#
# ```python
# person_age = 18
#
# if person_age >= 18:
#   print("I can watch an R-rated movie")
#   print("I can drive!")
# elif person_age >= 16:
#   print("I can watch a PG13-rated movie")
#   print("I can drive!")
# else:
#   print("I need my mommy")
# ```
#
# **OUTPUT**:
#
# ```text
# I can watch an R-rated movie
# I can drive!
# ```
#
# Notice how there are two `print()` statements after the first and second `if`s? Both will be performed if the test succeeds (the expression results in a value of `True`).
#
# ---

# %% [markdown]
# ## Combining Logical Operands and Decision Making
#
# Finally, try the next example, which combines multiple tests for the `if` and `elif` statements:
#
# ```python
# person_age = 15
# has_car = False
# mom_can_drive = True
# outcome = ""
#
# if person_age >= 18 and has_car:
#   outcome = "I can go and see an R-rated movie"
# elif person_age >= 13 and mom_can_drive:
#   outcome = "Mom can take me to see a PG13-rated movie"
# else:
#   outcome = "I'm stuck at home today"
#
# print(outcome)
# ```

# %%
person_age = 15
has_car = False
mom_can_drive = True
outcome = ""

if person_age >= 18 and has_car:
  outcome = "I can go and see an R-rated movie"
elif person_age >= 13 and mom_can_drive:
  outcome = "Mom can take me to see a PG13-rated movie"
else:
  outcome = "I'm stuck at home today"

print(outcome)
# Out:
# Mom can take me to see a PG13-rated movie

# %% [markdown]
# As you can see above, you can test against multiple conditions. The output will be `"Mom can take me to see a PG13-rated movie"`. Why?
#
# __Test 1__: Is the person's age 18 or more? Does this person have a car? If both are true, then set the value of `outcome` to "I can go and see an R-rated movie". If either are false, go to the next test.
#
# __Test 2__: Is the person's age 13 or more? Can their mother drive them to the cinema? If both are true, then set the value of `outcome` to "Mom can take me to see a PG13-rated movie". If either are false, go to the final `else` block.
#
# __Else__: If both tests fail, the else block will set the value of `outcome` to "I'm stuck at home today".
#
# What do you think would be the output if the age is changed to 18?
#
# Congratulations! You've now learned how to control the flow of your Python application by using decision-making via if/elif/else blocks with boolean expressions.
#
# <div class="panel panel-success">
#     <div class="panel-heading">
#         <h3 class="panel-title">Additional Info!</h3>
#     </div>
#     <div class="panel-body">
#         <p>You may want to watch this <a href="https://vimeo.com/426836051"> recorded live workshop </a> that goes over the concept of if/elif/else. </p>
#     </div>
# </div>

# %% [markdown]
# <hr style="height:10px;border-width:0;color:gray;background-color:gray">
#
# # Page 21 - Key Terms<a class="anchor" id="DS109L2_page_21"></a>
#
# [Back to Top](#DS109L2_toc)
#
# <hr style="height:10px;border-width:0;color:gray;background-color:gray">

# %% [markdown]
# # Key Terms
#
# Below is a list and short description of the important keywords learned in this lesson. Please read through and go back and review any concepts you do not fully understand. Great Work!
#
# <table class="table table-striped">
#     <tr>
#         <th>Keyword</th>
#         <th>Description</th>
#     </tr>
#     <tr>
#         <td style="font-weight: bold;" nowrap>Concatenation</td>
#         <td>Combining strings together.</td>
#     </tr>
#     <tr>
#         <td style="font-weight: bold;" nowrap>Parameters</td>
#         <td>Input to a function.</td>
#     </tr>
#     <tr>
#         <td style="font-weight: bold;" nowrap>Substring</td>
#         <td>A portion of a string.</td>
#     </tr>
#     <tr>
#         <td style="font-weight: bold;" nowrap>Logical Operator</td>
#         <td>Boolean operators of and / or / not.</td>
#     </tr>
#     <tr>
#         <td style="font-weight: bold;" nowrap>Indentation</td>
#         <td>Blank space at the beginning of a line.</td>
#     </tr>
#     <tr>
#         <td style="font-weight: bold;" nowrap>IndentationError:</td>
#         <td>An error message you will get when you have the wrong indentation in your code.</td>
#     </tr>
# </table>
#
#
# ---
#
# ## Key Python Code
#
# <table class="table table-striped">
#     <tr>
#         <th>Keyword</th>
#         <th>Description</th>
#     </tr>
#     <tr>
#         <td style="font-weight: bold;" nowrap>+ </td>
#         <td>Used to combine strings or perform addition on numbers.</td>
#     </tr>
#     <tr>
#         <td style="font-weight: bold;" nowrap>str()</td>
#         <td>Turns integers into strings.</td>
#     </tr>
#     <tr>
#         <td style="font-weight: bold;" nowrap>str.format()</td>
#         <td>Tells Python what to expect in regards to string variables.</td>
#     </tr>
#     <tr>
#         <td style="font-weight: bold;" nowrap>lower()</td>
#         <td>Makes strings all lower case.</td>
#     </tr>
#     <tr>
#         <td style="font-weight: bold;" nowrap>upper()</td>
#         <td>Makes strings all upper case.</td>
#     </tr>
#       <tr>
#         <td style="font-weight: bold;" nowrap>.replace()</td>
#         <td>Re-write strings with another word.</td>
#     </tr>
#       <tr>
#         <td style="font-weight: bold;" nowrap>split()</td>
#         <td>Breaking strings into substrings with a separator.</td>
#     </tr>
#     <tr>
#         <td style="font-weight: bold;" nowrap>and </td>
#         <td>Combines two conditions so that you need both.</td>
#     </tr>
#     <tr>
#         <td style="font-weight: bold;" nowrap>or </td>
#         <td>Combines two conditions so that you need either condition.</td>
#     </tr>
#     <tr>
#         <td style="font-weight: bold;" nowrap>not</td>
#         <td>Returns things that meet neither condition.</td>
#     </tr>
#     <tr>
#         <td style="font-weight: bold;" nowrap>if</td>
#         <td>Used to specify a condition.</td>
#     </tr>
#     <tr>
#         <td style="font-weight: bold;" nowrap>else</td>
#         <td>Used to specify the consequences of a condition.</td>
#     </tr>
#     <tr>
#         <td style="font-weight: bold;" nowrap>elif</td>
#         <td>Used to specify the consequences of not meeting a condition.</td>
#     </tr>
# </table>

# %% [markdown]
# <hr style="height:10px;border-width:0;color:gray;background-color:gray">
#
# # Page 22 - Lesson 2 Hands-On<a class="anchor" id="DS109L2_page_22"></a>
#
# [Back to Top](#DS109L2_toc)
#
# <hr style="height:10px;border-width:0;color:gray;background-color:gray">

# %% [markdown]
# For your Lesson 2 Hands-On, you will be practicing your new skills with operators, string concatenation, and control flow. For this project, you will be creating a new directory, so please follow the below setup instructions. This Hands-On **will** be graded, so be sure you complete all requirements. See [Hands On Helper Example](Examples/DS109L02-hands-on-helper.ipynb).
#
# ---
#
# ## Setup
#
# 1. First, open up your command prompt/terminal
# 2. Within your command prompt/terminal, run the following command:
#     ```text
#     cd desktop
#     ```
# 3. Next, run the following:
#     ```text
#     cd python_course
#     ```
# 4. Run the following to create a new directory for this project:
#     ```text
#     mkdir lesson_two_handson
#     ```
# 5. Open up a new window in VSCode.
# 6. Click on the "Explorer" button on the left-hand side of the VSCode window.
# 7. Click the `Open Folder` button.
# 8. Select the `lesson_two_handson` directory within the `python_course` folder on your Desktop. Click the `Open` button.
# 10. Create a new file named `main.py` by one of the following three ways:
#     - To the right of __LESSON_TWO_HANDSON__ in the EXPLORER is a button that looks like a piece of paper with a plus symbol in its top-left corner. If you hover your mouse over this button for a moment, a popup will appear indicating that this button will create a new file.
#     - Choose `File > New File` from the app's menu.
#     - Press `Control + N` in Windows or `Command + N` on a Mac (the plus means "and at the same time").
#
# Now you are ready to get started on your Lesson 2 Hands-On!
#
# ---
#
# ## Requirements
#
# This hands-on is broken into three parts. Please complete each part within your `main.py` file.
#
# ---
# ## Part 1
#
# Create a program that will concatenate string variables together to form your birthday.
#
# 1. Create three variables named `day`, `month` and `year`
# 2. Concatenate each of these variables to create your full birthday.
#     > Hint! You cannot concatenate strings and integers, so all variables will need to be strings
# 3. Assign the concatenation to a fourth variable named `my_birthday`.
# 4. Finally, `print` the variable `my_birthday` to see if you have the format identical to the one in the example below:
#     - For example, if your birthday is on November 11th of 1991, then the format/output should be `November 11, 1991`
#
# <div class="panel panel-info">
#     <div class="panel-heading">
#         <h3 class="panel-title">Tip!</h3>
#     </div>
#     <div class="panel-body">
#         <p>To add spaces between each word as you concatenate them, use double quotes with a space in between them like so: <code>" "</code>.</p>
#     </div>
# </div>
#
# ---
# ## Part 2
#
# 1. Concatenate the variables `first`, `second`, `third`, and `fourth` and set this concatenation to the variable `final`:
#     ```python
#     first = "happy"
#     second = "birthday"
#     third = "to"
#     fourth = "you"
#
#     final =
#     ```
# 2. Print the `final` variable, but all words should be uppercase.
# 3. Run this code in the VSCode terminal.
#     - The output should be `HAPPY BIRTHDAY TO YOU`.
#
# ---
# ## Part 3
#
# Finally, add code to your program that determines if the given age allows the attendee to see the movie, printing out a specific message based on the age. There should be four possible outputs:
#
# - If under the age of 10, print `Not permitted`
# - If under the age of 15, print `Permitted with a parent`
# - If under the age of 18, print `Permitted with anyone over 18`
# - If 18 or over, print `Permitted to attend alone`
#
# Below is some code to get you started:
#
# ```python
# age = 15
#
# if
# ```
#
# <div class="panel panel-info">
#     <div class="panel-heading">
#         <h3 class="panel-title">Tip!</h3>
#     </div>
#     <div class="panel-body">
#         <p>You may need more than one <code>elif</code> statement to capture each condition, and the sequence matters.</p>
#     </div>
# </div>
#
# <div class="panel panel-danger">
#     <div class="panel-heading">
#         <h3 class="panel-title">Caution!</h3>
#     </div>
#     <div class="panel-body">
#         <p>Be sure to zip and submit your entire <code>lesson_two_handson</code> directory when finished!</p>
#     </div>
# </div>
