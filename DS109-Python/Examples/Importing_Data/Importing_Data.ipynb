# %% [markdown]
# # To open jupyter lab:
# - Open the command prompt
# - Type: jupyter lab
# - Press Enter
# # To run a cell (line):
# - Press Shift + Enter

# %%
from PIL import Image                                                                                
img = Image.open('../Importing_Data/Command_Prompt.png')
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=452x182 at 0x1B97F0E85E0>

# %% [markdown]
# ##### Make sure to hit "Enter" or else... it'll be New Year's before you know it!

# %%
img = Image.open('../Importing_Data/When_Enter.png')
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1096x599 at 0x1B97F0E86A0>

# %% [markdown]
# #### This means that jupyter lab is opening. Please be patient! :-)

# %%
img = Image.open('../Importing_Data/Jupyter_Open.png')
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1916x930 at 0x2AF7B935D20>

# %% [markdown]
# ##### You are in the right place when you see this.
# ### To begin coding, click on Python.

# %% [markdown]
# # Downloading a package for the very first time

# %%
pip install pandas

# %% [markdown]
# ##### To install any package, it's a good idea to follow the format below:
# ##### pip install packageName# Importing my packages

# %%
import pandas as pd

# %% [markdown]
# # Importing Excel Dataset

# %%
# To import an excel dataset file
babies = pd.read_excel ("C:/Users/jesse/Documents/Project/babies.xlsx")
babies
# Out:
#         Name        First   Birthday                       StreetAddress  \
# 0     Potter      Alec J. 2017-11-06            229-8390 Dignissim. Road
# 1    Mcclure    Lucius S. 2018-08-14         P.O. Box 593, 7892 Nunc St.
# 2     Farley     Hilel Y. 2017-12-07                     3859 Tellus Rd.
# 3   Cummings   Randall W. 2018-03-07        Ap #293-6684 Lobortis Street
# 4     Lester     Bruce I. 2018-01-14                 495-3192 Dictum St.
# ..       ...          ...        ...                                 ...
# 95     Walls    Judith G. 2018-03-04             Ap #870-3273 Tempor Rd.
# 96     Cantu    Xandra X. 2018-06-08                      4937 Justo Ave
# 97   Griffin    Curran I. 2018-04-15  P.O. Box 408, 9749 Posuere, Avenue
# 98  Hamilton   Mufutau R. 2019-06-01      P.O. Box 609, 3807 Cursus, St.
# 99      Owen    Lucian L. 2017-12-07       P.O. Box 868, 7319 Cursus Rd.
#
#         City  Zipcode  Weight  Height     HospitalID ParentPhoneNumber  \
# ...

# %% [markdown]
# ##### To view the data, you simply type the name you chose to call it by as I did above.

# %% [markdown]
# # Importing CSV Dataset

# %%
# To import a csv dataset file
babies = pd.read_csv ("C:/Users/jesse/Documents/Project/vaccinations.csv")
babies
# Out:
#           location iso_code        date  total_vaccinations  \
# 0      Afghanistan      AFG  2021-02-22                 0.0
# 1      Afghanistan      AFG  2021-02-23                 NaN
# 2      Afghanistan      AFG  2021-02-24                 NaN
# 3      Afghanistan      AFG  2021-02-25                 NaN
# 4      Afghanistan      AFG  2021-02-26                 NaN
# ...            ...      ...         ...                 ...
# 84602     Zimbabwe      ZWE  2022-02-20           7823894.0
# 84603     Zimbabwe      ZWE  2022-02-21           7829096.0
# 84604     Zimbabwe      ZWE  2022-02-22           7836325.0
# 84605     Zimbabwe      ZWE  2022-02-23           7847314.0
# 84606     Zimbabwe      ZWE  2022-02-24           7858794.0
#
#        people_vaccinated  people_fully_vaccinated  total_boosters  \
# 0                    0.0                      NaN             NaN
# 1                    NaN                      NaN             NaN
# ...

# %% [markdown]
# ##### To view the data, you simply type the name you chose to call it by as I did above.

# %% [markdown]
# # Tips when using jupyter lab:
# - Please keep the Command Prompt (Windows)/Terminal open (MAC) along with jupyter lab because they are connected.
# - If you see a "Connection Error":
#     - go to the Kernel Tab up on top and select "Shut Down All Kernels"
#     - close the Command Prompt/Terminal
#     - re-open everything back up (see instructions at the top)
#     - make sure to *always* save your work!
#     -Happy Coding!
