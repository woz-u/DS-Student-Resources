# %%
import pandas as pd

# %% [markdown]
# # To Read in the Data as a CSV

# %%
diabetes = pd.read_csv('../Data/diabetes.csv')

# %% [markdown]
# # To look at the first seven rows

# %%
diabetes.head(7)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
# 5            5      116             74              0        0  25.6
# 6            3       78             50             32       88  31.0
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1
# 5                     0.201   30        0
# 6                     0.248   26        1

# %% [markdown]
# # To look at the last ten rows

# %%
diabetes.tail(10)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 758            1      106             76              0        0  37.5
# 759            6      190             92              0        0  35.5
# 760            2       88             58             26       16  28.4
# 761            9      170             74             31        0  44.0
# 762            9       89             62              0        0  22.5
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 758                     0.197   26        0
# 759                     0.278   66        1
# 760                     0.766   22        0
# ...

# %% [markdown]
# # To determine the number of rows the datset has

# %%
len(diabetes)
# Out:
# 768

# %% [markdown]
# # To determine the number of columns the dataset has

# %%
len(diabetes.columns)
# Out:
# 9

# %%
diabetes.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %% [markdown]
# # How many pregnancies were zero?
# 111

# %%
diabetes.Pregnancies.value_counts()
# Out:
# 1     135
# 0     111
# 2     103
# 3      75
# 4      68
# 5      57
# 6      50
# 7      45
# 8      38
# 9      28
# 10     24
# 11     11
# 13     10
# 12      9
# 14      2
# 15      1
# 17      1
# Name: Pregnancies, dtype: int64

# %% [markdown]
# # What is the mean and standard deviation of Age?
# The mean is 33, the standard deviation is 11.76

# %%
diabetes.Age.describe()
# Out:
# count    768.000000
# mean      33.240885
# std       11.760232
# min       21.000000
# 25%       24.000000
# 50%       29.000000
# 75%       41.000000
# max       81.000000
# Name: Age, dtype: float64

# %% [markdown]
# # What is the median Age of diabetes?
# The median Age is 29.

# %%
diabetes.Age.median()
# Out:
# 29.0
