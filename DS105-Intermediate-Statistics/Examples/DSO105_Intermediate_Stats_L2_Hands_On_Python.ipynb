# %% [markdown]
# # DSO105 Intermediate Stats L2 Hands On - Python

# %%
### import packages

import pandas as pd
import numpy as np
import seaborn as sns
from scipy import stats
from scipy.stats import boxcox

# %%
### load data
data = pd.read_csv('../../datasets/Seattle_ParksnRec.csv')

# %%
data.head()
# Out:
#   Geographic Region  Year  # of trips Winter  # of participants Winter  \
# 0           Central  2005                 13                       154
# 1           Central  2006                 17                       229
# 2           Central  2007                 17                       222
# 3           Central  2008                 18                       300
# 4           Central  2009                 18                       276
#
#    # of trips Spring  # of participants Spring  # of trips Summer  \
# 0                 18                       290                 20
# 1                 16                       227                 19
# 2                 15                       244                 13
# 3                 19                       335                 20
# 4                 23                       302                 25
#
#    # of participants Summer  # of trips Fall  # of participants Fall  \
# ...

# %% [markdown]
# ## Transforming Data in Python

# %% [markdown]
# In Python, assess the skew of the distribution and then transform it if necessary for the following variables:
#
# * number of trips Winter
#
# * number of participants Winter
#
# * number of trips Spring
#
# * number of participants Spring
#
# * number of trips Summer
#
# * number of participants Summer
#
# Please make notes about each variable's distribution and the transformation you made in your Python file and submit.

# %% [markdown]
# #### Winter trips

# %%
sns.displot(data = data, x = '# of trips Winter', kde = True)
## looks positively skewed

# %%
data['tripsWinterSQRT'] = np.sqrt(data['# of trips Winter'])

# %%
sns.displot(data = data, x = 'tripsWinterSQRT', kde = True)

# %% [markdown]
# #### Winter participants

# %%
sns.displot(data = data, x = '# of participants Winter', kde = True)
## looks positively skewed

# %%
data['participantsWinterSQRT'] = np.sqrt(data['# of participants Winter'])

# %%
sns.displot(data = data, x = 'participantsWinterSQRT', kde = True)

# %% [markdown]
# #### Spring trips

# %%
sns.displot(data = data, x = '# of trips Spring', kde = True)
## looks positively skewed

# %%
data['tripsSpringSQRT'] = np.sqrt(data['# of trips Spring'])

# %%
sns.displot(data = data, x = 'tripsSpringSQRT', kde = True)

# %% [markdown]
# #### Spring participants

# %%
sns.displot(data = data, x = '# of participants Spring', kde = True)
## looks positively skewed

# %%
data['participantsSpringSQRT'] = np.sqrt(data['# of participants Spring'])

# %%
sns.displot(data = data, x = 'participantsWinterSQRT', kde = True)

# %% [markdown]
# #### Summer trips

# %%
sns.displot(data = data, x = '# of trips Summer', kde = True)
## looks positively skewed - though the most normally distributed looking one yet!

# %%
data['tripsSummerSQRT'] = np.sqrt(data['# of trips Summer'])

# %%
sns.displot(data = data, x = 'tripsSummerSQRT', kde = True)
## this one is pretty near being approximately normally distributed

# %% [markdown]
# #### Summer participants

# %%
sns.displot(data = data, x = '# of participants Spring', kde = True)
## looks positively skewed

# %%
data['participantsSummerSQRT'] = np.sqrt(data['# of participants Summer'])

# %%
sns.displot(data = data, x = 'participantsSummerSQRT', kde = True)
## looks approximately a little more normal
