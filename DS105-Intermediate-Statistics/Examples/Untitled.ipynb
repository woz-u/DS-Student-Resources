# %%
install.packages("cloglog")
# Out:
# Warning message:
# “package ‘cloglog’ is not available for this version of R
#
# A version of this package for your version of R might be available elsewhere,
# see the ideas at
# https://cran.r-project.org/doc/manuals/r-patched/R-admin.html#Installing-packages”

# %%
# R code
eq = function(x){log(x/(1-x))}
curve(eq, xlab="probability", ylab="l(probability)",col="red",lwd=2)
curve(qnorm,add = T,lty="dashed",col="blue",lwd=2)
curve(cloglog,add=T,lty="dotted",col="green",lwd=2)
abline(v=0.5,lty="dashed",col="grey")
legend("topleft",legend=c("logit","probit","cloglog"),lty = c("solid","dashed","dotted"),col = c("red","blue","green"),lwd=2)
# Out:
# Error in cloglog(x): could not find function "cloglog"
# Traceback:
#
# 1. curve(cloglog, add = T, lty = "dotted", col = "green", lwd = 2)
# 2. eval(expr, envir = ll, enclos = parent.frame())
# 3. eval(expr, envir = ll, enclos = parent.frame())
# plot without title
