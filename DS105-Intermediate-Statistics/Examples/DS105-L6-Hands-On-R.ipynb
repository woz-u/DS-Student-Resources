# %% [markdown]
# # DS105 Intermediate Stats Lesson 6 Hands On Solution

# %%
# Install Packages
install.packages("rcompanion")
install.packages("car")
install.packages("IDPmisc")
install.packages("dplyr")

# %%
# Load Packages
library("rcompanion")
library("car")
library("IDPmisc")
library("dplyr")
# Out:
# Loading required package: carData
#
#
# Attaching package: ‘dplyr’
#
#
# The following object is masked from ‘package:car’:
#
#     recode
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union

# %%
# Load Data 
suicide = read.csv('../Data/suicide.csv')

# %% [markdown]
# ## Number of suicides by generation by country, with country being the repeated factor
#
# ### Check Assumptions

# %%
### Check for Normality
plotNormalHistogram(suicide$suicides.100k.pop)
# Out:
# Plot with title “”

# %%
# use SQRT
suicide$suicides.100k.popSQRT <- sqrt(suicide$suicides.100k.pop)
plotNormalHistogram(suicide$suicides.100k.popSQRT)
# Out:
# Plot with title “”

# %%
# Use Log
suicide$suicides.100k.popLOG <- log(suicide$suicides.100k.pop)

# %%
# omit NAs
suicide4 <- NaRV.omit(suicide)

# %%
plotNormalHistogram(suicide4$suicides.100k.popLOG)
# Out:
# Plot with title “”

# %%
#use Log since it's more normally distributed

# %% [markdown]
# ### Homogeneity of Variance

# %%
leveneTest(suicides.100k.popLOG ~ generation, data=suicide4)
# Out:
# Warning message in leveneTest.default(y = y, group = group, ...):
# “group coerced to factor.”
#       Df   F value  Pr(>F)
# group    5 18.17709 5.712815e-18
#       7201       NA           NA

# %% [markdown]
# #### This failed the assumption, but proceed anyway for learning purposes
#
# ### Sample size -you have more than enough data
#
# ## Run the analysis

# %%
# Out:
# Error in eval(predvars, data, env): object 'weight' not found
# Traceback:
#
# 1. aov(weight ~ group, data = suicide4)
# 2. eval(lmcall, parent.frame())
# 3. eval(lmcall, parent.frame())
# 4. stats::lm(formula = weight ~ group, data = suicide4, singular.ok = TRUE)
# 5. eval(mf, parent.frame())
# 6. eval(mf, parent.frame())
# 7. stats::model.frame(formula = weight ~ group, data = suicide4,
#  .     drop.unused.levels = TRUE)
# 8. model.frame.default(formula = weight ~ group, data = suicide4,
#  .     drop.unused.levels = TRUE)
# 9. eval(predvars, data, env)
# 10. eval(predvars, data, env)

# %%
RManova1 <- aov(suicides.100k.popLOG~(generation*year)+Error(i..country/(year)), suicide4)
summary(RManova1)
# Out:
# Error in eval(predvars, data, env): object 'i..country' not found
# Traceback:
#
# 1. aov(suicides.100k.popLOG ~ (generation * year) + Error(i..country/(year)),
#  .     suicide4)
# 2. eval(ecall, parent.frame())
# 3. eval(ecall, parent.frame())
# 4. stats::lm(formula = suicides.100k.popLOG ~ i..country/(year),
#  .     data = suicide4, singular.ok = TRUE, method = "qr", qr = TRUE)
# 5. eval(mf, parent.frame())
# 6. eval(mf, parent.frame())
# 7. stats::model.frame(formula = suicides.100k.popLOG ~ i..country/(year),
#  .     data = suicide4, drop.unused.levels = TRUE)
# 8. model.frame.default(formula = suicides.100k.popLOG ~ i..country/(year),
#  .     data = suicide4, drop.unused.levels = TRUE)
# 9. eval(predvars, data, env)
# 10. eval(predvars, data, env)
