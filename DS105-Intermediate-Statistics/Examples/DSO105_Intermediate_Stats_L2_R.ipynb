# %% [markdown]
# # DSO105 Intermediate Stats L2 - R

# %% [markdown]
# ## Transformations in R

# %% [markdown]
# ### Visualizing Transformations

# %% [markdown]
# ##### Distribution patterns: skewness and kurtosis
#
#
# <img src="../../media/The-distribution-patterns-Skewness-and-Kurtosis.png" align="left" alt="COE image" width = "600">

# %% [markdown]
# ##### Prescribing transformations
#
#
# <img src="../../media/prescribing-transformations.png" align="left" alt="COE image" width = "600">

# %% [markdown]
# ##### Common transformations
#
#
# <img src="../../media/common-transformations.png" align="left" alt="COE image" width = "600">

# %%
## load in libraries

# %%
install.packages('rcompanion')
install.packages('IDPmisc')
install.packages('readxl')

## install once and load every time

library(rcompanion)
library(IDPmisc)
library(readxl)
# Out:
# Installing package into 'C:/Users/nolan/OneDrive/Documents/R/win-library/4.1'
# (as 'lib' is unspecified)
# package 'rcompanion' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\nolan\AppData\Local\Temp\RtmpGEnhRN\downloaded_packages
# Installing package into 'C:/Users/nolan/OneDrive/Documents/R/win-library/4.1'
# (as 'lib' is unspecified)
# package 'IDPmisc' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\nolan\AppData\Local\Temp\RtmpGEnhRN\downloaded_packages
# Installing package into 'C:/Users/nolan/OneDrive/Documents/R/win-library/4.1'
# (as 'lib' is unspecified)
# package 'readxl' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\nolan\AppData\Local\Temp\RtmpGEnhRN\downloaded_packages

# %%
anime = read.csv('../../datasets/anime.csv')

# %%
head(anime)
# Out:
#   anime_id title                 title_english
# 1 11013    Inu x Boku SS         Inu X Boku Secret Service
# 2  2104    Seto no Hanayome      My Bride is a Mermaid
# 3  5262    Shugo Chara!! Doki    Shugo Chara!! Doki
# 4   721    Princess Tutu         Princess Tutu
# 5 12365    Bakuman. 3rd Season   Bakuman.
# 6  6586    Yume-iro PÃ¢tissiÃ¨re
#   title_japanese
# 1 å¦–ç‹\220Ã—åƒ•SS
# 2 ç\200¬æ\210¸ã\201®èŠ±å«\201
# 3 ã\201—ã‚…ã\201”ã‚­ãƒ£ãƒ©ï¼\201ï¼\201ã\201©ã\201\215ã\201£
# 4 ãƒ—ãƒªãƒ³ã‚»ã‚¹ãƒ\201ãƒ¥ãƒ\201ãƒ¥
# 5 ãƒ\220ã‚¯ãƒžãƒ³ã\200‚
# 6 å¤¢è‰²ãƒ‘ãƒ†ã‚£ã‚·ã‚¨ãƒ¼ãƒ«
#   title_synonyms
# 1 Youko x Boku SS
# 2 The Inland Sea Bride
# 3 Shugo Chara Ninenme, Shugo Chara! Second Year
# 4
# 5 Bakuman Season 3
# 6 Yumeiro Patissiere, YumePati, Dream-Colored Pastry Chef, Yumeiro PÃ¢tissiÃ¨re
#   image_url                                                  type source
# 1 https://myanimelist.cdn-dena.com/images/anime/12/35893.jpg TV   Manga
# 2 https://myanimelist.cdn-dena.com/images/anime/13/58383.jpg TV   Manga
# 3 https://myanimelist.cdn-dena.com/images/anime/11/10645.jpg TV   Manga
# 4 https://myanimelist.cdn-dena.com/images/anime/13/32209.jpg TV   Original
# 5 https://myanimelist.cdn-dena.com/images/anime/6/41845.jpg  TV   Manga
# 6 https://myanimelist.cdn-dena.com/images/anime/12/21674.jpg TV   Manga
#   episodes status          ... broadcast
# 1 12       Finished Airing ... Fridays at Unknown
# 2 26       Finished Airing ... Unknown
# 3 51       Finished Airing ... Unknown
# 4 38       Finished Airing ... Fridays at Unknown
# 5 25       Finished Airing ... Unknown
# 6 50       Finished Airing ... Unknown
#   related
# 1 {'Adaptation': [{'mal_id': 17207, 'type': 'manga', 'url': 'https://myanimelist.net/manga/17207/Inu_x_Boku_SS', 'title': 'Inu x Boku SS'}], 'Sequel': [{'mal_id': 13403, 'type': 'anime', 'url': 'https://myanimelist.net/anime/13403/Inu_x_Boku_SS_Special', 'title': 'Inu x Boku SS Special'}]}
# 2 {'Adaptation': [{'mal_id': 759, 'type': 'manga', 'url': 'https://myanimelist.net/manga/759/Seto_no_Hanayome', 'title': 'Seto no Hanayome'}], 'Sequel': [{'mal_id': 4163, 'type': 'anime', 'url': 'https://myanimelist.net/anime/4163/Seto_no_Hanayome_OVA', 'title': 'Seto no Hanayome OVA'}], 'Side story': [{'mal_id': 5199, 'type': 'anime', 'url': 'https://myanimelist.net/anime/5199/Seto_no_Hanayome_Fan_Disc', 'title': 'Seto no Hanayome Fan Disc'}], 'Alternative version': [{'mal_id': 28385, 'type': 'anime', 'url': 'https://myanimelist.net/anime/28385/Seto_no_Hanayome_Picture_Drama', 'title': 'Seto no Hanayome Picture Drama'}]}
# 3 {'Adaptation': [{'mal_id': 101, 'type': 'manga', 'url': 'https://myanimelist.net/manga/101/Shugo_Chara', 'title': 'Shugo Chara!'}], 'Prequel': [{'mal_id': 2923, 'type': 'anime', 'url': 'https://myanimelist.net/anime/2923/Shugo_Chara', 'title': 'Shugo Chara!'}], 'Sequel': [{'mal_id': 7082, 'type': 'anime', 'url': 'https://myanimelist.net/anime/7082/Shugo_Chara_Party', 'title': 'Shugo Chara! Party!'}]}
# 4 {'Adaptation': [{'mal_id': 1581, 'type': 'manga', 'url': 'https://myanimelist.net/manga/1581/Princess_Tutu', 'title': 'Princess Tutu'}], 'Summary': [{'mal_id': 3265, 'type': 'anime', 'url': 'https://myanimelist.net/anime/3265/Princess_Tutu_Recaps', 'title': 'Princess Tutu Recaps'}]}
# 5 {'Adaptation': [{'mal_id': 9711, 'type': 'manga', 'url': 'https://myanimelist.net/manga/9711/Bakuman', 'title': 'Bakuman.'}], 'Prequel': [{'mal_id': 10030, 'type': 'anime', 'url': 'https://myanimelist.net/anime/10030/Bakuman_2nd_Season', 'title': 'Bakuman. 2nd Season'}, {'mal_id': 15711, 'type': 'anime', 'url': 'https://myanimelist.net/anime/15711/Bakuman__Deraman', 'title': 'Bakuman.: Deraman.'}], 'Other': [{'mal_id': 23361, 'type': 'anime', 'url': 'https://myanimelist.net/anime/23361/Bakuman_3rd_Season_Specials', 'title': 'Bakuman. 3rd Season Specials'}]}
# 6 {'Adaptation': [{'mal_id': 10386, 'type': 'manga', 'url': 'https://myanimelist.net/manga/10386/Yume-iro_PÃ¢tissiÃ¨re', 'title': 'Yume-iro PÃ¢tissiÃ¨re'}], 'Side story': [{'mal_id': 8894, 'type': 'anime', 'url': 'https://myanimelist.net/anime/8894/Yume-iro_PÃ¢tissiÃ¨re__Mune_Kyun_Tropical_Island', 'title': 'Yume-iro PÃ¢tissiÃ¨re: Mune Kyun Tropical Island!'}], 'Sequel': [{'mal_id': 9441, 'type': 'anime', 'url': 'https://myanimelist.net/anime/9441/Yume-iro_PÃ¢tissiÃ¨re_SP_Professional', 'title': 'Yume-iro PÃ¢tissiÃ¨re SP Professional'}]}
#   producer
# 1 Aniplex, Square Enix, Mainichi Broadcasting System, Movic, Inu x Boku SS Production Partners
# 2 TV Tokyo, AIC, Square Enix, Sotsu
# 3 TV Tokyo, Sotsu
# 4 Memory-Tech, GANSIS, Marvelous AQL
# 5 NHK, Shueisha
# 6 Yomiuri Telecasting, DAX Production, Shueisha
#   licensor         studio
# 1 Sentai Filmworks David Production
# 2 Funimation       Gonzo
# 3                  Satelight
# 4 ADV Films        Hal Film Maker
# 5                  J.C.Staff
# 6                  Studio Pierrot, Studio Hibari
#   genre
# 1 Comedy, Supernatural, Romance, Shounen
# 2 Comedy, Parody, Romance, School, Shounen
# 3 Comedy, Magic, School, Shoujo
# 4 Comedy, Drama, Magic, Romance, Fantasy
# 5 Comedy, Drama, Romance, Shounen
# 6 Kids, School, Shoujo
#   opening_theme
# 1 ['"Nirvana" by MUCC']
# 2 ['"Romantic summer" by SUN&LUNAR']
# 3 ['#1: "Minna no Tamago (ã\201¿ã‚“ã\201ªã\201®ã\201Ÿã\201¾ã\201”)" by Shugo Chara Egg (eps 1-13)', '#2: "Shugo Shugo! (ã\201—ã‚…ã\201”ã\201—ã‚…ã\201”!)" by Shugo Chara Egg (eps 14-25)', '#3: "Omakaseâ\231ªGuardian (ã\201Šã\201¾ã\201‹ã\201›â\231ªã‚¬ãƒ¼ãƒ‡ã‚£ã‚¢ãƒ³)" by Guardians 4 (eps 26-38)', '#4: "School Days" by Guardians 4 (eps 39-51)']
# 4 ['"Morning Grace" by Ritsuko Okazaki']
# 5 ['#1: "Moshimo no Hanashi (ã‚‚ã\201—ã‚‚ã\201®è©±)" by nano.RIPE (eps 1-13)', '#2: "23:40 (23æ\231‚40å\210†) feat. Base Ball Bear" by Hyadain (eps 14-25)']
# 6 ['"Yume ni Yell! Patissiereâ\231ª (å¤¢ã\201«ã‚¨ãƒ¼ãƒ«ï¼\201ãƒ‘ãƒ†ã‚£ã‚·ã‚¨ãƒ¼ãƒ«â\231ª)" by Mayumi Gojou']
#   ending_theme
# 1 ['#1: "Nirvana" by MUCC (eps 1, 11-12)', '#2: "Rakuen no Photograph (æ¥½åœ’ã\201®Photograph)" by Soushi Miketsukami (Yuichi Nakamura) (eps 2, 9)', '#3: "Kimi wa (å\220›ã\201¯)" by Ririchiyo Shirakiin (Rina Hidaka) (eps 3, 8)', '#4: "one way" by Banri Watanuki (Takuya Eguchi) & Zange Natsume (Mamoru Miyano) (ep 4)', '#5: "SM Hantei Forum (SMå\210¤å®šãƒ•ã‚©ãƒ¼ãƒ©ãƒ )" by Kagerou Shoukiin (Tomokazu Sugita) (ep 5, 10)', '#6: "sweets parade" by Karuta Roromiya (Kana Hanazawa) (ep 6)', '#7: "Taiyou to Tsuki (å¤ªé\231½ã\201¨æœ\210)" by Renshou Sorinozuka (Yoshimasa Hosoya) & Nobara Yukinokouji (Youko Hikasa) (ep 7)']
# 2 ['#1: "Ashita e no Hikari (æ\230Žæ—¥ã\201¸ã\201®å…‰)" by Asuka Hinoi (1-13, 26)', '#2: "Dan Dan Dan" by SUN&LUNAR (eps 14-25)']
# 3 ['#1: "Rottara Rottara (ãƒ­ãƒƒã‚¿ãƒ© ãƒ­ãƒƒã‚¿ãƒ©)" by Buono! (eps 1-17)', '#2: "co.no.mi.chi" Buono! (eps 18-25)', '#3: "MY BOY" by Buono! (eps 26-38)', '#4: "Take it Easy!" by Buono! (eps. 39-50)', '#5: "Honto no Jibun (ãƒ›ãƒ³ãƒ\210ã\201®ã\201\230ã\201¶ã‚“)" by Buono! (ep 51)']
# 4 ['"Watashi No Ai Wa Chiisaikeredo" by Ritsuko Okazaki']
# 5 ['#1: "Pride on Everyday" by Sphere (eps 1-13)', '#2: "Yume Sketch (å¤¢ã‚¹ã‚±ãƒƒãƒ\201)" by JAM Project (eps 14-24)', '#3: "Moshimo no Hanashi (ã‚‚ã\201—ã‚‚ã\201®è©±)" by nano.RIPE (ep 25)']
# 6 ['"Ichigo no Miracle (ã\201„ã\201¡ã\201”ã\201®ãƒŸãƒ©ã‚¯ãƒ«ãƒ¼ãƒ«)" by Yukina Sugihara']
#   duration_min aired_from_year
# 1 24           2012
# 2 24           2007
# 3 24           2008
# 4 16           2002
# 5 24           2012
# 6 24           2009

# %% [markdown]
# Then, you can use the plotNormalHistogram function on the score variable:

# %%
plotNormalHistogram(anime$score)
# Out:
# Plot with title ""

# %%
## this looks to be apporximately normally distributed. No need to transform

# %% [markdown]
# ### Transforming Positively Skewed Data

# %% [markdown]
# How about scored_by?

# %%
plotNormalHistogram(anime$scored_by)
# Out:
# Plot with title ""

# %% [markdown]
# No such luck on that one. It looks to be horribly positively skewed.

# %% [markdown]
# #### Using sqrt()
#
# So start with a square root transformation, by using the function sqrt() just as a mathematical operation:

# %%
anime$scored_bySQRT <- sqrt(anime$scored_by)

# %% [markdown]
# This transforms the scored_by variable by square rooting it. It is then stored in a new column in anime, called scored_bySQRT so you can tell the old and the transformed data apart.
#
# Then run the histogram again:

# %%
plotNormalHistogram(anime$scored_bySQRT)
# Out:
# Plot with title ""

# %%
## looks a little better - maybe it can become even better still

# %% [markdown]
# #### Using log()
#
# So make a larger transformation - you will now take the log of the scored_by variable, using the log() function:

# %%
anime$scored_byLOG <- log(anime$scored_by)

# %%
plotNormalHistogram(anime$scored_byLOG)
# Out:
# Error in seq.default(min(x), max(x), length = length): 'from' must be a finite number
# Traceback:
#
# 1. plotNormalHistogram(anime$scored_byLOG)
# 2. seq(min(x), max(x), length = length)
# 3. seq.default(min(x), max(x), length = length)
# 4. stop("'from' must be a finite number")

# %%
## playing around with markdown here

# %% [markdown]
# #### Removing Infinite Values
# **You probably got an error here:**
#
# '''
# Error in seq.default(min(x), max(x), length = length) : 'from' must be a finite number
# '''
#
# This is because the log transformation made a few of the numbers so small that R gave up, and just gave them the value of -inf, or infinitely small. Most functions in R will not work with infinite data, including this one. There is, however, a package and a line of code that can save the day. From the "IDPmisc" library:

# %%
anime2 <- NaRV.omit(anime)

# %%
plotNormalHistogram(anime2$scored_byLOG)

# %%
## looks approximately normal now!

# %% [markdown]
# ### Transforming Negatively Skewed Data

# %% [markdown]
# You will follow a similar process to transform negatively skewed data, but this time, you will use squaring or cubing to transform your data.
#
# The variable aired_from_year is negatively skewed:

# %%
plotNormalHistogram(anime$aired_from_year)

# %% [markdown]
# #### Squaring the Variable
#
# So you can start by squaring it:

# %%
anime$aired_from_yearSQ <- anime$aired_from_year ^ 2

# %%
plotNormalHistogram(anime$aired_from_yearSQ)

# %% [markdown]
# That looks a bit better, but not amazing. No where near normally distributed.

# %% [markdown]
# #### Cubing the Variable
#
# Now try cubing it

# %%
anime$aired_from_yearCUBE <- anime$aired_from_year ^ 3

# %%
plotNormalHistogram(anime$aired_from_yearCUBE)

# %% [markdown]
# Overall, that definitely looks like the best option, so you can settle for that. Even though it is not perfect, you are out of options.

# %% [markdown]
# #### Tukey's Ladder of Power Transformation
#
# Wouldn't it be wonderful if there was some function that automatically transformed your data correctly, without all this time consuming guess work? Well, there is great news for you! There is. It's called the transformTukey function, which performs Tukey's Ladder of Power Transformation, and is available from the rcompanion package as well.
#
# You will try out this new wizardry using the cruise ship data. Here is what the original data looks like:

# %%
cruise_ship = read.csv('../../datasets/cruise_ship.csv')
## had to delete extra sheets inside cruise_ship.xlsx and change to a .csv

# %%
head(cruise_ship)
# Out:
#   Ship        Line     YearBlt Tonnage passngrs Length Cabins Crew PassSpcR
# 1 Journey     Azamara  2007     30277   694     594     355    355 42.64
# 2 Quest       Azamara  2007     30277   694     594     355    355 42.64
# 3 Celebration Carnival 1987     47262  1486     722     743    670 31.80
# 4 Conquest    Carnival 2002    110000  2974     953    1488   1910 36.99
# 5 Destiny     Carnival 1996    101353  2642     892    1321   1000 38.36
# 6 Ecstasy     Carnival 1991     70367  2052     855    1020    920 34.29
#   outcab
# 1 329
# 2 329
# 3 453
# 4 892
# 5 740
# 6 618

# %%
plotNormalHistogram(cruise_ship$Tonnage)
# Out:
# Plot with title ""

# %% [markdown]
# And then you can transform it with Tukey's, where the function transformTukey() takes the argument data$variable and where the argument plotit= takes either TRUE to add a plot or FALSE to do without.

# %%
cruise_ship$TonnageTUK <- transformTukey(cruise_ship$Tonnage, plotit=FALSE)
# Out:
#     lambda      W Shapiro.p.value
# 431   0.75 0.9852         0.09082
#
# if (lambda >  0){TRANS = x ^ lambda}
# if (lambda == 0){TRANS = log(x)}
# if (lambda <  0){TRANS = -1 * x ^ lambda}

# %%
plotNormalHistogram(cruise_ship$TonnageTUK)
# Out:
# Plot with title ""

# %%
#### Page 5 (activity)

# %% [markdown]
# ### determine whether each continuous variable is positively skewed, negatively skewed, or normally distributed. Then perform the correct transformations to get as close to the normal distribution as possible for each variable.

# %%
head(cruise_ship)
# Out:
#   Ship        Line     YearBlt Tonnage passngrs Length Cabins Crew PassSpcR
# 1 Journey     Azamara  2007     30277   694     594     355    355 42.64
# 2 Quest       Azamara  2007     30277   694     594     355    355 42.64
# 3 Celebration Carnival 1987     47262  1486     722     743    670 31.80
# 4 Conquest    Carnival 2002    110000  2974     953    1488   1910 36.99
# 5 Destiny     Carnival 1996    101353  2642     892    1321   1000 38.36
# 6 Ecstasy     Carnival 1991     70367  2052     855    1020    920 34.29
#   outcab TonnageTUK
# 1 329    2295.274
# 2 329    2295.274
# 3 453    3205.414
# 4 892    6040.105
# 5 740    5680.381
# 6 618    4320.428

# %% [markdown]
# ##### look at all distributions of continous variables

# %%
plotNormalHistogram(cruise_ship$YearBlt)
## YearBlt looks negatively skewed
# Out:
# Plot with title ""

# %%
plotNormalHistogram(cruise_ship$Tonnage)
## positively skewed
# Out:
# Plot with title ""

# %%
plotNormalHistogram(cruise_ship$passngrs)
## positively skewed
# Out:
# Plot with title ""

# %%
plotNormalHistogram(cruise_ship$Length)
## negatively skewed
# Out:
# Plot with title ""

# %%
plotNormalHistogram(cruise_ship$Cabins)
## positively skewed
# Out:
# Plot with title ""

# %%
plotNormalHistogram(cruise_ship$Crew)
## positively skewed
# Out:
# Plot with title ""

# %%
plotNormalHistogram(cruise_ship$PassSpcR)
## positively skewed
# Out:
# Plot with title ""

# %%
plotNormalHistogram(cruise_ship$outcab)
## positively skewed
# Out:
# Plot with title ""

# %% [markdown]
# #### Transform positively skewed variables

# %%
cruise_ship$TonnageSQRT <- sqrt(cruise_ship$Tonnage)

# %%
plotNormalHistogram(cruise_ship$TonnageSQRT)
## looks better and more normal
# Out:
# Plot with title ""

# %%
cruise_ship$passngrsSQRT <- sqrt(cruise_ship$passngrs)

# %%
plotNormalHistogram(cruise_ship$passngrsSQRT)
## looks better and more normal
# Out:
# Plot with title ""

# %%
cruise_ship$CabinsSQRT <- sqrt(cruise_ship$Cabins)

# %%
plotNormalHistogram(cruise_ship$CabinsSQRT)
## looks better and more normal
# Out:
# Plot with title ""

# %%
cruise_ship$CrewSQRT <- sqrt(cruise_ship$Crew)

# %%
plotNormalHistogram(cruise_ship$CrewSQRT)
## looks better and more normal
# Out:
# Plot with title ""

# %%
cruise_ship$PassSpcRSQRT <- sqrt(cruise_ship$PassSpcR)

# %%
plotNormalHistogram(cruise_ship$PassSpcRSQRT)
## looks better and more normal
# Out:
# Plot with title ""

# %%
cruise_ship$outcabSQRT <- sqrt(cruise_ship$outcab)

# %%
plotNormalHistogram(cruise_ship$outcabSQRT)
## looks better and more normal
# Out:
# Plot with title ""

# %% [markdown]
# #### Transform negatively skewed variables

# %%
cruise_ship$YearBltSQ = cruise_ship$YearBlt ^ 2

# %%
plotNormalHistogram(cruise_ship$YearBltSQ)
# Out:
# Plot with title ""

# %%
cruise_ship$LengthSQ = cruise_ship$Length ^ 2

# %%
plotNormalHistogram(cruise_ship$LengthSQ)
# Out:
# Plot with title ""

# %%
#### Let's try cubing YearBlt

# %%
cruise_ship$YearBltCUBE = cruise_ship$YearBlt ^ 3

# %%
plotNormalHistogram(cruise_ship$YearBltCUBE)
## looks a little more normal
# Out:
# Plot with title ""

# %%
#### Page 6 (activity solution)

# %%
#### Page 7 (Transforming Data in Python) - different notebook
