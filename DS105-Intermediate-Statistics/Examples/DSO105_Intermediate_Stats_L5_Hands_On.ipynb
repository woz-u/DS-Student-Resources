# %% [markdown]
# # DSO105 Intermediate Stats L5 Hands On

# %%
## packages
library(tidyverse)
library(rcompanion)
library(car)
# Out:
# -- Attaching packages ------------------------------------------------------------------------------- tidyverse 1.3.1 --
#
# v ggplot2 3.3.5     v purrr   0.3.4
# v tibble  3.1.2     v dplyr   1.0.6
# v tidyr   1.1.3     v stringr 1.4.0
# v readr   1.4.0     v forcats 0.5.1
#
# -- Conflicts ---------------------------------------------------------------------------------- tidyverse_conflicts() --
# x dplyr::filter() masks stats::filter()
# x dplyr::lag()    masks stats::lag()
#
# Loading required package: carData
#
#
# Attaching package: 'car'
#
#
# The following object is masked from 'package:dplyr':
#
#     recode
#
#
# The following object is masked from 'package:purrr':
#
#     some

# %%
## data
df = read.csv('../../datasets/honey.csv')

# %%
head(df)
# Out:
#   state numcol yieldpercol totalprod stocks  priceperlb prodvalue year
# 1 AL      9000 66            594000   214000 1.90        1129000  2008
# 2 AZ     25000 64           1600000   336000 1.26        2016000  2008
# 3 AR     28000 75           2100000   525000 1.35        2835000  2008
# 4 CA    360000 51          18360000  4039000 1.39       25520000  2008
# 5 CO     27000 45           1215000   656000 1.51        1835000  2008
# 6 FL    150000 79          11850000  1304000 1.32       15642000  2008

# %%
str(df)
# Out:
# 'data.frame':	201 obs. of  9 variables:
#  $ state      : chr  "AL" "AZ" "AR" "CA" ...
#  $ numcol     : num  9000 25000 28000 360000 27000 150000 65000 10000 90000 8000 ...
#  $ yieldpercol: int  66 64 75 51 45 79 71 90 40 56 ...
#  $ totalprod  : num  594000 1600000 2100000 18360000 1215000 ...
#  $ stocks     : int  214000 336000 525000 4039000 656000 1304000 369000 225000 1440000 116000 ...
#  $ priceperlb : num  1.9 1.26 1.35 1.39 1.51 1.32 1.52 1.59 1.46 2.59 ...
#  $ prodvalue  : int  1129000 2016000 2835000 25520000 1835000 15642000 7015000 1431000 5256000 1160000 ...
#  $ year       : int  2008 2008 2008 2008 2008 2008 2008 2008 2008 2008 ...
#  $ tpLOG      : num  13.3 14.3 14.6 16.7 14 ...

# %%
unique(df$year)
# Out:
# [1] 2008 2009 2010 2011 2012

# %% [markdown]
# ## Data Wrangling

# %%
years = length(unique(df$year))

# %%
year_vector = unique(df$year)

# %%
year_vector[1]
# Out:
# [1] 2008

# %%
year1 = df %>% filter(year == year_vector[1])

# %%
year1
# Out:
#    state numcol yieldpercol totalprod stocks   priceperlb prodvalue year
# 1  AL      9000 66            594000    214000 1.90        1129000  2008
# 2  AZ     25000 64           1600000    336000 1.26        2016000  2008
# 3  AR     28000 75           2100000    525000 1.35        2835000  2008
# 4  CA    360000 51          18360000   4039000 1.39       25520000  2008
# 5  CO     27000 45           1215000    656000 1.51        1835000  2008
# 6  FL    150000 79          11850000   1304000 1.32       15642000  2008
# 7  GA     65000 71           4615000    369000 1.52        7015000  2008
# 8  HI     10000 90            900000    225000 1.59        1431000  2008
# 9  ID     90000 40           3600000   1440000 1.46        5256000  2008
# 10 IL      8000 56            448000    116000 2.59        1160000  2008
# 11 IN      7000 67            469000    150000 1.68         788000  2008
# 12 IA     24000 62           1488000    580000 1.58        2351000  2008
# 13 KS     10000 61            610000    128000 1.55         946000  2008
# 14 KY      4000 39            156000     27000 2.44         381000  2008
# 15 LA     40000 77           3080000    493000 1.36        4189000  2008
# 16 ME      7000 42            294000     79000 1.57         462000  2008
# 17 MI     71000 73           5183000   2021000 1.44        7464000  2008
# 18 MN    122000 78           9516000   2569000 1.39       13227000  2008
# 19 MS     14000 98           1372000    110000 1.30        1784000  2008
# 20 MO     11000 53            583000    152000 1.68         979000  2008
# 21 MT    134000 70           9380000   4596000 1.37       12851000  2008
# 22 NE     36000 67           2412000   1254000 1.45        3497000  2008
# 23 NV     10000 29            290000     52000 1.42         412000  2008
# 24 NJ      9000 40            360000    122000 1.62         583000  2008
# 25 NM      6000 48            288000     95000 1.48         426000  2008
# 26 NY     50000 70           3500000   1260000 1.65        5775000  2008
# 27 NC     12000 52            624000    137000 2.18        1360000  2008
# 28 ND    400000 90          36000000   8640000 1.36       48960000  2008
# 29 OH     14000 53            742000    371000 1.68        1247000  2008
# 30 OR     50000 43           2150000   1097000 1.41        3032000  2008
# 31 PA     23000 48           1104000    276000 1.65        1822000  2008
# 32 SD    225000 95          21375000  11970000 1.34       28643000  2008
# 33 TN      7000 61            427000    149000 2.09         892000  2008
# 34 TX     77000 64           4928000   1380000 1.34        6604000  2008
# 35 UT     28000 48           1344000    242000 1.57        2110000  2008
# 36 VT      5000 66            330000    119000 2.20         726000  2008
# 37 VA      6000 42            252000     45000 2.42         610000  2008
# 38 WA     49000 44           2156000    862000 1.51        3256000  2008
# 39 WV      6000 43            258000     49000 2.16         557000  2008
# 40 WI     58000 80           4640000   2366000 1.50        6960000  2008
# 41 WY     39000 61           2379000    381000 1.37        3259000  2008

# %%
year2 = df %>% filter(year == year_vector[2])

# %%
year3 = df %>% filter(year == year_vector[3])

# %%
year4 = df %>% filter(year == year_vector[4])

# %%
year5 = df %>% filter(year == year_vector[5])

# %%
year5
# Out:
#    state numcol yieldpercol totalprod stocks  priceperlb prodvalue year
# 1  AL      8000  54           432000    65000 2.47        1067000  2012
# 2  AZ     22000  46          1012000   253000 1.79        1811000  2012
# 3  AR     25000  63          1575000   189000 1.98        3119000  2012
# 4  CA    330000  35         11550000  3119000 1.94       22407000  2012
# 5  CO     25000  48          1200000   468000 2.07        2484000  2012
# 6  FL    193000  64         12352000  1235000 1.84       22728000  2012
# 7  GA     59000  51          3009000   181000 1.92        5777000  2012
# 8  HI     10000  75           750000   263000 4.15        3113000  2012
# 9  ID     92000  32          2944000   530000 1.63        4799000  2012
# 10 IL      7000  61           427000   145000 3.55        1516000  2012
# 11 IN      8000  59           472000   203000 2.54        1199000  2012
# 12 IA     37000  61          2257000  1196000 2.17        4898000  2012
# 13 KS      6000  55           330000   125000 2.28         752000  2012
# 14 KY      5000  51           255000    41000 3.15         803000  2012
# 15 LA     41000  86          3526000   141000 1.83        6453000  2012
# 16 ME      4000  34           136000    24000 2.39         325000  2012
# 17 MI     73000  57          4161000  1332000 2.03        8447000  2012
# 18 MN    125000  67          8375000  1591000 1.92       16080000  2012
# 19 MS     18000 118          2124000    64000 1.77        3759000  2012
# 20 MO      7000  53           371000   108000 2.80        1039000  2012
# 21 MT    145000  52          7540000  2413000 1.95       14703000  2012
# 22 NE     43000  65          2795000  1146000 1.93        5394000  2012
# 23 NJ     14000  33           462000    51000 1.97         910000  2012
# 24 NM      5000  52           260000    99000 3.39         881000  2012
# 25 NY     51000  51          2601000   988000 2.23        5800000  2012
# 26 NC     13000  39           507000   106000 3.76        1906000  2012
# 27 ND    480000  69         33120000  5962000 1.92       63590000  2012
# 28 OH     18000  60          1080000   410000 2.46        2657000  2012
# 29 OR     60000  32          1920000   845000 2.16        4147000  2012
# 30 PA     16000  60           960000   269000 2.57        2467000  2012
# 31 SD    260000  63         16380000  3604000 1.95       31941000  2012
# 32 TN      6000  61           366000    59000 2.93        1072000  2012
# 33 TX     92000  52          4784000   718000 2.00        9568000  2012
# 34 UT     25000  38           950000   209000 1.87        1777000  2012
# 35 VT      4000  60           240000    53000 2.39         574000  2012
# 36 VA      4000  41           164000    23000 3.77         618000  2012
# 37 WA     62000  41          2542000  1017000 2.38        6050000  2012
# 38 WV      6000  48           288000    95000 2.91         838000  2012
# 39 WI     60000  69          4140000  1863000 2.05        8487000  2012
# 40 WY     50000  51          2550000   459000 1.87        4769000  2012

# %% [markdown]
# ## Assumptions

# %%
plotNormalHistogram(year1$totalprod)
## positively skewed
# Out:
# Plot with title ""

# %%
year1$tpLOG = log(year1$totalprod)
plotNormalHistogram(year1$tpLOG)
## looks a lot closer to being approx normally distributed
# Out:
# Plot with title ""

# %%
plotNormalHistogram(year2$totalprod)
## + skewed
# Out:
# Plot with title ""

# %%
year2$tpLOG = log(year2$totalprod)
plotNormalHistogram(year2$tpLOG)
## more normal
# Out:
# Plot with title ""

# %%
plotNormalHistogram(year3$totalprod)
## + skewed
# Out:
# Plot with title ""

# %%
year3$tpLOG = log(year3$totalprod)
plotNormalHistogram(year3$tpLOG)
## more normal
# Out:
# Plot with title ""

# %%
plotNormalHistogram(year4$totalprod)
## + skewed
# Out:
# Plot with title ""

# %%
year4$tpLOG = log(year4$totalprod)
plotNormalHistogram(year4$tpLOG)
## more normal
# Out:
# Plot with title ""

# %%
plotNormalHistogram(year5$totalprod)
## + skewed
# Out:
# Plot with title ""

# %%
year5$tpLOG = log(year5$totalprod)
plotNormalHistogram(year5$tpLOG)
## more normal
# Out:
# Plot with title ""

# %%
df$tpLOG = log(df$totalprod)

# %%
df$year = as.factor(df$year)

# %% [markdown]
# ## Homogeneity of Variance

# %%
leveneTest(tpLOG ~ year, data = df)
# Out:
#       Df  F value    Pr(>F)
# group   4 0.03178299 0.9980452
#       196         NA        NA

# %% [markdown]
# ## ANOVA

# %%
RManova <- aov(tpLOG ~ year+Error(state), df)
summary(RManova)
# Out:
# Error: state
#           Df Sum Sq Mean Sq F value Pr(>F)
# year       1    2.6   2.571   0.272  0.605
# Residuals 39  368.6   9.452
#
# Error: Within
#            Df Sum Sq Mean Sq F value  Pr(>F)
# year        4  0.677 0.16913   4.007 0.00402 **
# Residuals 156  6.584 0.04221
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1

# %%
RManova <- aov(tpLOG ~ year, df)
summary(RManova)
# Out:
#              Df Sum Sq Mean Sq F value Pr(>F)
# year          4    0.4   0.112   0.058  0.994
# Residuals   196  378.0   1.929
