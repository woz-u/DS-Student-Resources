# %% [markdown]
# # MySQL in Jupyter
# ##### By Matthew Gerardino
#
# **Important:** pip install MySQL Connector

# %%
import mysql.connector
import pandas as pd
from ipynb.fs.full.DBGenerator import *
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
import pymysql

mydb = mysql.connector.connect(
  host="127.0.0.1",
  user="root",
  password="",
  database="sakila"
)

mycursor = mydb.cursor()

# %%
df1 =pd.DataFrame(Table1)
df2 =pd.DataFrame(Table2)
df1['Country'] = Country
df2['Country'] = Country
df1.head()
df2.head()
# Out:
#               Name         DOB                City                        Job  \
# 0     Norma Fisher  1941-03-11        Sullivanport  Publishing rights manager
# 1  Steven Robinson  1924-11-28         Donaldville             Water engineer
# 2   Victoria Patel  2001-12-05          West Corey              Buyer, retail
# 3  Melinda Kennedy  1919-08-29         Ryanborough                        Sub
# 4       Sean Green  2015-07-09  North Jenniferfurt      Accommodation manager
#
#                        Country
# 0                        Congo
# 1  Falkland Islands (Malvinas)
# 2     Central African Republic
# 3            Brunei Darussalam
# 4                      Moldova
#              Name         DOB                City  \
# 0  Ryan Gallagher  1940-09-01  South Kathleenfort
# 1    Anna Johnson  2019-09-14        Reynoldstown
# 2    Robert Garza  1919-11-13         Anthonytown
# 3   Stanley Parks  1963-05-28    New Jeffreymouth
# 4    Haley Rhodes  2009-07-08          Farleytown
#
# ...

# %%
from sqlalchemy import create_engine
engine = create_engine("mysql+pymysql://{user}:{pw}@localhost/{db}"
                       .format(user="root",
                               pw="",
                               db="sakila"))

# %%
# Insert whole DataFrame into MySQL
df1.to_sql('loyal_cutomers', con = engine, if_exists = 'append', chunksize = 1000)
df2.to_sql('regular_cutomers', con = engine, if_exists = 'append', chunksize = 1000)

# %% [markdown]
# #### Join Example using the code below
#
# SELECT first_name, last_name, film_id
# FROM sakila.actor
# INNER JOIN sakila.film_actor
# USING(actor_id)

# %% [markdown]
# #### View Table 1 and Table 2 Separately

# %%
table1 = pd.read_sql("SELECT * FROM sakila.actor", con = mydb)
table2 = pd.read_sql("SELECT * FROM sakila.film_actor", con = mydb)

table1.head()
table2.head()
# Out:
#    actor_id first_name     last_name         last_update
# 0         1   PENELOPE       GUINESS 2006-02-15 04:34:33
# 1         2       NICK      WAHLBERG 2006-02-15 04:34:33
# 2         3         ED         CHASE 2006-02-15 04:34:33
# 3         4   JENNIFER         DAVIS 2006-02-15 04:34:33
# 4         5     JOHNNY  LOLLOBRIGIDA 2006-02-15 04:34:33
#    actor_id  film_id         last_update
# 0         1        1 2006-02-15 05:05:03
# 1         1       23 2006-02-15 05:05:03
# 2         1       25 2006-02-15 05:05:03
# 3         1      106 2006-02-15 05:05:03
# 4         1      140 2006-02-15 05:05:03

# %% [markdown]
# #### View Table 1 and Table 2 Using a Join

# %%
mycursor = mydb.cursor()

sql = "SELECT \
    first_name, last_name, film_id \
    FROM sakila.actor JOIN sakila.film_actor \
    USING(actor_id)"

mycursor.execute(sql)

myresult = mycursor.fetchall()

# for x in myresult:
#   print(x)
df=pd.read_sql(sql, con = mydb)
df.head()
# Out:
#   first_name last_name  film_id
# 0   PENELOPE   GUINESS        1
# 1   PENELOPE   GUINESS       23
# 2   PENELOPE   GUINESS       25
# 3   PENELOPE   GUINESS      106
# 4   PENELOPE   GUINESS      140

# %% [markdown]
# ## If you would like..
#
# ## You can now delete these two tables and start fresh, just uncomment below!!

# %%
# sql = "DROP TABLE IF EXISTS loyal_cutomers"
# mycursor.execute(sql)

# sql = "DROP TABLE IF EXISTS regular_cutomers"
# mycursor.execute(sql)
