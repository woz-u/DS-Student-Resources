# %%
import pandas as pd

# %% [markdown]
# ## Load in Data

# %%
payment = pd.read_csv("payment.csv")
payment.head()
# Out:
#   userID          Upayment
# 0  U1001              cash
# 1  U1002              cash
# 2  U1003              cash
# 3  U1004              cash
# 4  U1004  bank_debit_cards

# %%
profile = pd.read_csv("profile.csv")
profile.head()
# Out:
#   userID   latitude   longitude smoker     drink_level dress_preference  \
# 0  U1001  22.139997 -100.978803  false      abstemious         informal
# 1  U1002  22.150087 -100.983325  false      abstemious         informal
# 2  U1003  22.119847 -100.946527  false  social drinker           formal
# 3  U1004  18.867000  -99.183000  false      abstemious         informal
# 4  U1005  22.183477 -100.959891  false      abstemious    no preference
#
#   ambience transport marital_status        hijos  birth_year    interest  \
# 0   family   on foot         single  independent        1989     variety
# 1   family    public         single  independent        1990  technology
# 2   family    public         single  independent        1989        none
# 3   family    public         single  independent        1940     variety
# 4   family    public         single  independent        1992        none
#
#            personality  religion      activity  color  weight  budget  height
# ...

# %%
test = pd.read_csv("test.csv")
test.head()
# Out:
#    tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  tBodyAcc-std()-X  \
# 0           0.257178          -0.023285          -0.014654         -0.938404
# 1           0.286027          -0.013163          -0.119083         -0.975415
# 2           0.275485          -0.026050          -0.118152         -0.993819
# 3           0.270298          -0.032614          -0.117520         -0.994743
# 4           0.274833          -0.027848          -0.129527         -0.993852
#
#    tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  tBodyAcc-mad()-Y  \
# 0         -0.920091         -0.667683         -0.952501         -0.925249
# 1         -0.967458         -0.944958         -0.986799         -0.968401
# 2         -0.969926         -0.962748         -0.994403         -0.970735
# 3         -0.973268         -0.967091         -0.995274         -0.974471
# 4         -0.967445         -0.978295         -0.994111         -0.965953
#
#    tBodyAcc-mad()-Z  tBodyAcc-max()-X    ...     \
# ...

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2947 entries, 0 to 2946
# Columns: 563 entries, tBodyAcc-mean()-X to Activity
# dtypes: float64(561), int64(1), object(1)
# memory usage: 12.7+ MB

# %%
train = pd.read_csv("train.csv")
train.head()
# Out:
#    tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  tBodyAcc-std()-X  \
# 0           0.288585          -0.020294          -0.132905         -0.995279
# 1           0.278419          -0.016411          -0.123520         -0.998245
# 2           0.279653          -0.019467          -0.113462         -0.995380
# 3           0.279174          -0.026201          -0.123283         -0.996091
# 4           0.276629          -0.016570          -0.115362         -0.998139
#
#    tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  tBodyAcc-mad()-Y  \
# 0         -0.983111         -0.913526         -0.995112         -0.983185
# 1         -0.975300         -0.960322         -0.998807         -0.974914
# 2         -0.967187         -0.978944         -0.996520         -0.963668
# 3         -0.983403         -0.990675         -0.997099         -0.982750
# 4         -0.980817         -0.990482         -0.998321         -0.979672
#
#    tBodyAcc-mad()-Z  tBodyAcc-max()-X    ...     \
# ...

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7352 entries, 0 to 7351
# Columns: 563 entries, tBodyAcc-mean()-X to Activity
# dtypes: float64(561), int64(1), object(1)
# memory usage: 31.6+ MB

# %% [markdown]
# ## Transposing Data

# %%
payment.T
# Out:
#             0      1      2      3                 4      5      6      7    \
# userID    U1001  U1002  U1003  U1004             U1004  U1005  U1006  U1007
# Upayment   cash   cash   cash   cash  bank_debit_cards   cash   cash   cash
#
#             8      9    ...      167    168    169               170    171  \
# userID    U1008  U1009  ...    U1129  U1131  U1132             U1133  U1133
# Upayment   cash   cash  ...     cash   cash   cash  bank_debit_cards   cash
#
#             172    173    174    175    176
# userID    U1134  U1135  U1136  U1137  U1138
# Upayment   cash   cash   cash   cash   cash
#
# [2 rows x 177 columns]

# %%
payment.head()
# Out:
#   userID          Upayment
# 0  U1001              cash
# 1  U1002              cash
# 2  U1003              cash
# 3  U1004              cash
# 4  U1004  bank_debit_cards

# %%
payment1 = payment.set_index('userID').T

# %%
payment1.head()
# Out:
# userID   U1001 U1002 U1003 U1004             U1004 U1005 U1006 U1007 U1008  \
# Upayment  cash  cash  cash  cash  bank_debit_cards  cash  cash  cash  cash
#
# userID   U1009  ...  U1129 U1131 U1132             U1133 U1133 U1134 U1135  \
# Upayment  cash  ...   cash  cash  cash  bank_debit_cards  cash  cash  cash
#
# userID   U1136 U1137 U1138
# Upayment  cash  cash  cash
#
# [1 rows x 177 columns]

# %% [markdown]
# ## Merging Datasets

# %%
UsersData = pd.merge(payment, profile, on="userID")

# %%
UsersData.head()
# Out:
#   userID          Upayment   latitude   longitude smoker     drink_level  \
# 0  U1001              cash  22.139997 -100.978803  false      abstemious
# 1  U1002              cash  22.150087 -100.983325  false      abstemious
# 2  U1003              cash  22.119847 -100.946527  false  social drinker
# 3  U1004              cash  18.867000  -99.183000  false      abstemious
# 4  U1004  bank_debit_cards  18.867000  -99.183000  false      abstemious
#
#   dress_preference ambience transport marital_status        hijos  birth_year  \
# 0         informal   family   on foot         single  independent        1989
# 1         informal   family    public         single  independent        1990
# 2           formal   family    public         single  independent        1989
# 3         informal   family    public         single  independent        1940
# 4         informal   family    public         single  independent        1940
#
# ...

# %% [markdown]
# ## Concatenating Datasets

# %%
AllProcessors = pd.concat([test, train])

# %%
AllProcessors.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10299 entries, 0 to 7351
# Columns: 563 entries, tBodyAcc-mean()-X to Activity
# dtypes: float64(561), int64(1), object(1)
# memory usage: 44.3+ MB

# %% [markdown]
# ## Group By - Aggregating Data

# %%
UsersData.groupby('dress_preference')['birth_year'].mean()
# Out:
# dress_preference
# ?                1985.500000
# elegant          1987.875000
# formal           1988.387755
# informal         1979.574468
# no preference    1985.239437
# Name: birth_year, dtype: float64
