# %% [markdown]
# # DSO104 L1 Python - Hands On
#
# ## Fake News dataset hands on

# %%
## import packages

# %%
import pandas as pd

# %%
fakenews = pd.read_csv('../datasets/observed-trackers.csv')

# %%
fakenews.head()
# Out:
#               when          domain  \
# 0  before-nov-2016  alertchild.com
# 1  before-nov-2016  alertchild.com
# 2  before-nov-2016  alertchild.com
# 3  before-nov-2016  alertchild.com
# 4  before-nov-2016  alertchild.com
#
#                                                  url  \
# 0  http://wayback.archive.org/web/20161004072420i...
# 1  http://wayback.archive.org/web/20161004072420i...
# 2  http://wayback.archive.org/web/20161004072420i...
# 3  http://wayback.archive.org/web/20161004072420i...
# 4  http://wayback.archive.org/web/20161004072420i...
#
#                           tracker
# 0                     DoubleClick
# 1                      RevContent
# 2                     DoubleClick
# 3              Google Syndication
# 4  DoubleClick Ad Exchange-Seller

# %% [markdown]
# ### Add a column labeled StoryType and fill it with Fake.

# %%
fakenews['StoryType'] = "Fake"
fakenews.head()
# Out:
#               when          domain  \
# 0  before-nov-2016  alertchild.com
# 1  before-nov-2016  alertchild.com
# 2  before-nov-2016  alertchild.com
# 3  before-nov-2016  alertchild.com
# 4  before-nov-2016  alertchild.com
#
#                                                  url  \
# 0  http://wayback.archive.org/web/20161004072420i...
# 1  http://wayback.archive.org/web/20161004072420i...
# 2  http://wayback.archive.org/web/20161004072420i...
# 3  http://wayback.archive.org/web/20161004072420i...
# 4  http://wayback.archive.org/web/20161004072420i...
#
#                           tracker StoryType
# 0                     DoubleClick      Fake
# 1                      RevContent      Fake
# 2                     DoubleClick      Fake
# 3              Google Syndication      Fake
# 4  DoubleClick Ad Exchange-Seller      Fake

# %% [markdown]
# ### Remove the when column.

# %%
fakenews.drop(['when'], axis=1, inplace=True)
fakenews.head()
# Out:
#            domain                                                url  \
# 0  alertchild.com  http://wayback.archive.org/web/20161004072420i...
# 1  alertchild.com  http://wayback.archive.org/web/20161004072420i...
# 2  alertchild.com  http://wayback.archive.org/web/20161004072420i...
# 3  alertchild.com  http://wayback.archive.org/web/20161004072420i...
# 4  alertchild.com  http://wayback.archive.org/web/20161004072420i...
#
#                           tracker StoryType
# 0                     DoubleClick      Fake
# 1                      RevContent      Fake
# 2                     DoubleClick      Fake
# 3              Google Syndication      Fake
# 4  DoubleClick Ad Exchange-Seller      Fake

# %% [markdown]
# ### Separate the url column out so that you can see in one column the website and in the second column the domain.

# %%
fakenews1 = fakenews['url'].str.split('_', expand=True).rename(columns = lambda x: "URL"+str(x+1))
fakenews1.head()
# Out:
#                                               URL1                     URL2
# 0  http://wayback.archive.org/web/20161004072420id  /http://alertchild.com/
# 1  http://wayback.archive.org/web/20161004072420id  /http://alertchild.com/
# 2  http://wayback.archive.org/web/20161004072420id  /http://alertchild.com/
# 3  http://wayback.archive.org/web/20161004072420id  /http://alertchild.com/
# 4  http://wayback.archive.org/web/20161004072420id  /http://alertchild.com/

# %%
fakenews2 = pd.concat([fakenews, fakenews1], axis=1)
fakenews2.head()
# Out:
#            domain                                                url  \
# 0  alertchild.com  http://wayback.archive.org/web/20161004072420i...
# 1  alertchild.com  http://wayback.archive.org/web/20161004072420i...
# 2  alertchild.com  http://wayback.archive.org/web/20161004072420i...
# 3  alertchild.com  http://wayback.archive.org/web/20161004072420i...
# 4  alertchild.com  http://wayback.archive.org/web/20161004072420i...
#
#                           tracker StoryType  \
# 0                     DoubleClick      Fake
# 1                      RevContent      Fake
# 2                     DoubleClick      Fake
# 3              Google Syndication      Fake
# 4  DoubleClick Ad Exchange-Seller      Fake
#
#                                               URL1                     URL2
# 0  http://wayback.archive.org/web/20161004072420id  /http://alertchild.com/
# 1  http://wayback.archive.org/web/20161004072420id  /http://alertchild.com/
# 2  http://wayback.archive.org/web/20161004072420id  /http://alertchild.com/
# 3  http://wayback.archive.org/web/20161004072420id  /http://alertchild.com/
# 4  http://wayback.archive.org/web/20161004072420id  /http://alertchild.com/

# %%
fakenews2.drop(['url'], axis=1, inplace=True)
fakenews2.head()
# Out:
#            domain                         tracker StoryType  \
# 0  alertchild.com                     DoubleClick      Fake
# 1  alertchild.com                      RevContent      Fake
# 2  alertchild.com                     DoubleClick      Fake
# 3  alertchild.com              Google Syndication      Fake
# 4  alertchild.com  DoubleClick Ad Exchange-Seller      Fake
#
#                                               URL1                     URL2
# 0  http://wayback.archive.org/web/20161004072420id  /http://alertchild.com/
# 1  http://wayback.archive.org/web/20161004072420id  /http://alertchild.com/
# 2  http://wayback.archive.org/web/20161004072420id  /http://alertchild.com/
# 3  http://wayback.archive.org/web/20161004072420id  /http://alertchild.com/
# 4  http://wayback.archive.org/web/20161004072420id  /http://alertchild.com/

# %% [markdown]
# ### Put back together the domain column.

# %%
fakenews2['url'] = fakenews2["URL1"] + "_" + fakenews2["URL2"].map(str)
fakenews2.head()
# Out:
#            domain                         tracker StoryType  \
# 0  alertchild.com                     DoubleClick      Fake
# 1  alertchild.com                      RevContent      Fake
# 2  alertchild.com                     DoubleClick      Fake
# 3  alertchild.com              Google Syndication      Fake
# 4  alertchild.com  DoubleClick Ad Exchange-Seller      Fake
#
#                                               URL1                     URL2  \
# 0  http://wayback.archive.org/web/20161004072420id  /http://alertchild.com/
# 1  http://wayback.archive.org/web/20161004072420id  /http://alertchild.com/
# 2  http://wayback.archive.org/web/20161004072420id  /http://alertchild.com/
# 3  http://wayback.archive.org/web/20161004072420id  /http://alertchild.com/
# 4  http://wayback.archive.org/web/20161004072420id  /http://alertchild.com/
#
#                                                  url
# 0  http://wayback.archive.org/web/20161004072420i...
# 1  http://wayback.archive.org/web/20161004072420i...
# 2  http://wayback.archive.org/web/20161004072420i...
# 3  http://wayback.archive.org/web/20161004072420i...
# 4  http://wayback.archive.org/web/20161004072420i...

# %%
fakenews2.drop(['URL1', 'URL2'], axis=1, inplace=True)
fakenews2.head()
# Out:
#            domain                         tracker StoryType  \
# 0  alertchild.com                     DoubleClick      Fake
# 1  alertchild.com                      RevContent      Fake
# 2  alertchild.com                     DoubleClick      Fake
# 3  alertchild.com              Google Syndication      Fake
# 4  alertchild.com  DoubleClick Ad Exchange-Seller      Fake
#
#                                                  url
# 0  http://wayback.archive.org/web/20161004072420i...
# 1  http://wayback.archive.org/web/20161004072420i...
# 2  http://wayback.archive.org/web/20161004072420i...
# 3  http://wayback.archive.org/web/20161004072420i...
# 4  http://wayback.archive.org/web/20161004072420i...

# %% [markdown]
# ### Keep only the first ten rows of the data.

# %%
fakenews3 = fakenews2[:10]
fakenews3
# Out:
#             domain                         tracker StoryType  \
# 0   alertchild.com                     DoubleClick      Fake
# 1   alertchild.com                      RevContent      Fake
# 2   alertchild.com                     DoubleClick      Fake
# 3   alertchild.com              Google Syndication      Fake
# 4   alertchild.com  DoubleClick Ad Exchange-Seller      Fake
# 5   alertchild.com                           Kixer      Fake
# 6   alertchild.com                  Google Adsense      Fake
# 7  areyousleep.com                     DoubleClick      Fake
# 8  areyousleep.com                     DoubleClick      Fake
# 9  areyousleep.com              Google Syndication      Fake
#
#                                                  url
# 0  http://wayback.archive.org/web/20161004072420i...
# 1  http://wayback.archive.org/web/20161004072420i...
# 2  http://wayback.archive.org/web/20161004072420i...
# 3  http://wayback.archive.org/web/20161004072420i...
# 4  http://wayback.archive.org/web/20161004072420i...
# 5  http://wayback.archive.org/web/20161004072420i...
# 6  http://wayback.archive.org/web/20161004072420i...
# 7  http://wayback.archive.org/web/20161001155200i...
# 8  http://wayback.archive.org/web/20161001155200i...
# 9  http://wayback.archive.org/web/20161001155200i...
