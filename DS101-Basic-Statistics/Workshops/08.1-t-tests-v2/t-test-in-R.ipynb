# %% [markdown]
# # t-tests in R

# %%
library('ggplot2')
library('reshape2')

# %%
df = read.csv('weights_ttests.csv')

# %%
head(df)
# Out:
#   id sex  start_weight end_weight
# 1 1  Male 203          205
# 2 2  Male 180          177
# 3 3  Male 222          218
# 4 4  Male 190          190
# 5 5  Male 201          199
# 6 6  Male 185          183

# %%
t.test(df$start_weight, mu=200)
# Out:
# 	One Sample t-test
#
# data:  df$start_weight
# t = -4.2559, df = 29, p-value = 0.0001989
# alternative hypothesis: true mean is not equal to 200
# 95 percent confidence interval:
#  172.0667 190.2000
# sample estimates:
# mean of x
#  181.1333

# %%
# Since our p-value is less than .05, we determine that start weight differs from 200

# %%
t.test(df$end_weight, mu=200)
# Out:
# 	One Sample t-test
#
# data:  df$end_weight
# t = -4.6184, df = 29, p-value = 7.317e-05
# alternative hypothesis: true mean is not equal to 200
# 95 percent confidence interval:
#  170.9027 188.7640
# sample estimates:
# mean of x
#  179.8333

# %%
# Since our p-value is less than .05, we determine that end weight differs from 200

# %% [markdown]
# ## Independent Sample t-test
#
# Compares two indepedent samples
#
# Here, we will compare male and female start weight and end weight

# %%
male_data <- subset(df, sex == 'Male', select = c('start_weight'))
female_data <- subset(df, sex == 'Female', select = c('start_weight'))

# %%
t.test(male_data, female_data, paired = FALSE)
# Out:
# 	Welch Two Sample t-test
#
# data:  male_data and female_data
# t = 2.1352, df = 27.897, p-value = 0.04166
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#   0.7236681 35.0096652
# sample estimates:
# mean of x mean of y
#  190.0667  172.2000

# %%
# Since our p value is less than .05, we can conclude that there is a difference
# Next let's plot the means to see the direction

# %%
ggplot(df, aes(sex,start_weight)) +
 geom_bar(stat = "summary", position = "dodge", fun = mean)
# Out:
# plot without title

# %%
# We can see that males weight more at start

# %%
# Compare end weights for males and females
male_data <- subset(df, sex == 'Male', select = c('end_weight'))
female_data <- subset(df, sex == 'Female', select = c('end_weight'))
t.test(male_data, female_data, paired = FALSE)
# Out:
# 	Welch Two Sample t-test
#
# data:  male_data and female_data
# t = 1.9597, df = 27.91, p-value = 0.06008
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -0.7415415 33.4082081
# sample estimates:
# mean of x mean of y
#  188.0000  171.6667

# %%
# Since our p-value is above .05, we conclude there is not a sig diff in end weights

# %% [markdown]
# ## Paired Sample t-test
#
# When data is paired, such as start and end weights for an individual, we run a paired samples t-test.
#
# Here, the question is: Do start and end weights differ?

# %%
t.test(df$start_weight, df$end_weight, paired = TRUE)
# Out:
# 	Paired t-test
#
# data:  df$start_weight and df$end_weight
# t = 2.5378, df = 29, p-value = 0.01679
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  0.2523037 2.3476963
# sample estimates:
# mean of the differences
#                     1.3

# %%
# Since our p value is less than .05, we can conclude that there is a difference
# Next, lets plot the data to visualize the difference

# %%
mean(df$start_weight)
mean(df$end_weight)
# Out:
# [1] 181.1333
# [1] 179.8333

# %%
long_form_data = melt(df, id.vars = c("id", "sex"))

# %%
long_form_data
# Out:
#    id sex    variable     value
# 1   1 Male   start_weight 203
# 2   2 Male   start_weight 180
# 3   3 Male   start_weight 222
# 4   4 Male   start_weight 190
# 5   5 Male   start_weight 201
# 6   6 Male   start_weight 185
# 7   7 Male   start_weight 150
# 8   8 Male   start_weight 193
# 9   9 Male   start_weight 209
# 10 10 Male   start_weight 213
# 11 11 Male   start_weight 209
# 12 12 Male   start_weight 160
# 13 13 Male   start_weight 175
# 14 14 Male   start_weight 155
# 15 15 Male   start_weight 206
# 16 16 Female start_weight 201
# 17 17 Female start_weight 197
# 18 18 Female start_weight 145
# 19 19 Female start_weight 167
# 20 20 Female start_weight 190
# 21 21 Female start_weight 185
# 22 22 Female start_weight 142
# 23 23 Female start_weight 169
# 24 24 Female start_weight 202
# 25 25 Female start_weight 146
# 26 26 Female start_weight 167
# 27 27 Female start_weight 190
# 28 28 Female start_weight 194
# 29 29 Female start_weight 154
# 30 30 Female start_weight 134
# 31  1 Male   end_weight   205
# 32  2 Male   end_weight   177
# 33  3 Male   end_weight   218
# 34  4 Male   end_weight   190
# 35  5 Male   end_weight   199
# 36  6 Male   end_weight   183
# 37  7 Male   end_weight   148
# 38  8 Male   end_weight   190
# 39  9 Male   end_weight   207
# 40 10 Male   end_weight   210
# 41 11 Male   end_weight   205
# 42 12 Male   end_weight   159
# 43 13 Male   end_weight   172
# 44 14 Male   end_weight   152
# 45 15 Male   end_weight   205
# 46 16 Female end_weight   210
# 47 17 Female end_weight   194
# 48 18 Female end_weight   144
# 49 19 Female end_weight   167
# 50 20 Female end_weight   190
# 51 21 Female end_weight   182
# 52 22 Female end_weight   141
# 53 23 Female end_weight   167
# 54 24 Female end_weight   201
# 55 25 Female end_weight   146
# 56 26 Female end_weight   164
# 57 27 Female end_weight   186
# 58 28 Female end_weight   191
# 59 29 Female end_weight   152
# 60 30 Female end_weight   140

# %%
ggplot(long_form_data, aes(variable,value)) +
 geom_bar(stat = "summary", position = "dodge", fun = mean)
# Out:
# plot without title

# %%
# Although it is hard to see in the plot, end weights were on average lower than start weights
