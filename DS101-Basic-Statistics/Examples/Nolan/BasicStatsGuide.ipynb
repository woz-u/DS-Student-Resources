# %% [markdown]
# # DS101 Basic Statistics Guide with Examples
# ## Nolan Hardeman
#
# The world of Data Science revolves around probability: finding which __Independent__ variables (x) predict which __Dependent__ variables (y), and what percentage of influence these __predictor__ variables have on the model. [Further Reading on foundations of probability in data science](https://www.analyticsvidhya.com/blog/2021/04/statistics-and-probability-concepts-for-data-science/)
#
# As we all know, and are refreshed of in the first module. Probability is the likelihood of an event happening. Refer to this video for a brief overview, and a look at independent and dependent events.

# %%
from IPython.display import YouTubeVideo
# Video Name: Probability Explained
YouTubeVideo('uzkc-qNVoOk', width=720, height=480)

# %% [markdown]
# #### Proabability: a simple visual
# ![Probability: Jar of Marbles]('../../../probability-marble-example.png')

# %% [markdown]
# #### Basic Rules of Probability
# ![Probability Rules](Media/basic-prob-rules.jpg)

# %% [markdown]
# ## Factorials:
#
# Remember that a factorial is: the product of an integer and all the integers below it; e.g. factorial four (4!) is equal to 24.

# %%
# Video Name: Intro to Factorials!
YouTubeVideo('eXcJOgNPYJE', width=720, height=480)

# %% [markdown]
# #### Factorial Notation
# ![Factorial Notation](Media/factorial-notation.png)

# %% [markdown]
# ## Combinations and Permutations:
#
# A combination is a possbile arrangement of items out of a total list of items.
# A permuataion is a possible arrangement of items out of the total list of items, but __the order does matter!__

# %%
# Video Name: Easy Coombinations and Permutaions
YouTubeVideo('bAk_7p5gAWc', width=720, height=480)

# %% [markdown]
# ## Boolean Operators:
#
# Knowing which boolean operator to use, and the restrictions that operator place upon your scenario are vital.
#
# #### Boolean Operators
# ![Boolean Operators]('Media/boolean-operators.png')

# %%
# Video Name: Boolean Operators: AND OR NOT
YouTubeVideo('bCAULDuMcso', width=720, height=480)
