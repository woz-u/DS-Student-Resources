# %% [markdown]
# <img src="https://github.githubassets.com/images/modules/logos_page/GitHub-Logo.png" align="left" alt="Python image" width = "300">

# %% [markdown]
# [Home](https://github.com) |
# [About](https://github.com/about) |
# [Community-Stories](https://github.com/readme) |
# [Customer-Stories](https://github.com/customer-stories?type=enterprise) |
# [Blog](https://github.blog/) |
# [Press](https://github.com/about/press)
# ***

# %%
from IPython.display import VimeoVideo
# Tutorial Video Name: Introduction to Python
VimeoVideo('570012385', width=720, height=480)
# Out:
#         <iframe
#             width="720"
#             height="480"
#             src="https://player.vimeo.com/video/570012385"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# <p style="text-align: left">
#   <img  src="https://git-scm.com/images/logo@2x.png" width="100" alt="git logo">
# </p>
#
# When you love to organize, share, work in a team, and showcase your work.
#
# ## [git](https://git-scm.com/)
#
# - [git docs](https://git-scm.com/docs)
# - [Pro Git book](https://git-scm.com/book/en/v2)
# - [git videos](https://git-scm.com/videos)
# - [git cli](https://git-scm.com/book/en/v2/Getting-Started-The-Command-Line)
#
# ---
#
# <p style="text-align: left">
#    <img  src="https://github.githubassets.com/images/modules/logos_page/Octocat.png" width="100" alt="github logo">
# </p>
#
# ## [GitHub](https://github.com/)
#
# ### Getting Started
# - [Get started](https://docs.github.com/en/get-started)
# - [Account and Profile](https://docs.github.com/en/account-and-profile)
# - [Authentication](https://docs.github.com/en/authentication)
# - [Billing and payments](https://docs.github.com/en/billing)
# - [Site policy](https://docs.github.com/en/site-policy)
#
# ### Collaborative coding
# - [GitHub Codespaces](https://docs.github.com/en/codespaces)
# - [Repositories](https://docs.github.com/en/repositories)
# - [Pull requests](https://docs.github.com/en/pull-requests)
# - [GitHub Discussions](https://docs.github.com/en/discussions)
#
# ### CI/CD and DevOps
# - [GitHub Actions](https://docs.github.com/en/actions)
# - [GitHub Packages](https://docs.github.com/en/packages)
# - [GitHub Pages](https://docs.github.com/en/pages)
#
# ### Security
# - [Code security](https://docs.github.com/en/code-security)
#
# ### Client apps
# - [GitHub CLI](https://docs.github.com/en/github-cli)
# - [GitHub Desktop](https://docs.github.com/en/desktop)
#
# ### Project management
# - [GitHub Issues](https://docs.github.com/en/issues)
# - [Search on GitHub](https://docs.github.com/en/search-github)
#
# ### Developers
# - [Developers](https://docs.github.com/en/developers)
# - [REST API](https://docs.github.com/en/rest)
# - [GraphQL API](https://docs.github.com/en/graphql)
#
# ### Enterprise and Teams
# - [Organizations](https://docs.github.com/en/organizations)
# - [Enterprise administrators](https://docs.github.com/en/enterprise-cloud@latest/admin)
#
# ### Community
# - [Building communities](https://docs.github.com/en/communities)
# - [GitHub Sponsors](https://docs.github.com/en/sponsors)
# - [Education](https://docs.github.com/en/education)
# - [GitHub Support](https://docs.github.com/en/support)
#
#
# ### [Education](https://docs.github.com/en/education)
# -[Git and GitHub learning resources](https://docs.github.com/en/get-started/quickstart/git-and-github-learning-resources)
# - [Manage coursework with GitHub Classroom](https://docs.github.com/en/education/manage-coursework-with-github-classroom)
# -[Basics of setting up GitHub Classroom](https://docs.github.com/en/education/manage-coursework-with-github-classroom/get-started-with-github-classroom/basics-of-setting-up-github-classroom)
#
# ### Popular
# - [About pull requests](https://docs.github.com/en/pull-requests/collaborating-with-pull-requests/proposing-changes-to-your-work-with-pull-requests/about-pull-requests)
# - [Authentication](https://docs.github.com/en/authentication)
# - [Adding locally hosted code to GitHub](https://docs.github.com/en/get-started/importing-your-projects-to-github/importing-source-code-to-github/adding-locally-hosted-code-to-github)
# - [Managing remote repositories](https://docs.github.com/en/get-started/getting-started-with-git/managing-remote-repositories)
# - [GitHub Pages Documentation](https://docs.github.com/en/pages)
#
# ### More!
# - [GitHub Docs](https://docs.github.com/en)
# - [GitHub flow](https://docs.github.com/en/get-started/quickstart/github-flow)
# - [Hello World](https://docs.github.com/en/get-started/quickstart/hello-world)
# - [Quickstart for GitHub Pages](https://docs.github.com/en/pages/quickstart)
# - [About Git](https://docs.github.com/en/get-started/using-git/about-git)
# - [Contributing to projects](https://docs.github.com/en/get-started/quickstart/contributing-to-projects)
# - [Be Social](https://docs.github.com/en/get-started/quickstart/be-social)
# - [Referencing and citing content](https://docs.github.com/en/repositories/archiving-a-github-repository/referencing-and-citing-content)
# - [About Issues](https://docs.github.com/en/issues/tracking-your-work-with-issues/about-issues)
# - [Basic writing and formatting syntax](https://docs.github.com/en/get-started/writing-on-github/getting-started-with-writing-and-formatting-on-github/basic-writing-and-formatting-syntax)
# - [Making READMEs Readable](https://github.com/18F/open-source-guide/blob/18f-pages/pages/making-readmes-readable.md)
# - [GitHub Training Videos](https://www.youtube.com/c/GitHubGuides/videos)
# - [Github README](https://docs.github.com/en/repositories/managing-your-repositorys-settings-and-features/customizing-your-repository/about-readmes)
# - [The README Project](https://github.com/readme)
# - [Github Desktop References](https://docs.github.com/en/desktop/installing-and-configuring-github-desktop)
# - [GitHub CLI](https://cli.github.com/)
#
# ### Popular Questions
#
# - What is the difference between branching and forking?
#
# ref: [Differencebetween.net](http://www.differencebetween.net/technology/difference-between-fork-and-branch/#:~:text=Branching%20is%20to%20create%20another,without%20affecting%20the%20main%20repository.)
# answer: Branching is to create another line of development in the project without affecting the main branch or repository. Forking, on the other hand, is to make a clone of the repository on your GitHub account without affecting the main repository.
#
# ---
#
# ref: [Quora](https://www.quora.com/What-is-the-difference-between-a-branch-and-a-fork-on-GitHub)
# A branch of a GitHub repository can be local to your PC or remote in GitHub. If you want to work on a specific feature on a repository, you branch out separately, work on that branch and then commit it to GitHub.
#
# If you branch out in your PC, it is a local branch. The branch itself needs to be committed along with the changes in it. The merge then happens from remote branch to the master branch.
#
# You raise a pull request to get the changes from the remote branch merged into the master branch. The owner of the master branch will accept your pull request and merge your changes.
#
# A fork (unlike branching) is a GitHub to GitHub operation. When you fork a repository, it’s a clone of the entire repository within GitHub with all of its branches. Typically you do a fork if you want to use the current repository as a base to work on a new project or make changes to show differences between the current repository and the new one in large open source projects.
#
# Forking creates a clone of the entire repository in your GitHub account and branches can be created from this repository as well.
#
# Pull requests are raised from a fork as well if it needs to be merged into a destination repository.
#
# ---
#
# Below is a reference from [Pluralsight](https://www.pluralsight.com/blog/software-development/the-definitive-guide-to-forks-and-branches-in-git)
#
# #### Let's talk about Open Source Patterns
#
# Open source patterns don’t always make the most sense for business.
#
# Their goals are a bit different: open source favors experimentation, where business tends to want focus in order to reduce time to market.
#
# Structural choices tend to mirror these goals. And the decision to use a forks or branches to work on features can have an appreciable impact a team’s overall productivity.
#
# Forking tends to empower a divergent evolution of the codebase, which makes it ideal for an environment that’s looking to empower broad experimentation on a theme.
#
# Branching, on the other hand, caters toward convergent evolution. This tends to be a better fit for private repositories, and why it is commonly used by enterprise companies and in most business contexts.
#
# #### Divergent development vs. Convergent development
#
# In the open source world, it’s very common for a codebase, once reaching a certain point, to split into two distinct projects, each with a different goal (though still a shared ancestry).
#
# The most canonical example is the Linux codebase. Today, Linux has many forks (i.e RedHat), all stemming from a shared historical baseline.
#
# What’s important to note is that these flavors aren’t just temporary development paths — they are codebases with distinct ‘identities,’ with no intention of re-integration with one another.
#
# Branches, on the other hand, are always intended to be ‘convergent’ development paths. Branches are ephemeral by their very nature: a branch is really nothing more than a pointer at the head of a commit lineage. Both this pointer and the branch are eventually destroyed and purged from the Git history after the branch is merged into origin/master.
#
# #### Forking creates an entirely new repository
#
# GitHub popularized “forking” with a convenient button. When you make a fork, you are duplicating the entire repository and its history up until that point in time.
#
# Forking creates a new repository
#
# Clicking the fork button in GitHub, or any other host that allows for forking, completes a git clone command and creates a new origin/master.
#
# Forks are best used: when the intent of the ‘split’ is to create a logically independent project, which may never reunite with its parent.
#
# In the open source world, this happens all the time. A team sees a codebase that could be a good starting point for their project, and they have no intention of trying to merge this back into the root codebase. So they use a fork as a starting point.
#
# #### Branching
#
# Branches are more commonly used to act like ‘construction zones’ in a codebase.
#
# Branches are best used: when they are created as temporary places to work through a feature, with the intent to merge the branch with the origin.
#
# Most branches are short lived; once a feature is merged into origin/master the branch is deleted. Some branches are long-lived, i.e. Staging, still have the intent to converge with origin/master.
#
# To create a branch, use git checkout -b new-branch which creates a new branch from the origin of your current repository. Changes can still occur on while you are working on your new-branch.

# %% [markdown]
# ## Command line Git
#
# ```git
# git fetch
# git pull
# git status
# git add .
# git commit -m "added file"
# git push
#
# #if you have things you don't want saved
# git stash
# ```
