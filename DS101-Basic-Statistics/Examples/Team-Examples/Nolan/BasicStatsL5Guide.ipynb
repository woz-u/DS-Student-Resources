# %% [markdown]
# # DS101 Basic Statistics Lesson 5 Guide with Examples
# ## Nolan Hardeman
#
# During Lesson 5 we are introduced to some the __Normal Distribution__.
#
# ### Normal Distrubtion
# <p style="text-align: left;">
#   <img width="600" alt="the normal distribution" src="../../../Media/normal-distribution.png">
# </p>
#
# [Reference](https://www.google.com/imgres?imgurl=https%3A%2F%2Fmiro.medium.com%2Fmax%2F1200%2F1*IdGgdrY_n_9_YfkaCh-dag.png&imgrefurl=https%3A%2F%2Ftowardsdatascience.com%2Funderstanding-the-68-95-99-7-rule-for-a-normal-distribution-b7b7cbf760c2&tbnid=tfalmXQH_1OaOM&vet=12ahUKEwiZ1N6V9cfzAhXNl60KHRx6AmUQMygAegUIARDKAQ..i&docid=IHBRA5u2SVyimM&w=1200&h=600&q=the%20normal%20distribution&ved=2ahUKEwiZ1N6V9cfzAhXNl60KHRx6AmUQMygAegUIARDKAQ)

# %%
from IPython.display import YouTubeVideo
# Video Name: The Normal Distribution, Clearly Explained!!!
YouTubeVideo('rzFX5NWojp0', width=720, height=480)

# %% [markdown]
# #### Click this link for more information!
# [Further reading](https://www.mathsisfun.com/data/standard-normal-distribution.html)

# %% [markdown]
# ### Standard Normal Distribution
# <p style="text-align: left;">
#   <img width="600" alt="the standard normal distribution" src="../../../Media/standard-normal-distribution.jpg">
# </p>
#
# [Reference](https://www.google.com/url?sa=i&url=https%3A%2F%2Fwww.youtube.com%2Fwatch%3Fv%3DBabHeCOLfys&psig=AOvVaw2ycuGHzYzvahDF0q4htq3K&ust=1634234212178000&source=images&cd=vfe&ved=0CAsQjRxqFwoTCKiz04X7x_MCFQAAAAAdAAAAABAc)
#
# ### The 68-95-99 Rule

# %%
# Video Name: The Normal Distribution and the 68-95-99.7 Rule (5.2)
YouTubeVideo('mtbJbDwqWLE', width=720, height=480)

# %% [markdown]
# ### the z-Score
# <p style="text-align: left;">
#   <img width="600" alt="z-Score formula" src="../../../Media/Z-score-formula.jpg">
# </p>
#
# [Reference](https://www.google.com/url?sa=i&url=https%3A%2F%2Ftoptipbio.com%2Fcalculate-z-scores-excel%2F&psig=AOvVaw0P1IYkeqQW5RlYq6UfMc7N&ust=1634234539159000&source=images&cd=vfe&ved=0CAsQjRxqFwoTCPj17p38x_MCFQAAAAAdAAAAABAJ)

# %%
# Video Name: ck12.org normal distribution problems: z-score | Probability and Statistics | Khan Academy
YouTubeVideo('Wp2nVIzBsE8', width=720, height=480)

# %% [markdown]
# #### z-Score Example
# <p style="text-align: left;">
#   <img width="600" alt="z-Score example" src="../../../Media/z-score-example.png">
# </p>
#
# [Reference](https://www.google.com/url?sa=i&url=https%3A%2F%2Fdatascienceupskill.com%2Fstatistics%2Fz-scores&psig=AOvVaw0KurEO39g17K-JP8YHPlVN&ust=1634234946865000&source=images&cd=vfe&ved=0CAsQjRxqFwoTCOiUn-79x_MCFQAAAAAdAAAAABAD)

# %% [markdown]
# ### z-Score and the Normal Distribution
# <p style="text-align: left;">
#   <img width="600" alt="z-Score and the normal distribution" src="../../../Media/z-score-normal-distribution.jpg">
# </p>
#
# [Reference](https://www.google.com/url?sa=i&url=https%3A%2F%2Fwww.youtube.com%2Fwatch%3Fv%3DmFYvUxOO2T4&psig=AOvVaw2jF2nH4YX3aepTxx0EVAqk&ust=1634235091011000&source=images&cd=vfe&ved=0CAsQjRxqFwoTCNCYoqX-x_MCFQAAAAAdAAAAABAD)

# %% [markdown]
# ## Use this applet to compute the z-Score
# ### Save abd Bookmark This Link
# [z-Score applet](https://davidmlane.com/hyperstat/z_table.html)

# %% [markdown]
# ### z-Scores to determine a percentage
# <p style="text-align: left;">
#   <img width="600" alt="z-Score to determine a percentile" src="../../../Media/z-score-percentage.jpg">
# </p>
#
# [Reference](https://www.google.com/url?sa=i&url=https%3A%2F%2Fslideplayer.com%2Fslide%2F7855419%2F&psig=AOvVaw3WsdDNwZpDHbWlv4u2JCXu&ust=1634235320391000&source=images&cd=vfe&ved=0CAsQjRxqFwoTCPCYj5D_x_MCFQAAAAAdAAAAABAZ)
