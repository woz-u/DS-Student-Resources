# %% [markdown]
# # DS101 Basic Statistics Lesson 3 Guide with Examples
# ## Nolan Hardeman
#
# During Lesson 3, we are introduced to concepts already familiar to us: variables. We use the ideas of variables everyday, whether we know ourselves to be using them or not. Whenever we weigh things in our minds, estimate distances, and guess the numbers of jellybeans in a jar, we are using variables.
#
# ### A Reminder of Experimental Design:
# <p style="text-align: left;">
#   <img width="600" alt="experimental design example" src="../../../Media/experimental-design-example.jpg">
# </p>
#
# [Reference](https://www.google.com/url?sa=i&url=https%3A%2F%2Fberel.delanolorettouw.org%2Fexperimental-design-examples%2F&psig=AOvVaw2ggy-iFeG2CAqILSnwaiee&ust=1634065110424000&source=images&cd=vfe&ved=0CAgQjRxqFwoTCNiEpYuFw_MCFQAAAAAdAAAAABAU)
#
# ### Different Types of Data
# <p style="text-align: left;">
#   <img width="600" alt="types of data" src="../../../Media/types-of-data.jpg">
# </p>
#
# [Reference](https://www.google.com/url?sa=i&url=https%3A%2F%2Fwww.analyticssteps.com%2Fblogs%2F4-types-data-statistics&psig=AOvVaw0uefaU4mPi-S4cV07Bi0Rn&ust=1634065446643000&source=images&cd=vfe&ved=0CAgQjRxqFwoTCKiZ86WGw_MCFQAAAAAdAAAAABAD)

# %%
from IPython.display import YouTubeVideo
# Video Name: Kinds of data
YouTubeVideo('7bsNWq2A5gI', width=720, height=480)

# %% [markdown]
# ### Quantitative to Categorical, or vice versa
# <p style="text-align: left;">
#   <img width="600" alt="categorical to numerical" src="../../../Media/categorical-to-quantitative.jpg">
# </p>
#
# [Reference](https://www.google.com/url?sa=i&url=https%3A%2F%2Fwww.youtube.com%2Fwatch%3Fv%3DbJHN86aaDnY&psig=AOvVaw13xWMmQv1VzHaIhVKqzKot&ust=1634067379431000&source=images&cd=vfe&ved=0CAgQjRxqFwoTCKCM-MONw_MCFQAAAAAdAAAAABAD)
# See here how we take several colors, and assign them value inside their specific column matching that color.

# %% [markdown]
# ### Ordinal Data
# <p style="text-align: left;">
#   <img width="600" alt="ordinal data" src="../../../Media/ordinal-data.jpg">
# </p>
#
# [Reference](https://www.google.com/url?sa=i&url=https%3A%2F%2Fcareerfoundry.com%2Fen%2Fblog%2Fdata-analytics%2Fwhat-is-ordinal-data%2F&psig=AOvVaw0lSLTVhWynzVga4ntNGYpJ&ust=1634068026973000&source=images&cd=vfe&ved=0CAgQjRxqFwoTCMjWw-eQw_MCFQAAAAAdAAAAABAD)

# %% [markdown]
# ### Discrete Quantitative Variables vs. Continuous Qunatitative Variables
# <p style="text-align: left;">
#   <img width="600" alt="discrete vs. continuous" src="../../../Media/examples-of-discrete-and-continuous-data.png">
# </p>
#
# [Reference](https://www.google.com/url?sa=i&url=https%3A%2F%2Fwww.mymarketresearchmethods.com%2Fdata-types-in-statistics%2Fexamples-of-discrete-and-continuous-data%2F&psig=AOvVaw1iYoMH3-ZED7sYrlY8dJ1c&ust=1634068492036000&source=images&cd=vfe&ved=0CAgQjRxqFwoTCJDkvdSRw_MCFQAAAAAdAAAAABAY)
