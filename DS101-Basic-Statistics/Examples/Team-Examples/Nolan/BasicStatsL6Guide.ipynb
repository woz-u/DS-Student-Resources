# %% [markdown]
# # DS101 Basic Statistics Lesson 6 Guide with Examples
# ## Nolan Hardeman
#
# During Lesson 6 we are introduced to __Statistical Inference__.
#
# ### Population and Samples
# <p style="text-align: left;">
#   <img width="600" alt="the normal distribution" src="../../../Media/Population-and-Sample1.jpg">
# </p>
#
# [Reference](https://www.google.com/url?sa=i&url=https%3A%2F%2Fwww.questionpro.com%2Fblog%2Fpopulation-vs-sample%2F&psig=AOvVaw3mE4Snzx1gPbXqnlO3wOKm&ust=1634579508474000&source=images&cd=vfe&ved=0CAgQjRxqFwoTCMjw_q6B0vMCFQAAAAAdAAAAABAD)
#
# ### Population and Samples
# <p style="text-align: left;">
#   <img width="600" alt="the normal distribution" src="../../../Media/pop-samp.png">
# </p>
#
# [Reference](https://www.google.com/url?sa=i&url=https%3A%2F%2Fwww.scribbr.com%2Fmethodology%2Fpopulation-vs-sample%2F&psig=AOvVaw3mE4Snzx1gPbXqnlO3wOKm&ust=1634579508474000&source=images&cd=vfe&ved=0CAgQjRxqFwoTCMjw_q6B0vMCFQAAAAAdAAAAABAI)
#
# ### Inference
# <p style="text-align: left;">
#   <img width="600" alt="inference" src="../../../Media/Inference.png">
# </p>
#
# [Reference](https://www.google.com/url?sa=i&url=https%3A%2F%2Fonline.stat.psu.edu%2Fstat200%2Fbook%2Fexport%2Fhtml%2F21&psig=AOvVaw3mE4Snzx1gPbXqnlO3wOKm&ust=1634579508474000&source=images&cd=vfe&ved=0CAgQjRxqFwoTCMjw_q6B0vMCFQAAAAAdAAAAABAN)

# %%
from IPython.display import YouTubeVideo
# Video Name: Population vs Sample
YouTubeVideo('eIZD1BFfw8E', width=720, height=480)

# %% [markdown]
# ### Sampling Methods (include convenience too)
# <p style="text-align: left;">
#   <img width="600" alt="sampling methods" src="../../../Media/probability-sampling.png">
# </p>
#
# [Reference](https://www.google.com/url?sa=i&url=https%3A%2F%2Fwww.scribbr.com%2Fmethodology%2Fsampling-methods%2F&psig=AOvVaw17CogPAk65qRYd9QYNgF43&ust=1634579816621000&source=images&cd=vfe&ved=0CAgQjRxqFwoTCLDr9r2C0vMCFQAAAAAdAAAAABAD)

# %%
# Video Name: Sampling: Simple Random, Convenience, systematic, cluster, stratified - Statistics Help
YouTubeVideo('be9e-Q-jC-0', width=720, height=480)

# %% [markdown]
# ### Statistical Inference
# <p style="text-align: left;">
#   <img width="600" alt="statistical inference" src="../../../Media/Statistical-Inference.jpg">
# </p>
#
# [Reference](https://www.google.com/url?sa=i&url=https%3A%2F%2Fslideplayer.com%2Fslide%2F5130463%2F&psig=AOvVaw1G3VjJcNcyMYv-lnSup_uz&ust=1634580024849000&source=images&cd=vfe&ved=0CAgQjRxqFwoTCPjG76KD0vMCFQAAAAAdAAAAABAJ)

# %% [markdown]
# ### Hypothesis Testing

# %%
# Video Name: Simple hypothesis testing | Probability and Statistics | Khan Academy
YouTubeVideo('5D1gV37bKXY', width=720, height=480)

# %% [markdown]
# ### Type 1 & Type 2 Errors
# <p style="text-align: left;">
#   <img width="600" alt="type 1 & type 2 errors" src="../../../Media/type-1-2-errors.png">
# </p>
#
# [Reference](https://www.google.com/url?sa=i&url=https%3A%2F%2Fwww.abtasty.com%2Fblog%2Ftype-1-and-type-2-errors%2F&psig=AOvVaw04roA5LakO56QU5bSwJKH9&ust=1634580223606000&source=images&cd=vfe&ved=0CAgQjRxqFwoTCKi08sKG0vMCFQAAAAAdAAAAABAD)

# %%
# Video Name: Type I error vs Type II error
YouTubeVideo('a_l991xUAOU', width=720, height=480)

# %% [markdown]
# ### Type 1 & Type 2 Errors - Visual Example
# <p style="text-align: left;">
#   <img width="600" alt="type 1 & type 2 errors - visual example" src="../../../Media/errorTypes.jpg">
# </p>
#
# [Reference](https://www.google.com/url?sa=i&url=https%3A%2F%2Fwww.statisticssolutions.com%2Fto-err-is-human-what-are-type-i-and-ii-errors%2F&psig=AOvVaw04roA5LakO56QU5bSwJKH9&ust=1634580223606000&source=images&cd=vfe&ved=0CAgQjRxqFwoTCKi08sKG0vMCFQAAAAAdAAAAABAJ)
