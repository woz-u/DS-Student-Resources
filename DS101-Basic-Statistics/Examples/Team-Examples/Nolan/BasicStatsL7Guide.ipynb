# %% [markdown]
# # DS101 Basic Statistics Lesson 7 Guide with Examples
# ## Nolan Hardeman
#
# During Lesson 7 we are introduced to __Uniform, Binomial, Student's T, & F-Distributions__.
#
# ### Uniform Distribution Examples
# <p style="text-align: left;">
#   <img width="600" alt="uniform distribution" src="../../../Media/uniform.png">
# </p>
#
# [Reference](https://www.google.com/url?sa=i&url=https%3A%2F%2Fcorporatefinanceinstitute.com%2Fresources%2Fknowledge%2Fother%2Funiform-distribution%2F&psig=AOvVaw3-9rjWF5RdaW6sxfuWNCvK&ust=1634582540720000&source=images&cd=vfe&ved=0CAgQjRxqFwoTCOC4ntyM0vMCFQAAAAAdAAAAABAD)
#
# ### Here is a video covering concepts, at length (this is a 50 minute video):

# %%
from IPython.display import YouTubeVideo
# Video Name: Standard Normal Distribution Tables, Z Scores, Probability & Empirical Rule - Stats
YouTubeVideo('CjF_yQ2N638', width=720, height=480)

# %% [markdown]
# ### The Student's t-Distribution
# <p style="text-align: left;">
#   <img width="600" alt="student's t-distribution" src="../../../Media/student-t-distribution.jpeg">
# </p>
#
# [Reference](https://image.slidesharecdn.com/studentt-distribution-100202074439-phpapp01/95/student-t-distribution-1-728.jpg?cb=1265096705)

# %%
from IPython.display import YouTubeVideo
# Video Name: Student's T Distribution
YouTubeVideo('32CuxWdOlow', width=720, height=480)

# %% [markdown]
# #### Remember: There is no formula to perform a one-step single sample t-test in excel
#
# We will have to uncover enough variables to solve for the t-statistic. Which we take, along with our degrees of freedom and plug into this applet: [student's t-probabilities applet](https://byuimath.com/apps/normprobwitht)
#
# ##### There are new methods being discovered everyday - here is a trick to getting a single sample t-test to run in excel (hint: just label and solve for all our variables!)
#     HERE IS THE GUIDE - SPREAD THIS KNOWLEDGE

# %%
from IPython.display import YouTubeVideo
# Video Name: How To Perform A One-Sample T-Test In Excel
YouTubeVideo('OCSmMABkVqQ', width=720, height=480)

# %% [markdown]
# [Another Resource](https://www.socscistatistics.com/tests/tsinglesample/default2.aspx)

# %% [markdown]
# ### Paired Vs. Independent Data - With Respect To t-Tests
# <p style="text-align: left;">
#   <img width="600" alt="uniform distribution" src="../../../Media/paired-vs-ind.png">
# </p>
#
# [Reference](https://www.google.com/url?sa=i&url=https%3A%2F%2Fwww.technologynetworks.com%2Finformatics%2Farticles%2Fpaired-vs-unpaired-t-test-differences-assumptions-and-hypotheses-330826&psig=AOvVaw0eYqXeXdcWtTgTlFzspDGG&ust=1635287452337000&source=images&cd=vfe&ved=0CAgQjRxqFwoTCKiHmNDO5vMCFQAAAAAdAAAAABAD)

# %%
from IPython.display import YouTubeVideo
# Video Name: Independent vs. Paired T-Tests: When To Use Each
YouTubeVideo('P83D-5F21DA', width=720, height=480)

# %% [markdown]
# ### Dependent t-Tests

# %%
from IPython.display import YouTubeVideo
# Video Name: Matched or Paired Samples T-Test - Hypothesis Testing
YouTubeVideo('JiQR0lHLe74', width=720, height=480)

# %% [markdown]
# ### Effect Size Formula - Cohen's d
# <p style="text-align: left;">
#   <img width="600" alt="cohen's d, effect size" src="../../../Media/effect-size-formula.png">
# </p>
#
# [Reference](https://www.google.com/imgres?imgurl=https%3A%2F%2Fcdn.educba.com%2Facademy%2Fwp-content%2Fuploads%2F2019%2F07%2FEffect-Size-Formula.jpg&imgrefurl=https%3A%2F%2Fwww.educba.com%2Feffect-size-formula%2F&tbnid=lo3fT_S_Hg2icM&vet=12ahUKEwjAop7C0ObzAhVFTa0KHVnXDDIQMygAegUIARDFAQ..i&docid=f0FpIELJ13mC0M&w=1024&h=526&q=effect%20size%20formula&ved=2ahUKEwjAop7C0ObzAhVFTa0KHVnXDDIQMygAegUIARDFAQ)

# %% [markdown]
# ### Dependent t-Test in Excel

# %%
from IPython.display import YouTubeVideo
# Video Name: How to perform paired t-test in Excel
YouTubeVideo('4WuVjdVDZ3I', width=720, height=480)

# %% [markdown]
# ### Independent t-Test in Excel

# %%
from IPython.display import YouTubeVideo
# Video Name: Independent-Samples t-test in Excel
YouTubeVideo('2r0k_NsVLAE', width=720, height=480)

# %% [markdown]
# ### F-Distribution

# %%
from IPython.display import YouTubeVideo
# Video Name: Introduction to the t Distribution (non-technical)
YouTubeVideo('Uv6nGIgZMVw', width=720, height=480)
