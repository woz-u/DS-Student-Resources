# %% [markdown]
# # DS101 Basic Statistics Lesson 4 Guide with Examples
# ## Nolan Hardeman
#
# During Lesson 4 we are introduced to some __Common Descriptive Statistics__.
#
# ### Descriptive Statistics vs. Inferential Statistics
# <p style="text-align: left;">
#   <img width="600" alt="descriptive vs. inferential" src="../../../Media/descriptive-vs-inferential.jpeg">
# </p>

# %%
from IPython.display import YouTubeVideo
# Video Name: Descriptive Statistics vs. Inferential Statistics
YouTubeVideo('VHYOuWu9jQI', width=720, height=480)

# %% [markdown]
# ### Measures of Central Tendency
# <p style="text-align: left;">
#   <img width="600" alt="central tendency" src="../../../Media/central-tendency.png">
# </p>
#
# [Reference](https://www.google.com/url?sa=i&url=https%3A%2F%2Fwww.researchgate.net%2Ffigure%2FDefinition-and-Measures-of-Central-Tendency_tbl1_326359246&psig=AOvVaw1ya1tCySK4NApS1QpSyezL&ust=1634148386001000&source=images&cd=vfe&ved=0CAgQjRxqFwoTCPjDwqi7xfMCFQAAAAAdAAAAABAJ)

# %%
# Video Name: Mean, Median, and Mode: Measures of Central Tendency: Crash Course Statistics #3
YouTubeVideo('kn83BA7cRNM', width=720, height=480)

# %% [markdown]
# ### Measures of Distribution
# <p style="text-align: left;">
#   <img width="600" alt="measures of distribution" src="../../../Media/measures-distribution.jpg">
# </p>
#
# [Reference](https://www.google.com/url?sa=i&url=https%3A%2F%2Fcdn.citl.illinois.edu%2Fcourses%2FKINES401%2FLesson1_lectures%2FLecture1_P4%2Fweb_data%2Ffile10.htm&psig=AOvVaw2UO6e2MaxuajNjz7OCQWOT&ust=1634148716184000&source=images&cd=vfe&ved=0CAgQjRxqFwoTCMjIs8e8xfMCFQAAAAAdAAAAABAE)

# %%
# Video Name: Range, variance and standard deviation as measures of dispersion
YouTubeVideo('E4HAYd0QnRc', width=720, height=480)

# %% [markdown]
# ### Quartiles
# <p style="text-align: left;">
#   <img width="600" alt="quartiles" src="../../../Media/quartiles.jpg">
# </p>
#
# [Reference](https://www.google.com/url?sa=i&url=https%3A%2F%2Fwww.sigmamagic.com%2Fblogs%2Fwhat-are-quartiles%2F&psig=AOvVaw3RFBvGXrd6AQypTxDJBEEB&ust=1634149360524000&source=images&cd=vfe&ved=0CAgQjRxqFwoTCODc0va_xfMCFQAAAAAdAAAAABAD)

# %%
# Video Name: Quartiles & Interquartile Range
YouTubeVideo('K3wsOqIqA6k', width=720, height=480)

# %% [markdown]
# ### Margin of Error and Confidence Interval
# <p style="text-align: left;">
#   <img width="600" alt="margin of error and confidence interval" src="../../../Media/margin-error-confidence-interval.png">
# </p>
#
# [Reference](https://www.google.com/url?sa=i&url=https%3A%2F%2Fmathalope.co.uk%2F2015%2F03%2F24%2Fudacity-inferential-statistics-margin-of-error-mind-map%2F&psig=AOvVaw2rmBQUIuFUxtikZc6rsr6T&ust=1634149868756000&source=images&cd=vfe&ved=0CAgQjRxqFwoTCOjs0ejAxfMCFQAAAAAdAAAAABAS)

# %%
# Video Name: How To Find The Z Score, Confidence Interval, and Margin of Error for a Population Mean
YouTubeVideo('DT-fPG0Hff8', width=720, height=480)

# %% [markdown]
# ### Measures of Frequency
#
# This visual describes measures of frequency in the context of disease, where it is most frequently used. The general idea is to get a rate/ratio/percentage to see the proportions.
#
# <p style="text-align: left;">
#   <img width="600" alt="measures of frequency" src="../../../Media/measure-frequency.jpg">
# </p>
#
# [Reference](https://www.google.com/url?sa=i&url=https%3A%2F%2Fslideplayer.com%2Fslide%2F6607075%2F&psig=AOvVaw3JB5iyV_hpngoJ7O91U_Vl&ust=1634150145644000&source=images&cd=vfe&ved=0CAgQjRxqFwoTCNi15OrBxfMCFQAAAAAdAAAAABAD)
