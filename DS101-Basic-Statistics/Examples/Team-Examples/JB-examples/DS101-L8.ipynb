# %% [markdown]
# #
# # DS101 Lesson 8 Helper
# #

# %% [markdown]
# Table of Contents
# - Overview and Objectives
# - Poisson Distribution
# - Exponential Distribution
# - Bathtub Curve
# - Chi-Square Distribution
# - Conducting Chi-Square
# - Chi-Square Activity
# - Chi-Square Activity Solution
# - Key Terms
# - Lesson 8 Exam

# %% [markdown]
# #
# # Overview and Objectives
#
# - Poisson distribution
# - Exponential distribution
# - Bathtub curve
# - Chi-square distribution

# %% [markdown]
# #
# # Poisson Distribution

# %%
from IPython.display import YouTubeVideo
# Video Name: Kinds of data
YouTubeVideo('jmqZG6roVqU', width=720, height=480)

# %% [markdown]
# [Reference](https://www.google.com/search?q=jmqZG6roVqU&oq=jmqZG6roVqU&aqs=chrome..69i57j69i60.1024j0j7&sourceid=chrome&ie=UTF-8)

# %% [markdown]
# #
# # How to Code Poisson in R

# %%
from IPython.display import YouTubeVideo
# Video Name: Kinds of data
YouTubeVideo('ekauSSzjvb8', width=720, height=480)

# %% [markdown]
# [Reference](https://www.youtube.com/watch?v=ekauSSzjvb8)

# %% [markdown]
# - Create an example to go through, link here to start up code and follow along

# %% [markdown]
# #
# # Expontential

# %%
from IPython.display import YouTubeVideo
# Video Name: Kinds of data
YouTubeVideo('p3T-_LMrvBc', width=720, height=480)

# %% [markdown]
# [Reference](https://www.youtube.com/watch?v=p3T-_LMrvBc)

# %% [markdown]
# #
# # How to Code Expontential Distribution in R

# %%
from IPython.display import YouTubeVideo
# Video Name: Kinds of data
YouTubeVideo('HenFpbOz6E4', width=720, height=480)

# %% [markdown]
# [Reference](https://www.youtube.com/watch?v=HenFpbOz6E4)

# %% [markdown]
# #
# # Expontential vs. Poisson

# %%
from IPython.display import YouTubeVideo
# Video Name: Kinds of data
YouTubeVideo('n7K8s4vryCQ', width=720, height=480)

# %% [markdown]
# [Reference](https://www.youtube.com/watch?v=n7K8s4vryCQ)

# %% [markdown]
# #
# # Bathtub curve

# %%
from IPython.display import YouTubeVideo
# Video Name: Kinds of data
YouTubeVideo('6A4_suM-ecg', width=720, height=480)

# %% [markdown]
# [Reference](https://www.youtube.com/watch?v=6A4_suM-ecg)
