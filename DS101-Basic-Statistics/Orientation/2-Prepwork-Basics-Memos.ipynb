# %% [markdown]
# # Prepwork, Basics and Important Memos for each Module

# %% [markdown]
# ### DS101- BASIC STATISTICS:
# 1. Conduct a simple walkthrough and overview of all the applications that students will learn throughout the program to provide deeper understanding of the programs and languages in each course
# 2. If you do NOT have Microsoft Excel, here are some free options:
#     - [Google Sheets]()
#     - [LibreOffice Calc Spreadsheets]()
#     - [Numbers on Mac]()
#     - 101 Spreadsheet fundamentals using [Excel](https://support.microsoft.com/en-us/office/excel-video-training-9bc05390-e94c-46af-a5b3-d7c22f6990bb), [Google sheets](https://support.google.com/a/users/answer/9282959?visit_id=637361702049227170-1815413770&rd=1), [Libre Calc](https://www.libreofficehelp.com/libreoffice-calc-tutorials/), and [Numbers](https://support.apple.com/numbers).
#     - 101 Introduce [Jupyter Lab notebooks](../Examples/12-Tutorial-Jupyter-Notebooks.ipynb) and simple command basics.
#     - 101 Simple math homework/refresher on day one to get the students thinking
#     - 101 [Windows Keyboard Basics](https://support.microsoft.com/en-us/windows/keyboard-shortcuts-in-windows-dcc61a57-8ff0-cffe-9796-cb9706c75eec)
#     - 101 [Mac Keyboard Basics](https://support.apple.com/en-us/HT201236)
#
# ### DS102- STATISTICAL PROGRAMING IN R:
# 1. Conduct a simple walkthrough and overview of all the applications that students will learn throughout the program to provide deeper understanding of the programs and languages in each course
#     - 102 Introduce Jupyter notebooks using R kernel
#     - 102 Introduce R and RStudio
#     - 102 [Path basics](../Examples/5-Path-Basics.ipynb)
#     - 102 [Importing Data](https://vimeo.com/734528591)
#         - Windows
#             - R-kernel in Jupyterlab
#             - Rstudio
#         - Mac
#             - R-kernel in Jupyterlab
#             - Rstudio
# 2. Common R Packages Basics
#     - 102 R [Packages Basic Packages](https://support.rstudio.com/hc/en-us/articles/201057987-Quick-list-of-useful-R-packages)
#     - 102 [R Cheatsheet](https://cheatography.com/tag/r/)
#
# ### DS108- DATABASES:
# 1. Conduct a simple walkthrough and overview of all the applications that students will learn throughout the program to provide deeper understanding of the programs and languages in each course
#     - 108 [SQL CheatSheet](https://www.interviewbit.com/sql-cheat-sheet/#crud-operations-in-sql)
#     - 108 [NoSQL Cheatsheet 1](https://gist.github.com/bradtraversy/f407d642bdc3b31681bc7e56d95485b6)
#     - 108 [NoSQL Cheatsheet 2](https://gist.github.com/michaeltreat/d3bdc989b54cff969df86484e091fd0c)
#
# ### DS109- PROGRAMING IN PYTHON:
# 1. Conduct a simple walkthrough and overview of all the applications that students will learn throughout the program to provide deeper understanding of the programs and languages in each course
#     - 109 Introduce [Jupyter Lab notebooks](../Examples/12-Tutorial-Jupyter-Notebooks.ipynb) and simple command basics.
#     - 109 Creating a Project in Python in VScode
#          - [Creating a file/project in command prompt](https://vimeo.com/showcase/8740300/video/631546106)
#      - 109 Command line basics
#         - Windows
#         - [Mac](../Examples/Mac-Terminal-Commands.ipynb)
#     - 109 [Path basics](../Examples/5-Path-Basics.ipynb)
#         - Windows vs Mac/Linux
#         - Absolute vs Relative
#     - 109 [Importing Data](https://nbviewer.org/github/woz-u/DS-Student-Resources/blob/main/DS101-Basic-Statistics/Orientation/3-Importing-Paths-Saving-Zipping-Data-Mac-Windows.ipynb)
#         - Windows
#             - Python-kernel in Jupyterlab
#         - Mac
#             - Python-kernel in Jupyterlab
# 2. Common Python Packages Basics
#     - 109 [Python Packages Basics](https://learnpython.com/blog/most-popular-python-packages/)
#
# ### DS104- DATA WRANGLING AND VISUALIZATIONS:
# 1. Conduct a simple walkthrough and overview of all the applications that students will learn throughout the program to provide deeper understanding of the programs and languages in each course
#     - 104 [Tableau Training Videos](https://public.tableau.com/en-us/s/resources)
#     - 104 [Tableau Examples](https://public.tableau.com/app/discover/viz-of-the-day)
# 2. [Common Codes](https://nbviewer.org/github/woz-u/DS-Student-Resources/blob/main/DS101-Basic-Statistics/Orientation/5-Common-Codes.ipynb) in Python and R
#     - 104 Python and R Graphing
#     - 104 Python and R Exploring Data code
#
# ### DS105- INTERMEDIATE STATISTICS:
# 1. Conduct a simple walkthrough and overview of all the applications that students will learn throughout the program to provide deeper understanding of the programs and languages in each course
#     - 105
#     - 105
# 2. Common Statistical Packages for Python and R
#     - 105 Python Statistical Packages
#     - 105 R Statistical Packages
#
# ### DS106- MACHINE LEARNING AND MODELING:
# 1. Conduct a simple walkthrough and overview of all the applications that students will learn throughout the program to provide deeper understanding of the programs and languages in each course
#     - 106
#     - 106
# 2. Common ML Packages for Python and R
#     - 106 Python ML Packages
#     - 106 R ML Packages
#
# ### DS107- INTRODUCTION TO BIG DATA:
#
# #### Memos
# 1. Conduct a simple walkthrough and overview of all the applications that students will learn throughout the program to provide deeper understanding of the programs and languages in each course
#     - 107 AWS emails
#     - 107 Look up computer specs, do not download VMs... etc
#     - 107 Focus on AWS and do alternative assignemnts
#
# ### DS103- METRICS AND PROCESSING:
# 1. Conduct a simple walkthrough and overview of all the applications that students will learn throughout the program to provide deeper understanding of the programs and languages in each course
#     - 103
#     - 103
