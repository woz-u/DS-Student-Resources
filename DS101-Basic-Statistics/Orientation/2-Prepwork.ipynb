# %% [markdown]
# # Prepwork: Important Memos, Basics and Advanced Concepts

# %% [markdown]
# ### DS101- BASIC STATISTICS:
# Conduct a simple walkthrough and overview of all the applications that students will learn throughout the program to provide deeper understanding of the programs and languages in each course
#
# 1. Memos: If you `Do NOT have Microsoft Excel`, here are some free options:
#     - [Google Sheets](https://www.google.com/sheets/about/), [LibreOffice Calc Spreadsheets](https://www.libreoffice.org/discover/calc/), Numbers on Mac
#
#
# 2. Basics:
#     - 101 Computer Basics: [Windows](https://vimeo.com/352609377) / [Mac Part 1](https://vimeo.com/352615114) and [Mac Part 2](https://vimeo.com/352616280)
#     - 101 Fundamentals of [Excel](https://support.microsoft.com/en-us/office/excel-video-training-9bc05390-e94c-46af-a5b3-d7c22f6990bb), [Google sheets](https://support.google.com/a/users/answer/9282959?visit_id=637361702049227170-1815413770&rd=1), [Libre Calc](https://www.libreofficehelp.com/libreoffice-calc-tutorials/), and [Numbers](https://support.apple.com/numbers).
#     - 101 [Math Basics](https://www.ipracticemath.com/learn/basicmath)
#     - 101 Key Board Basics:[Windows](https://support.microsoft.com/en-us/windows/keyboard-shortcuts-in-windows-dcc61a57-8ff0-cffe-9796-cb9706c75eec) / [Mac](https://support.apple.com/en-us/HT201236)
#     - 101 [Command Line Basics](https://www.computervillage.org/articles/CommandLine.pdf)
#         - [Mac](../Examples/Mac-Terminal-Commands.ipynb)
#         - [Windows](https://www.softwaretestinghelp.com/windows-cmd-commands/)
#
#
# 3. Advanced:
#     - 101 [Introduction to Jupyter Lab notebooks](../Examples/12-Tutorial-Jupyter-Notebooks.ipynb)
#     - 101 [Navigating through the Jupyter Notebooks](https://nbviewer.org/github/woz-u/DS-Student-Resources/blob/main/DS101-Basic-Statistics/Examples/0-Navigating-the-Companion-Notebook-Series.ipynb)
#     - 101 [Introduction to Github](https://nbviewer.org/github/woz-u/DS-Student-Resources/blob/main/DS101-Basic-Statistics/Examples/1-Github-Basics.ipynb)
#
# ### DS102- STATISTICAL PROGRAMMING IN R:
# Conduct a simple walkthrough and overview of all the applications that students will learn throughout the program to provide deeper understanding of the programs and languages in each course
#
# 2. Basics
#     - 102 Introduce RStudio
#     - 102 Common R [Packages](https://support.rstudio.com/hc/en-us/articles/201057987-Quick-list-of-useful-R-packages)
#     - 102 [R Cheatsheet](https://cheatography.com/tag/r/)
#
# 3. Advanced:
#     - 102 Introduce Jupyter notebooks using R kernel
#     - 102 [Path basics](../Examples/5-Path-Basics.ipynb)
#     - 102 [Importing Data](https://nbviewer.org/github/woz-u/DS-Student-Resources/blob/main/DS101-Basic-Statistics/Orientation/3-Importing-Saving-Files.ipynb)
#
# ### DS108- DATABASES:
# Conduct a simple walkthrough and overview of all the applications that students will learn throughout the program to provide deeper understanding of the programs and languages in each course
#
# 2. Basics:
#     - 108 [SQL CheatSheet](https://www.interviewbit.com/sql-cheat-sheet/#crud-operations-in-sql)
#     - 108 [NoSQL Cheatsheet 1](https://gist.github.com/bradtraversy/f407d642bdc3b31681bc7e56d95485b6)
#     - 108 [NoSQL Cheatsheet 2](https://gist.github.com/michaeltreat/d3bdc989b54cff969df86484e091fd0c)
#
#
# ### DS109- PROGRAMMING IN PYTHON:
# Conduct a simple walkthrough and overview of all the applications that students will learn throughout the program to provide deeper understanding of the programs and languages in each course
#
# 2. Basics:
#     - 109 [Command line basics](../Examples/Mac-Terminal-Commands.ipynb)
#     - 109 [Creating a python-course folder in the Command Prompt/Terminal](https://vimeo.com/showcase/8740300/video/631546106)
#     - 109 [Getting Started in VSCode](https://vimeo.com/showcase/8740300/video/631566043)
#
# 3. Advanced:
#     - 109 Introduction of [Jupyter Lab notebooks](../Examples/12-Tutorial-Jupyter-Notebooks.ipynb)
#     - 109 [Path basics](../Examples/5-Path-Basics.ipynb)
#         - Windows vs Mac/Linux
#         - Absolute vs Relative
#     - 109 [Importing Data](https://nbviewer.org/github/woz-u/DS-Student-Resources/blob/main/DS101-Basic-Statistics/Orientation/3-Importing-Saving-Files.ipynb)
#     - 109 [Python Packages Basics](https://learnpython.com/blog/most-popular-python-packages/)
#
# ### DS104- DATA WRANGLING AND VISUALIZATION:
# Conduct a simple walkthrough and overview of all the applications that students will learn throughout the program to provide deeper understanding of the programs and languages in each course
#
# 2. Basics:
#     - 104 [Importing Data](https://nbviewer.org/github/woz-u/DS-Student-Resources/blob/main/DS101-Basic-Statistics/Orientation/3-Importing-Paths-Saving-Zipping-Data-Mac-Windows.ipynb)
#     - 104 [Common Codes](https://nbviewer.org/github/woz-u/DS-Student-Resources/blob/main/DS101-Basic-Statistics/Orientation/5-Common-Codes.ipynb) in Python and R
#         - Graphing Code
#         - Exploring Data Code
#     - 104 [Data Transformations in Python](https://nbviewer.org/github/woz-u/DS-Student-Resources/blob/main/DS104-Data-Wrangling-and-Visualization/Examples/DataWrang-and-Viz-L2-Data-Transformations-Py.ipynb)
#     - 104 [Mosiac Graph](https://nbviewer.org/github/woz-u/DS-Student-Resources/blob/main/DS104-Data-Wrangling-and-Visualization/Examples/DS104-L5-P9-Mosaic-Example.ipynb)
#     - 104 [Tableau Training Videos](https://public.tableau.com/en-us/s/resources)
#     - 104 [Tableau Examples](https://public.tableau.com/app/discover/viz-of-the-day)
#
#
# 3. Advanced:
#     - 104 [Data Visualizations in Seaborn](https://nbviewer.org/github/woz-u/DS-Student-Resources/blob/main/DS104-Data-Wrangling-and-Visualization/Examples/Data%20Visualizations%20Using%20Seaborn.ipynb)
#     - 104 [Data Cleaning and PCA](https://nbviewer.org/github/woz-u/DS-Student-Resources/blob/main/DS104-Data-Wrangling-and-Visualization/Examples/Data_Cleaning_and_PCA_Example/Data_Cleaning_and_PCA.ipynb)
#     - 104 [Imputating Missing Data](https://nbviewer.org/github/woz-u/DS-Student-Resources/blob/main/DS104-Data-Wrangling-and-Visualization/Examples/MissingData-Imputations-R.ipynb)
#     - 104 [Dealing with Nulls](https://nbviewer.org/github/woz-u/DS-Student-Resources/blob/main/DS104-Data-Wrangling-and-Visualization/Examples/Fill-NAs-With-Mean-Or-Mode-Python.ipynb)
#     - 104 [Tableau Showcases](https://www.tableau.com/data-insights/dashboard-showcase)
#
# ### DS105- INTERMEDIATE STATISTICS:
# Conduct a simple walkthrough and overview of all the applications that students will learn throughout the program to provide deeper understanding of the programs and languages in each course
#
# 2. Basics:
#     - 105 Statistics in Python
#     - 105 Statistics in R
#
# 3. Advanced:
#     - 105 [find examples]()
#     - 105 [find examples]()
#     - 105 [find examples]()
#
# ### DS106- MACHINE LEARNING AND MODELING:
# Conduct a simple walkthrough and overview of all the applications that students will learn throughout the program to provide deeper understanding of the programs and languages in each course
#
# 2. Basics:
#     - 106 Python ML Packages
#     - 106 Machine Learning in Python
#     - 106 Modeling in Python
#
#     - 106 R ML Packages
#     - 106 Machine Learning in R
#     - 106 Modeling in R
#
# 3. Advanced:
#     - 105 [find examples]()
#     - 105 [find examples]()
#     - 105 [find examples]()
#
# ### DS107- INTRODUCTION TO BIG DATA:
#
# 1. Memos: This module is under contruction. We strongly advise you to do alternative assignments and focus on AWS. Use AWS Academy, but we have indeed switched over to using AWS Academy, and not AWS Educate. Sorry for any inconvience.
#
# - Please Follow the simple instructions below...
#     - 107 Find your computer specs, `DO NOT download anything!!!`
#         - Your computer will crash!!! (If your computer specs is 5-cores and 8gb Rams)
#     - 107 Look for AWS Academy email (look in spam folder)
#     - 107 Focus on AWS Academy and do alternative assignemntsin the LMS
#
#     - 107 Get 2 certifications instead of 1:
#         - 107 `AWS Academy is NOT apart of the LMS` and does not count towards assignments completed in the LMS, It is addition too the alternative assignments.
#         - 107 Please map out and complete AWS Cloud in the 3 week spand of the module
#         - 107 AWS certifications looks really good on resumes, Happy Learning
#
# ### DS103- METRICS AND PROCESSING:
# Conduct a simple walkthrough and overview of all the applications that students will learn throughout the program to provide deeper understanding of the programs and languages in each course
#
# 1. Memos:
#     - 103
#     - 103
