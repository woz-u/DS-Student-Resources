# %% [markdown]
# [Home](https://chocolatey.org)
# [Why](https://chocolatey.org/why-chocolatey)
# [Compare](https://chocolatey.org/compare)
# [FOSS](https://chocolatey.org/products/#foss)
# [Community](https://community.chocolatey.org)
# [Blog](https://blog.chocolatey.org)
# [Packages](https://community.chocolatey.org/packages)
# [Docs](https://docs.chocolatey.org/en-us/)
# [Install](https://chocolatey.org/install)
# ***
#
# # THE PACKAGE MANAGER FOR WINDOWS
#
# <img src="https://chocolatey.org/assets/images/global-shared/logo-square.svg" align="left" alt="Chocolatey image" width = "100" />
#
#
# ## Modern Software Automation

# %%
from IPython.display import VimeoVideo
# Tutorial Video Name: Chocolatey and companion notebook Installation
VimeoVideo('625448814', width=720, height=480)
# Out:
#         <iframe
#             width="720"
#             height="480"
#             src="https://player.vimeo.com/video/625448814"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ## APPLICATIONS FOR THE DATA SCIENCE COURSE
#
# ## Watch this Video while you are installing: https://vimeo.com/625448814
#
# ## Things to check:
#  - Ensure you have a solid, high-bandwidth and unlimited connection to the internet
#  - Don't install during a storm
#  - Important that if Anaconda3 or Python3 is installed that you uninstall it
#  - Important that if you have AVG or any other firewall protection that you dissable while installation of Chocolatey
#  - If you have previously tried to install Chocolatey and had an issue please remove the folder located here:
#
# ```powershell
# C:\ProgramData\chocolatey
# ```
#
#  - Check to see if you have Chocolatey running using the below command in powershell:
#
# ```powershell
# choco list --localonly
# ```

# %% [markdown]
# # Step 1: Open Powershell and run as Administrator
# <p style="text-align:center">
#   <img  src="../Media/powershell.png" width="400" alt="Powershell run as Admin" />
# </p>

# %% [markdown]
# # Step 2: Run the below command to install Chocolately in Powershell
# ```powershell
# Set-ExecutionPolicy Bypass -Scope Process -Force; [System.Net.ServicePointManager]::SecurityProtocol = [System.Net.ServicePointManager]::SecurityProtocol -bor 3072; iex ((New-Object System.Net.WebClient).DownloadString('https://chocolatey.org/install.ps1'))
# ```
#
# # Step 3: Close and Reopen Powershell for chocolately to take effect
#
# # Step 4: Install Python
# ### IMPORTANT Note: that if python is already installed please uninstall
#
# ```powershell
# choco install python3 --params "/InstallDir:C:\Python3"
#
# <Press A> for All
# ```
#
# # Step 5: Install Data Science Applications using powershell as administrator
# ### if you have a *.edu account change tableau-public to tableau-desktop
#
# ```powershell
# choco install git github-desktop mysql mysql.workbench vscode mongodb-shell vscode-mongodb vscode-python r r.studio tableau-public julia speedtest putty wget gpower mongodb nodejs
#
# <Press A> for All
# ```
#
# # Step 6: Follow steps in video to connect Github Desktop to Github.com account/create new account and then connect to github desktop
#
# https://github.com (right-click and open as a new tab)
#
# <font color='red'>Please DO NOT clone into Microsoft OneDrive! It will cause issues later</font>
#
# # Step 7: Clone the DS-Student-Resources Companion Notebook series
#
# https://github.com/woz-u/DS-Student-Resources (right-click and open as a new tab)
#
# # Step 8: After all Data Science Applications have installed please close Powershell
#
# if you have an error because of a hash mismatch for a specific application for tableau-public and/or gpower run:
#
# ```bash
# choco install tableau-public -y --ignore-checksums
# choco install gpower -y --ignore-checksums
# ```
#
# in an Administrator PowerShell
#
#
# # Step 9: SWITCH TO COMMAND PROMPT!!!!, Open the command prompt as Administrator to Install Jupyter Lab
#
# <p style="text-align: center;">
#   <img width="400" alt="open command prompt" src="../Media/cmd.png" />
# </p>
#
#
# ## In your command prompt type or copy the below command and run:
#
# ```bash
# pip install jupyterlab
# ```
#
# # Then update your pip using the command below
# ```shell
# C:\Python3\python.exe -m pip install --upgrade pip
# ```
# # Close and reopen command prompt as adminstrator
#
# <p style="text-align: center;">
#   <img width="400" alt="command prompt" src="../Media/shell.png" />
# </p>
#
# # Step 10: Install R kernel into Jupyter
# a.  open a command prompt as administrator
#
# b.  change directories by copying and pasting the below command into your command prompt
#
# ```shell
# cd C:\Program Files\R\R-4.*\bin
# ```
#
# c. Then type R in the command prompt
#
# ```shell
# R
# ```
#
# d. Rterm should open inside the command prompt/terminal:
#
# e. Inside the Rterm, install the below commands in order:
#
# ```R
# install.packages("devtools")
# # select the closest CRAN mirror to your location
#
# devtools::install_github("IRkernel/IRkernel")
# # select 1 for All updates
#
# IRkernel::installspec()
#
# q()
#
# y
# ```
#
# Note: that if Rtools didn't install, go ahead and run:
#
# ```bash
# install.packages("devtools", force=TRUE)
# ```
#
#
#
#
# # Step 11: Install Julia kernel into Jupyter
#
# a. Open another admin command prompt and type:
#
# ```bash
# julia
# ```
#
# b. Type the following line in the Julia terminal
#
# ```Julia
# using Pkg
# ```
#
# c. press ENTER
#
# d. Then type this command
#
# ```Julia
# Pkg.add("IJulia")
# ```
#
# e. Press ENTER
#
# f. You’ll have to wait a few minutes or so for the installation to complete
#
# # Step 12: Exit out of your current adminstrator command prompt
# # Step 13: Open a normal command prompt (Not in administrator mode)
#
# a.  change directories by copying and pasting the below command into your command prompt
#
# ```shell
# cd %userprofile%\Documents\GitHub\DS-Student-Resources
# ```
#
# <font color='red'>Note if this above command gave you an error, you didn't follow step 7 correctly and probably installed into Microsoft OneDrive</font>
#
# ## Enable quizzes inside your companion notebooks
#
# ```bash
# pip install ds-students
# pip install nodejs (if you don't already have it installed)
# ```
#
# # Step 14: Test jupyter lab by typing:
#
# ```shell
# jupyter lab
# ```
#
# a. You should see the companion notebook series. Ensure you see an option for an R and Julia notebook in the launcher in addition to Python
#
# <p style="text-align: center;">
#   <img width="600" alt="jupyter lab " src="../Media/jupyterlab.png" />
# </p>
#
# # Step 15: Test drive out the companion notebooks
#
# 1. double click on each course folder
# 2. double click the DS10... notebooks and explore each lesson
# 3. notice the examples folders
# 4. shift + enter to run each code cell
# 5. enable extensions in Jupyter Lab
# 6. install @jupyter-widgets/jupyterlab-manager
# 7. restart kernel and run all cells on the main question notebook
#
# # Step 16: You can start and stop both mysql and mongodb servers from administrator command prompt
#
# ## know that mysql workbench will start the server automatically in most instances
#
# ```bash
# net start mysql
# net stop mysql
# ```
#
# ```bash
# net start mongodb
# net stop mongodb
# ```
#
# # Step 17: Give your computer a good reboot!
#
# # Welcome to the Data Science World!
