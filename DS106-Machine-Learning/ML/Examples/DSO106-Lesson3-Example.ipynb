# %% [markdown]
#  ## Lesson 3
#
#  Creating a Decision Tree Model

# %% [markdown]
# ### Import Packages

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

# %% [markdown]
# Import your data

# %%
geyser = sns.load_dataset('geyser')

# %%
geyser.head()
# Out:
#    duration  waiting   kind
# 0     3.600       79   long
# 1     1.800       54  short
# 2     3.333       74   long
# 3     2.283       62  short
# 4     4.533       85   long

# %% [markdown]
# ![istockphoto-1028386430-612x612.jpg](attachment:istockphoto-1028386430-612x612.jpg)

# %% [markdown]
# ### Data Wrangling

# %% [markdown]
# Specify your x and y variables. y = the column you are predicting and x = everything you are using to predict it.

# %%
x = geyser.drop('kind', axis=1)
y = geyser['kind']

# %% [markdown]
# ### Train Test Split

# %% [markdown]
# Split the data into training and testing sets.

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.3, random_state=76)

# %% [markdown]
# ### Create Initial Decision Tree

# %% [markdown]
# Utilize the DecisionTreeClassifier() function and then fit() the model. Once more, to keep everyone on the same page,
# the random_state is 76.

# %%
decisionTree = DecisionTreeClassifier(random_state=76)
decisionTree.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier(random_state=76)

# %% [markdown]
# ### Assess the Model

# %% [markdown]
# Using the predict() function, utilize the same confusion matrix and classification report coding like you did before!

# %%
treePredictions = decisionTree.predict(x_test)

# %%
print(confusion_matrix(y_test, treePredictions))
# Out:
# [[53  0]
#  [ 0 29]]

# %% [markdown]
# ### How Well Does your Model Fit?

# %%
print(classification_report(y_test, treePredictions))
# Out:
#               precision    recall  f1-score   support
#
#         long       1.00      1.00      1.00        53
#        short       1.00      1.00      1.00        29
#
#     accuracy                           1.00        82
#    macro avg       1.00      1.00      1.00        82
# weighted avg       1.00      1.00      1.00        82
