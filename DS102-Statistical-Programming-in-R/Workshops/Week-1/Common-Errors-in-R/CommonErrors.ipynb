# %%
*For another instance of non-numeric
# Out:
# Error in ggplot(height_df, aes(x = height)): could not find function "ggplot"
# Traceback:

# %%
height <- c(171, 192, 183, 177, 154, 176)

# %%
height_df <- data.frame(height)

# %%
d <- ggplot(height_df, aes(x = height))
# Out:
# Error in ggplot(height_df, aes(x = height)): could not find function "ggplot"
# Traceback:

# %%
#This error above means we need to install package ggplot2
install.packages("ggplot2")
# Out:
# The downloaded binary packages are in
# 	/var/folders/wk/6why77bn1kn0l0pkd4vd3zl00000gn/T//Rtmppxcivh/downloaded_packages

# %%
#next we need to add it to our session
library(ggplot2)

# %%
#now we can call ggplot
d <- ggplot(height_df, aes(x = height))

# %%
d + geom_histogram(binwidth = 10) + ggtitle("Histogram of Heights") + xlab("Height (in cm)")
# Out:
# plot without title

# %%
# Remove the first plus sign to get non-numeric
faithful_histogram <- ggplot(faithful, aes(x = eruptions))

# %%
faithful_histogram + geom_histogram()
# Out:
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# plot without title

# %%
# Take off a paren up above from the first line of code to get unexpected symbol
Names <- c("Wolert", "BunBun", "Buffalump", "Teddy") Names + 1
