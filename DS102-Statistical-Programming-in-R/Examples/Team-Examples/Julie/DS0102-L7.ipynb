# %%
# DS0102: L7. t-Tests

# %%
# Requirements
# The nhtemp built-in data set gives the mean annual 
# temperature in New Haven, CT, for the years 1912 to 1971.

# Suppose you want to test whether the average over the 
# first 25 years (1912 to 1936) of the data is statistically
# significantly different than the average over the
# last 25 years (1947 to 1971) of the data set. 
# You create two vectors from the data set: 
# first25 and last25, using the following code:

# first25 <- nhtemp[1:25]
# last25 <- nhtemp[36:60]

# Compute a test to see if these two vectors have 
# the same mean.

# What type of t-test should you use?

# Single sample...
# Independent...
# Dependent...

# The correct answer is Dependent t-test!

# Within a text document, discuss the following:

# The problem to be solved
# The hypotheses
# The results of the hypothesis test and the conclusion
# What is the p-value for this test? Based on this p-value,
# do you reject the null hypothesis?

# %%
# Import Packages

# %%
install.packages("reshape")
# Out:
# The downloaded binary packages are in
# 	/var/folders/zx/l_cgsg6x7j9bkr74lmfcsk2h0000gn/T//RtmpjCcLfa/downloaded_packages

# %%
library(ggplot2)
library(reshape)

# %%
#Look at your Dataset

# %%
head(nhtemp)
# Out:
# [1] 49.9 52.3 49.4 51.1 49.4 47.9

# %%
# Vectors:
first25 <- nhtemp[1:25]
last25 <- nhtemp[36:60]

# %%
# Create data frame in order to run the 
# 1st way to find dependent t-test
NHtemp <- data.frame(first25,last25)

# %%
# 1st way to find dependent T-test:

# %%
NHtemp1 <- t.test(NHtemp$first25, NHtemp$last25, paired = TRUE)
print(NHtemp1)
# Out:
# 	Paired t-test
#
# data:  NHtemp$first25 and NHtemp$last25
# t = -3.924, df = 24, p-value = 0.0006383
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -2.2645321 -0.7034679
# sample estimates:
# mean of the differences
#                  -1.484

# %%
# OR

# %%
# 2nd way to find dependent T-test:

# %%
NHtemp2 <- t.test(first25, last25, paired = TRUE)
NHtemp2
# Out:
# 	Paired t-test
#
# data:  first25 and last25
# t = -3.924, df = 24, p-value = 0.0006383
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -2.2645321 -0.7034679
# sample estimates:
# mean of the differences
#                  -1.484

# %%
# The p value is .00, so because it is less than .05, 
# you should reject the null hypothesis! 
# There is a significant difference in temperatures between 
# the first twenty five years and the last twenty-five years.

# %%
# find means:

# %%
summary(first25)
summary(last25)
# Out:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#   47.90   49.60   50.60   50.42   51.10   52.80
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#    50.2    51.3    51.8    51.9    52.6    54.6

# %%
# the means are different
# first25 mean- 50.52
# last25 mean- 51.9

# %%
# problem: is there a significant difference between the temps
# How significant are the mean temp? in New Haven, CT, from the years (1912-1936) to (1947-1971)?
# Use Dependent t-test bc the temps  and years are dependent from one another, hint, time is usually dependent

# %%
NHtemp1 <- melt(nhtemp, measure.vars = c("first25", "last25"))

# %%
ggplot(NHtemp1) + geom_boxplot(aes(x = " " , y = " ")) + xlab(" ") + ylab(" ")
# Out:
# plot without title

# %%
ggplot(NHtemp1, aes(x = " ")) + geom_histogram(binwidth = 1) + xlab("Difference between first25 and last25")
# Out:
# ERROR while rich displaying an object: Error: StatBin requires a continuous x variable: the x variable is discrete.Perhaps you want stat="count"?
#
# Traceback:
# 1. FUN(X[[i]], ...)
# 2. tryCatch(withCallingHandlers({
#  .     if (!mime %in% names(repr::mime2repr))
#  .         stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
#  .     rpr <- repr::mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler), error = outer_handler)
# 3. tryCatchList(expr, classes, parentenv, handlers)
# 4. tryCatchOne(expr, names, parentenv, handlers[[1L]])
# 5. doTryCatch(return(expr), name, parentenv, handler)
# 6. withCallingHandlers({
#  .     if (!mime %in% names(repr::mime2repr))
#  .         stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
#  .     rpr <- repr::mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
# ...
